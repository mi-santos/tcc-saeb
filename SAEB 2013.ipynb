# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importando dados da prova SAEB de 2013

# %%
#saeb
df_saeb = pd.read_csv('gs://bucket-tcc-fia-mba/SAEB/2013/TS_ESCOLA_2013.csv', sep=',', encoding='utf-8', index_col = 'ID_ESCOLA')
print(df_saeb.shape)
# Out:
# (59251, 126)

# %%
with pd.option_context("display.max_rows", 153, "display.max_columns", 153):
    display(df_saeb.head())
# Out:
#            ID_PROVA_BRASIL  ID_UF  ID_MUNICIPIO  ID_DEPENDENCIA_ADM  \
# ID_ESCOLA
# 11025638              2013     11       1100015                   2
# 11025352              2013     11       1100015                   3
# 11024828              2013     11       1100015                   3
# 11025310              2013     11       1100015                   3
# 11024968              2013     11       1100015                   2
#
#            ID_LOCALIZACAO  PC_FORMACAO_DOCENTE_INICIAL  \
# ID_ESCOLA
# 11025638                1                         89.6
# 11025352                2                          NaN
# 11024828                2                         80.0
# 11025310                2                        100.0
# 11024968                1                         87.5
#
#            PC_FORMACAO_DOCENTE_FINAL NIVEL_SOCIO_ECONOMICO  \
# ID_ESCOLA
# 11025638                        54.1               Grupo 3
# 11025352                        34.5               Grupo 3
# 11024828                        19.7               Grupo 3
# 11025310                        39.7               Grupo 3
# 11024968                        38.9               Grupo 4
#
#            NU_MATRICULADOS_CENSO_5EF  NU_PRESENTES_5EF  TAXA_PARTICIPACAO_5EF  \
# ID_ESCOLA
# 11025638                        70.0              65.0               0.928571
# 11025352                         NaN               NaN                    NaN
# 11024828                         NaN               NaN                    NaN
# 11025310                         NaN               NaN                    NaN
# 11024968                        71.0              61.0               0.859155
#
#            ATE_NIVEL_1_LP5  NIVEL_2_LP5  NIVEL_3_LP5  NIVEL_4_LP5  \
# ID_ESCOLA
# 11025638              9.25        12.28        24.72        16.86
# 11025352               NaN          NaN          NaN          NaN
# 11024828               NaN          NaN          NaN          NaN
# 11025310               NaN          NaN          NaN          NaN
# 11024968             11.95         8.18        11.22        19.84
#
#            NIVEL_5_LP5  NIVEL_6_LP5  NIVEL_7_LP5  NIVEL_8_LP5  NIVEL_9_LP5  \
# ID_ESCOLA
# 11025638         15.21        15.51         6.17         0.00          0.0
# 11025352           NaN          NaN          NaN          NaN          NaN
# 11024828           NaN          NaN          NaN          NaN          NaN
# 11025310           NaN          NaN          NaN          NaN          NaN
# 11024968         29.26        13.18         4.71         1.66          0.0
#
#            NIVEL_0_MT5  NIVEL_1_MT5  NIVEL_2_MT5  NIVEL_3_MT5  NIVEL_4_MT5  \
# ID_ESCOLA
# 11025638          0.00         1.57         4.56        21.63        15.33
# 11025352           NaN          NaN          NaN          NaN          NaN
# 11024828           NaN          NaN          NaN          NaN          NaN
# 11025310           NaN          NaN          NaN          NaN          NaN
# 11024968          1.81         1.66         5.14         9.41        26.65
#
#            NIVEL_5_MT5  NIVEL_6_MT5  NIVEL_7_MT5  NIVEL_8_MT5  NIVEL_9_MT5  \
# ID_ESCOLA
# 11025638         23.05        21.48         9.25         1.55         1.57
# 11025352           NaN          NaN          NaN          NaN          NaN
# 11024828           NaN          NaN          NaN          NaN          NaN
# 11025310           NaN          NaN          NaN          NaN          NaN
# 11024968         19.12        16.80        14.55         4.85         0.00
#
#            NIVEL_10_MT5  NU_MATRICULADOS_CENSO_9EF  NU_PRESENTES_9EF  \
# ID_ESCOLA
# 11025638            0.0                      113.0              97.0
# 11025352            NaN                       31.0              25.0
# 11024828            NaN                       23.0              20.0
# 11025310            NaN                       34.0              27.0
# 11024968            0.0                       92.0              66.0
#
#            TAXA_PARTICIPACAO_9EF  NIVEL_0_LP9  NIVEL_1_LP9  NIVEL_2_LP9  \
# ID_ESCOLA
# 11025638                0.858407        33.24        12.14        15.36
# 11025352                0.806452        31.83        20.00        23.66
# 11024828                0.869565        30.00        25.00         5.00
# 11025310                0.794118        34.61        21.37        28.92
# 11024968                0.717391        19.64        15.19        18.36
#
#            NIVEL_3_LP9  NIVEL_4_LP9  NIVEL_5_LP9  NIVEL_6_LP9  NIVEL_7_LP9  \
# ID_ESCOLA
# 11025638         16.78        13.16         7.22         2.09         0.00
# 11025352         16.34         4.52         3.66         0.00         0.00
# 11024828         30.00         5.00         5.00         0.00         0.00
# 11025310         10.69         0.00         4.41         0.00         0.00
# 11024968         19.99        17.91         4.44         3.05         1.42
#
#            NIVEL_8_LP9  NIVEL_0_MT9  NIVEL_1_MT9  NIVEL_2_MT9  NIVEL_3_MT9  \
# ID_ESCOLA
# 11025638           0.0        18.78        17.45        17.58        24.62
# 11025352           0.0        17.20         8.17        27.31        35.48
# 11024828           0.0        35.00        15.00         5.00        25.00
# 11025310           0.0        44.71        10.69        12.55        16.96
# 11024968           0.0        10.96        13.23        27.15        21.62
#
#            NIVEL_4_MT9  NIVEL_5_MT9  NIVEL_6_MT9  NIVEL_7_MT9  NIVEL_8_MT9  \
# ID_ESCOLA
# 11025638         16.49         1.98         2.03         1.07          0.0
# 11025352          8.17         3.66         0.00         0.00          0.0
# 11024828         20.00         0.00         0.00         0.00          0.0
# 11025310         10.69         0.00         0.00         4.41          0.0
# 11024968         21.36         2.84         0.00         2.84          0.0
#
#            NIVEL_9_MT9  MEDIA_5EF_LP  MEDIA_5EF_MT  MEDIA_9EF_LP  \
# ID_ESCOLA
# 11025638           0.0        209.54        230.22        233.25
# 11025352           0.0           NaN           NaN        223.29
# 11024828           0.0           NaN           NaN        228.97
# 11025310           0.0           NaN           NaN        219.39
# 11024968           0.0        213.73        233.84        242.93
#
#            MEDIA_9EF_MT  IN_PREENCHIMENTO_QUESTIONARIO TX_RESP_Q007  \
# ID_ESCOLA
# 11025638         242.78                              1            A
# 11025352         239.49                              1            B
# 11024828         226.35                              1            C
# 11025310         222.39                              1            B
# 11024968         250.56                              1            B
#
#           TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010 TX_RESP_Q011 TX_RESP_Q012  \
# ID_ESCOLA
# 11025638             A            C            B            A            B
# 11025352             C            C            C            C            C
# 11024828             C            B            B            B            C
# 11025310             B            B          NaN            C            B
# 11024968             A            A            A            A            A
#
#           TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015 TX_RESP_Q016 TX_RESP_Q017  \
# ID_ESCOLA
# 11025638             C            B            B            B            A
# 11025352             C            C            C            B            B
# 11024828             C            C            C            B            C
# 11025310             B            C            C            B            A
# 11024968             B            B            B            B            B
#
#           TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020 TX_RESP_Q021 TX_RESP_Q022  \
# ID_ESCOLA
# 11025638             A            C            A            A            A
# 11025352             C            C            B            B            A
# 11024828             B            C            A            A            C
# 11025310             A            B            D            D            A
# 11024968             A            B            B            B            B
#
#           TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025 TX_RESP_Q026 TX_RESP_Q027  \
# ID_ESCOLA
# 11025638             A            D            D            D            D
# 11025352             A            C            A            A            C
# 11024828             C            D            C            B            D
# 11025310             A            A            D            A            D
# 11024968             B            C            C            C            C
#
#           TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030 TX_RESP_Q031 TX_RESP_Q032  \
# ID_ESCOLA
# 11025638             D            D            D            B            A
# 11025352             C            C            C            C            A
# 11024828             D            D            D            A            B
# 11025310             D            D            B            A            B
# 11024968             C            C            B            B            A
#
#           TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035 TX_RESP_Q036 TX_RESP_Q037  \
# ID_ESCOLA
# 11025638             A            A            B            C            A
# 11025352             B            A            A            B            B
# 11024828             A            B            B            A            B
# 11025310             A            A            A            A            A
# 11024968             A            B            B            B            B
#
#           TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040 TX_RESP_Q041 TX_RESP_Q042  \
# ID_ESCOLA
# 11025638             B            B            A            A            A
# 11025352             D            B            D            A            A
# 11024828             D            A            A            A            A
# 11025310             D            A            D            A            A
# 11024968             B            B            B            A            A
#
#           TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045 TX_RESP_Q046 TX_RESP_Q047  \
# ID_ESCOLA
# 11025638             D            A            A            A            A
# 11025352             A            A            A            A            A
# 11024828             B            A            A            A            A
# 11025310             A            A            B            A            A
# 11024968             C            B            A            A            A
#
#           TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050 TX_RESP_Q051 TX_RESP_Q052  \
# ID_ESCOLA
# 11025638             B            A            D            A            B
# 11025352             A            A            C            A            C
# 11024828             A            A            C            A            A
# 11025310             A            A            D            A            A
# 11024968             A            A            D            A            B
#
#           TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055 TX_RESP_Q056 TX_RESP_Q057  \
# ID_ESCOLA
# 11025638             A            A            A            A            C
# 11025352             D            A            D            D            B
# 11024828             D            D            D            B            B
# 11025310             D            A            D            B            B
# 11024968           NaN            A            A            A            B
#
#           TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060 TX_RESP_Q061 TX_RESP_Q062  \
# ID_ESCOLA
# 11025638             A            B            C            C            C
# 11025352             D            A            D            D            D
# 11024828             D            B            D            D            D
# 11025310             D            A            D            D            D
# 11024968             C            A            A            A            D
#
#           TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065 TX_RESP_Q066 TX_RESP_Q067  \
# ID_ESCOLA
# 11025638             D            B            A            B            B
# 11025352             D            D            A            B            A
# 11024828             D            D            B            C            C
# 11025310             D            D            A            B            A
# 11024968             D            D            A            B            B
#
#           TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070 TX_RESP_Q071 TX_RESP_Q072  \
# ID_ESCOLA
# 11025638             A            A            B            A            A
# 11025352             A            A            A            A            A
# 11024828             A            A            B            B            A
# 11025310             A            A            B            A            A
# 11024968             A            A            A            A            A
#
#           TX_RESP_Q073 TX_RESP_Q074
# ID_ESCOLA
# 11025638             A            B
# 11025352             A            A
# 11024828             B            B
# 11025310             A            A
# 11024968             A            A

# %% [markdown]
# Deleta colunas de avaliação de outros periodos de ensino.

# %%
df_saeb.drop(columns=['PC_FORMACAO_DOCENTE_INICIAL', 'IN_PREENCHIMENTO_QUESTIONARIO',
                      'NU_MATRICULADOS_CENSO_5EF', 'NU_PRESENTES_5EF', 'TAXA_PARTICIPACAO_5EF', 
                      'ATE_NIVEL_1_LP5', 'NIVEL_2_LP5', 'NIVEL_3_LP5', 'NIVEL_4_LP5', 'NIVEL_5_LP5', 'NIVEL_6_LP5', 'NIVEL_7_LP5', 'NIVEL_8_LP5', 'NIVEL_9_LP5', 
                      'NIVEL_0_MT5', 'NIVEL_1_MT5', 'NIVEL_2_MT5', 'NIVEL_3_MT5', 'NIVEL_4_MT5', 'NIVEL_5_MT5', 'NIVEL_6_MT5', 'NIVEL_7_MT5', 'NIVEL_8_MT5', 'NIVEL_9_MT5', 'NIVEL_10_MT5',
                      'MEDIA_5EF_LP', 'MEDIA_5EF_MT'], inplace=True)
print(df_saeb.shape)
# Out:
# (59251, 99)

# %% [markdown]
# Remove escolas que não possuem nono ano.

# %%
df_saeb9 = df_saeb[df_saeb['NU_MATRICULADOS_CENSO_9EF'].notnull()]
df_saeb9.shape
# Out:
# (31776, 99)

# %%
with pd.option_context("display.max_rows", 153, "display.max_columns", 153):
    display(df_saeb9.head())
# Out:
#            ID_PROVA_BRASIL  ID_UF  ID_MUNICIPIO  ID_DEPENDENCIA_ADM  \
# ID_ESCOLA
# 11025638              2013     11       1100015                   2
# 11025352              2013     11       1100015                   3
# 11024828              2013     11       1100015                   3
# 11025310              2013     11       1100015                   3
# 11024968              2013     11       1100015                   2
#
#            ID_LOCALIZACAO  PC_FORMACAO_DOCENTE_FINAL NIVEL_SOCIO_ECONOMICO  \
# ID_ESCOLA
# 11025638                1                       54.1               Grupo 3
# 11025352                2                       34.5               Grupo 3
# 11024828                2                       19.7               Grupo 3
# 11025310                2                       39.7               Grupo 3
# 11024968                1                       38.9               Grupo 4
#
#            NU_MATRICULADOS_CENSO_9EF  NU_PRESENTES_9EF  TAXA_PARTICIPACAO_9EF  \
# ID_ESCOLA
# 11025638                       113.0              97.0               0.858407
# 11025352                        31.0              25.0               0.806452
# 11024828                        23.0              20.0               0.869565
# 11025310                        34.0              27.0               0.794118
# 11024968                        92.0              66.0               0.717391
#
#            NIVEL_0_LP9  NIVEL_1_LP9  NIVEL_2_LP9  NIVEL_3_LP9  NIVEL_4_LP9  \
# ID_ESCOLA
# 11025638         33.24        12.14        15.36        16.78        13.16
# 11025352         31.83        20.00        23.66        16.34         4.52
# 11024828         30.00        25.00         5.00        30.00         5.00
# 11025310         34.61        21.37        28.92        10.69         0.00
# 11024968         19.64        15.19        18.36        19.99        17.91
#
#            NIVEL_5_LP9  NIVEL_6_LP9  NIVEL_7_LP9  NIVEL_8_LP9  NIVEL_0_MT9  \
# ID_ESCOLA
# 11025638          7.22         2.09         0.00          0.0        18.78
# 11025352          3.66         0.00         0.00          0.0        17.20
# 11024828          5.00         0.00         0.00          0.0        35.00
# 11025310          4.41         0.00         0.00          0.0        44.71
# 11024968          4.44         3.05         1.42          0.0        10.96
#
#            NIVEL_1_MT9  NIVEL_2_MT9  NIVEL_3_MT9  NIVEL_4_MT9  NIVEL_5_MT9  \
# ID_ESCOLA
# 11025638         17.45        17.58        24.62        16.49         1.98
# 11025352          8.17        27.31        35.48         8.17         3.66
# 11024828         15.00         5.00        25.00        20.00         0.00
# 11025310         10.69        12.55        16.96        10.69         0.00
# 11024968         13.23        27.15        21.62        21.36         2.84
#
#            NIVEL_6_MT9  NIVEL_7_MT9  NIVEL_8_MT9  NIVEL_9_MT9  MEDIA_9EF_LP  \
# ID_ESCOLA
# 11025638          2.03         1.07          0.0          0.0        233.25
# 11025352          0.00         0.00          0.0          0.0        223.29
# 11024828          0.00         0.00          0.0          0.0        228.97
# 11025310          0.00         4.41          0.0          0.0        219.39
# 11024968          0.00         2.84          0.0          0.0        242.93
#
#            MEDIA_9EF_MT TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010  \
# ID_ESCOLA
# 11025638         242.78            A            A            C            B
# 11025352         239.49            B            C            C            C
# 11024828         226.35            C            C            B            B
# 11025310         222.39            B            B            B          NaN
# 11024968         250.56            B            A            A            A
#
#           TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015  \
# ID_ESCOLA
# 11025638             A            B            C            B            B
# 11025352             C            C            C            C            C
# 11024828             B            C            C            C            C
# 11025310             C            B            B            C            C
# 11024968             A            A            B            B            B
#
#           TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020  \
# ID_ESCOLA
# 11025638             B            A            A            C            A
# 11025352             B            B            C            C            B
# 11024828             B            C            B            C            A
# 11025310             B            A            A            B            D
# 11024968             B            B            A            B            B
#
#           TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025  \
# ID_ESCOLA
# 11025638             A            A            A            D            D
# 11025352             B            A            A            C            A
# 11024828             A            C            C            D            C
# 11025310             D            A            A            A            D
# 11024968             B            B            B            C            C
#
#           TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030  \
# ID_ESCOLA
# 11025638             D            D            D            D            D
# 11025352             A            C            C            C            C
# 11024828             B            D            D            D            D
# 11025310             A            D            D            D            B
# 11024968             C            C            C            C            B
#
#           TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035  \
# ID_ESCOLA
# 11025638             B            A            A            A            B
# 11025352             C            A            B            A            A
# 11024828             A            B            A            B            B
# 11025310             A            B            A            A            A
# 11024968             B            A            A            B            B
#
#           TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040  \
# ID_ESCOLA
# 11025638             C            A            B            B            A
# 11025352             B            B            D            B            D
# 11024828             A            B            D            A            A
# 11025310             A            A            D            A            D
# 11024968             B            B            B            B            B
#
#           TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045  \
# ID_ESCOLA
# 11025638             A            A            D            A            A
# 11025352             A            A            A            A            A
# 11024828             A            A            B            A            A
# 11025310             A            A            A            A            B
# 11024968             A            A            C            B            A
#
#           TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050  \
# ID_ESCOLA
# 11025638             A            A            B            A            D
# 11025352             A            A            A            A            C
# 11024828             A            A            A            A            C
# 11025310             A            A            A            A            D
# 11024968             A            A            A            A            D
#
#           TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055  \
# ID_ESCOLA
# 11025638             A            B            A            A            A
# 11025352             A            C            D            A            D
# 11024828             A            A            D            D            D
# 11025310             A            A            D            A            D
# 11024968             A            B          NaN            A            A
#
#           TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060  \
# ID_ESCOLA
# 11025638             A            C            A            B            C
# 11025352             D            B            D            A            D
# 11024828             B            B            D            B            D
# 11025310             B            B            D            A            D
# 11024968             A            B            C            A            A
#
#           TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065  \
# ID_ESCOLA
# 11025638             C            C            D            B            A
# 11025352             D            D            D            D            A
# 11024828             D            D            D            D            B
# 11025310             D            D            D            D            A
# 11024968             A            D            D            D            A
#
#           TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070  \
# ID_ESCOLA
# 11025638             B            B            A            A            B
# 11025352             B            A            A            A            A
# 11024828             C            C            A            A            B
# 11025310             B            A            A            A            B
# 11024968             B            B            A            A            A
#
#           TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074
# ID_ESCOLA
# 11025638             A            A            A            B
# 11025352             A            A            A            A
# 11024828             B            A            B            B
# 11025310             A            A            A            A
# 11024968             A            A            A            A

# %% [markdown]
# #### Base questionário Diretor

# %%
#diretor
df_diretor = pd.read_csv('gs://bucket-tcc-fia-mba/SAEB/2013/TS_DIRETOR_2013.csv', sep=',', encoding='utf-8', index_col = 'ID_ESCOLA')
print(df_diretor.shape)
# Out:
# (56737, 117)

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_diretor.head(10))
# Out:
#            ID_PROVA_BRASIL  ID_UF  ID_MUNICIPIO  ID_DEPENDENCIA_ADM  \
# ID_ESCOLA
# 11024682              2013     11       1100015                   2
# 11024828              2013     11       1100015                   3
# 11024968              2013     11       1100015                   2
# 11025310              2013     11       1100015                   3
# 11025352              2013     11       1100015                   3
# 11025620              2013     11       1100015                   2
# 11025638              2013     11       1100015                   2
# 11006773              2013     11       1100023                   2
# 11006846              2013     11       1100023                   2
# 11006854              2013     11       1100023                   3
#
#            ID_LOCALIZACAO  IN_PREENCHIMENTO_QUESTIONARIO TX_RESP_Q001  \
# ID_ESCOLA
# 11024682                1                              1            B
# 11024828                2                              1            B
# 11024968                1                              1            B
# 11025310                2                              1            B
# 11025352                2                              1            B
# 11025620                1                              1            B
# 11025638                1                              1            B
# 11006773                1                              1            B
# 11006846                1                              1            B
# 11006854                1                              1            A
#
#           TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004 TX_RESP_Q005 TX_RESP_Q006  \
# ID_ESCOLA
# 11024682             C            A            D            C            B
# 11024828             E            A            D            D            B
# 11024968             E            B            G            C            C
# 11025310             C            B            D            B            B
# 11025352             C            A            F            C            C
# 11025620             D            A            G            C            C
# 11025638             D            A            G            C            C
# 11006773             D            B            H            E            D
# 11006846             D            B            D            D            B
# 11006854             C            B            H            C            C
#
#           TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010 TX_RESP_Q011  \
# ID_ESCOLA
# 11024682             B            C            E            G            C
# 11024828             D            C            F            D            C
# 11024968             B            C            C            H            C
# 11025310             D            C            E            G            C
# 11025352             B            C            D            F            C
# 11025620             B            A            A            G            C
# 11025638             B            A            A            I            C
# 11006773             B            C            E            F            C
# 11006846             B            C            E            I            C
# 11006854             B            C            E            I            C
#
#           TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015 TX_RESP_Q016  \
# ID_ESCOLA
# 11024682           NaN            A            B            D            C
# 11024828             D            B            C            H            A
# 11024968             I            B            B            H            B
# 11025310             G            B            C            F            A
# 11025352           NaN            B            C            F            A
# 11025620             G            B            B            F            C
# 11025638             I            B            B            H            C
# 11006773             E            B            B            F            E
# 11006846             I            B            B            H            B
# 11006854             I            A            B            E            C
#
#           TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020 TX_RESP_Q021  \
# ID_ESCOLA
# 11024682             C            D            B            E            A
# 11024828             A            G            B            E            B
# 11024968             B            G            A            A            B
# 11025310             A            E            B            D            A
# 11025352             A            E            B            D            B
# 11025620             C            F            B            E            B
# 11025638             B            G            B            A            B
# 11006773             C            G            B            E            B
# 11006846             B            G            B            D            B
# 11006854             B            F            B            C            B
#
#           TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025 TX_RESP_Q026  \
# ID_ESCOLA
# 11024682             C            C            C            B            B
# 11024828             B            B            B            B            A
# 11024968             B            C            C            B            A
# 11025310             B            B            B            C            A
# 11025352             B            B            B            C            A
# 11025620             C            B            B            B            B
# 11025638             B            B            B            C            A
# 11006773             C            C            C            B            B
# 11006846             C            C            B            C            A
# 11006854             C            C            C            C            A
#
#           TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030 TX_RESP_Q031  \
# ID_ESCOLA
# 11024682             E            D            E            C            D
# 11024828             E            B            A            A            D
# 11024968             A            A            E            B            E
# 11025310             A            D            D            B            E
# 11025352             A            C            A            A            E
# 11025620             E            E            E            B            E
# 11025638           NaN            D            E            B            E
# 11006773             E            E            E            B            E
# 11006846             E            E            D            C            E
# 11006854             A            D            E            B            E
#
#           TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035 TX_RESP_Q036  \
# ID_ESCOLA
# 11024682             H            A            A            A            A
# 11024828             C            A            A            A            A
# 11024968             F            A            A            A            A
# 11025310             F            A            A            A            B
# 11025352             D            C            B            B            B
# 11025620             H            A            A            B            B
# 11025638             F            A            A            A            A
# 11006773             H            A            A            A            A
# 11006846             F            A            A            A            A
# 11006854             F            A            A            A            A
#
#           TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040 TX_RESP_Q041  \
# ID_ESCOLA
# 11024682             D            A            C            E            E
# 11024828             E            A            E            I            B
# 11024968             D            C            E            I            C
# 11025310             C            A            F            J            C
# 11025352             C            A            E            I            C
# 11025620             D            A            A            H            D
# 11025638             D            A            E            B            C
# 11006773             D            D            D            B            C
# 11006846             D            A            D            I            C
# 11006854             C            B            E            B            B
#
#           TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045 TX_RESP_Q046  \
# ID_ESCOLA
# 11024682             D            A            C            C            C
# 11024828             D            B            C            C            D
# 11024968             C            B            C            B            C
# 11025310             C            B            C            C            D
# 11025352             E            B            C            C            D
# 11025620             D            B            D            D            D
# 11025638             C            B            C            C            D
# 11006773             D            B            C            C            C
# 11006846             D            B            C            D            D
# 11006854             D            B            C            C            C
#
#           TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050 TX_RESP_Q051  \
# ID_ESCOLA
# 11024682             C            C            B            C            C
# 11024828             D            D            A            B            A
# 11024968             A            C            A            B            B
# 11025310             D            D            B            B            C
# 11025352             D            D            B            B            B
# 11025620             C            D            B            B            B
# 11025638             C            C            B            B            B
# 11006773             C            C            B            C            B
# 11006846             D            D            B            B            B
# 11006854             D            B            B            B            B
#
#           TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055 TX_RESP_Q056  \
# ID_ESCOLA
# 11024682             C            C            A            A            B
# 11024828             B            C            B            A            B
# 11024968             D            B            B            B            B
# 11025310             D            B            B            D            A
# 11025352             B            B            D            B            B
# 11025620             D            C            B            B            B
# 11025638             B            B            B            A            B
# 11006773             C            B            D            A            D
# 11006846             B            B            B            B            C
# 11006854             C            C            D            B            D
#
#           TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060 TX_RESP_Q061  \
# ID_ESCOLA
# 11024682             C            A            A            A            A
# 11024828             A            A            A            A            A
# 11024968             C            C            A            A            A
# 11025310             A            A            C            A            A
# 11025352             B            A            A            A            A
# 11025620             C            B            A            A            A
# 11025638             B            A            A            A            B
# 11006773             B            B            A            B            B
# 11006846             B            C            A            B            A
# 11006854             B            C            A            B            A
#
#           TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065 TX_RESP_Q066  \
# ID_ESCOLA
# 11024682             C            C            D            D            D
# 11024828             C            C            C            C            C
# 11024968             C            C            D            D            C
# 11025310             D            D            D            C            C
# 11025352             D            C            D            C            D
# 11025620             C            C            D            E            E
# 11025638             C            C            D            C            C
# 11006773             D            C            E            C            B
# 11006846             C            C            D            D            D
# 11006854             C            D            D            B            D
#
#           TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070 TX_RESP_Q071  \
# ID_ESCOLA
# 11024682             A            A            A            A            A
# 11024828             B            B            D            A            A
# 11024968             B            D            C            A            B
# 11025310             A            B            A            A            A
# 11025352             C            A            D            A            A
# 11025620             C            A            A            A            B
# 11025638             B            C            D            D            C
# 11006773             B            B            B            C            A
# 11006846             B            A            C            B            A
# 11006854             B            B            A            A            B
#
#           TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074 TX_RESP_Q075 TX_RESP_Q076  \
# ID_ESCOLA
# 11024682             A            A            A            A            A
# 11024828             B            C            D            B            D
# 11024968             C            C            C            D            A
# 11025310             B            A            A            A            A
# 11025352             A            B            A            A            A
# 11025620             B            A            A            A            A
# 11025638             D            C            C            C            C
# 11006773             B            C            B            B            D
# 11006846             C            B            B            A            C
# 11006854             A            A            A            A            B
#
#           TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079 TX_RESP_Q080 TX_RESP_Q081  \
# ID_ESCOLA
# 11024682             B            A            A            A            A
# 11024828             B            B            A            A            A
# 11024968             A            A            A            A            A
# 11025310             A            A            A            A            A
# 11025352             A            A            A            A            A
# 11025620             B            A            A            A            A
# 11025638             A            A            A            A            A
# 11006773             B            A            A            A            A
# 11006846             B            A            A            A            A
# 11006854             B            A            A            A            A
#
#           TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084 TX_RESP_Q085 TX_RESP_Q086  \
# ID_ESCOLA
# 11024682             A            B            B            A            B
# 11024828             A            A            B            A            B
# 11024968             A            A            B            A            B
# 11025310             B            A            B            A            B
# 11025352             B            A            B            A            B
# 11025620             A            B            B            A            B
# 11025638             A            B            A            A            B
# 11006773             A            B            B            A            B
# 11006846             A            B            B            A            B
# 11006854             A            A            B            A            B
#
#           TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089 TX_RESP_Q090 TX_RESP_Q091  \
# ID_ESCOLA
# 11024682             A            A            A            B            A
# 11024828             A            A            A            A            A
# 11024968             B            A            B            A            A
# 11025310             A            B            A            B            A
# 11025352             A            A            A            B            A
# 11025620             A            A            A            B            A
# 11025638             A            B            A            A            A
# 11006773             A            A            B            A            A
# 11006846             A            A            A            A            A
# 11006854             A            A            A            B            A
#
#           TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094 TX_RESP_Q095 TX_RESP_Q096  \
# ID_ESCOLA
# 11024682             B            B            B            B            B
# 11024828             B            B            B            B            B
# 11024968             B            B            B            B            B
# 11025310             B            B            B            B            B
# 11025352             B            B            B            B            B
# 11025620           NaN            B            B            B            B
# 11025638             B            B            B            B            B
# 11006773             B            B            B            B            B
# 11006846             B            B            B            B            B
# 11006854             B            B            A            A            B
#
#           TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099 TX_RESP_Q100 TX_RESP_Q101  \
# ID_ESCOLA
# 11024682             B            A            B            B            A
# 11024828             B            B            B            B            B
# 11024968             B            B            B            A            A
# 11025310             B            B            B            B            A
# 11025352             B            B            B            B            B
# 11025620             B            B            B            A            A
# 11025638             B            B            B            A            A
# 11006773             B            A            B            A            A
# 11006846             B            B            B            A            A
# 11006854             B            B            B            A            A
#
#           TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104 TX_RESP_Q105 TX_RESP_Q106  \
# ID_ESCOLA
# 11024682             A            B            A            B            B
# 11024828             B            B            B            B            B
# 11024968             A            A            A            A            A
# 11025310             B            B            A            A            B
# 11025352             B            B            B            B            B
# 11025620             A            A            A            A            A
# 11025638             A            A            A            A            A
# 11006773             A            A            A            A            A
# 11006846             A            A            A            A            A
# 11006854             B            B            A            A            B
#
#           TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109 TX_RESP_Q110 TX_RESP_Q111
# ID_ESCOLA
# 11024682             B            A            C            C            C
# 11024828             A            A            C            C            C
# 11024968             A            A            C            C            C
# 11025310             B            A            B            C            C
# 11025352             B            A            B            C            C
# 11025620             A            A            C            C            C
# 11025638             A            A            A            A            A
# 11006773             A            A            C            C            C
# 11006846             A            A            B            C            C
# 11006854             B            A            B            C            C

# %% [markdown]
# Mantém apenas escolas com questionário preenchido e remove colunas que não correnspodem ao questionário.

# %%
df_diretor = df_diretor[df_diretor.IN_PREENCHIMENTO_QUESTIONARIO==1]
df_diretor.drop(columns=['ID_UF', 'ID_MUNICIPIO', 'ID_DEPENDENCIA_ADM', 'ID_LOCALIZACAO', 'IN_PREENCHIMENTO_QUESTIONARIO', 'ID_PROVA_BRASIL'], inplace=True)
print(df_diretor.shape)
# Out:
# (56737, 111)

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_diretor.head(10))
# Out:
#           TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004 TX_RESP_Q005  \
# ID_ESCOLA
# 11024682             B            C            A            D            C
# 11024828             B            E            A            D            D
# 11024968             B            E            B            G            C
# 11025310             B            C            B            D            B
# 11025352             B            C            A            F            C
# 11025620             B            D            A            G            C
# 11025638             B            D            A            G            C
# 11006773             B            D            B            H            E
# 11006846             B            D            B            D            D
# 11006854             A            C            B            H            C
#
#           TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010  \
# ID_ESCOLA
# 11024682             B            B            C            E            G
# 11024828             B            D            C            F            D
# 11024968             C            B            C            C            H
# 11025310             B            D            C            E            G
# 11025352             C            B            C            D            F
# 11025620             C            B            A            A            G
# 11025638             C            B            A            A            I
# 11006773             D            B            C            E            F
# 11006846             B            B            C            E            I
# 11006854             C            B            C            E            I
#
#           TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015  \
# ID_ESCOLA
# 11024682             C          NaN            A            B            D
# 11024828             C            D            B            C            H
# 11024968             C            I            B            B            H
# 11025310             C            G            B            C            F
# 11025352             C          NaN            B            C            F
# 11025620             C            G            B            B            F
# 11025638             C            I            B            B            H
# 11006773             C            E            B            B            F
# 11006846             C            I            B            B            H
# 11006854             C            I            A            B            E
#
#           TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020  \
# ID_ESCOLA
# 11024682             C            C            D            B            E
# 11024828             A            A            G            B            E
# 11024968             B            B            G            A            A
# 11025310             A            A            E            B            D
# 11025352             A            A            E            B            D
# 11025620             C            C            F            B            E
# 11025638             C            B            G            B            A
# 11006773             E            C            G            B            E
# 11006846             B            B            G            B            D
# 11006854             C            B            F            B            C
#
#           TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025  \
# ID_ESCOLA
# 11024682             A            C            C            C            B
# 11024828             B            B            B            B            B
# 11024968             B            B            C            C            B
# 11025310             A            B            B            B            C
# 11025352             B            B            B            B            C
# 11025620             B            C            B            B            B
# 11025638             B            B            B            B            C
# 11006773             B            C            C            C            B
# 11006846             B            C            C            B            C
# 11006854             B            C            C            C            C
#
#           TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030  \
# ID_ESCOLA
# 11024682             B            E            D            E            C
# 11024828             A            E            B            A            A
# 11024968             A            A            A            E            B
# 11025310             A            A            D            D            B
# 11025352             A            A            C            A            A
# 11025620             B            E            E            E            B
# 11025638             A          NaN            D            E            B
# 11006773             B            E            E            E            B
# 11006846             A            E            E            D            C
# 11006854             A            A            D            E            B
#
#           TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035  \
# ID_ESCOLA
# 11024682             D            H            A            A            A
# 11024828             D            C            A            A            A
# 11024968             E            F            A            A            A
# 11025310             E            F            A            A            A
# 11025352             E            D            C            B            B
# 11025620             E            H            A            A            B
# 11025638             E            F            A            A            A
# 11006773             E            H            A            A            A
# 11006846             E            F            A            A            A
# 11006854             E            F            A            A            A
#
#           TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040  \
# ID_ESCOLA
# 11024682             A            D            A            C            E
# 11024828             A            E            A            E            I
# 11024968             A            D            C            E            I
# 11025310             B            C            A            F            J
# 11025352             B            C            A            E            I
# 11025620             B            D            A            A            H
# 11025638             A            D            A            E            B
# 11006773             A            D            D            D            B
# 11006846             A            D            A            D            I
# 11006854             A            C            B            E            B
#
#           TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045  \
# ID_ESCOLA
# 11024682             E            D            A            C            C
# 11024828             B            D            B            C            C
# 11024968             C            C            B            C            B
# 11025310             C            C            B            C            C
# 11025352             C            E            B            C            C
# 11025620             D            D            B            D            D
# 11025638             C            C            B            C            C
# 11006773             C            D            B            C            C
# 11006846             C            D            B            C            D
# 11006854             B            D            B            C            C
#
#           TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050  \
# ID_ESCOLA
# 11024682             C            C            C            B            C
# 11024828             D            D            D            A            B
# 11024968             C            A            C            A            B
# 11025310             D            D            D            B            B
# 11025352             D            D            D            B            B
# 11025620             D            C            D            B            B
# 11025638             D            C            C            B            B
# 11006773             C            C            C            B            C
# 11006846             D            D            D            B            B
# 11006854             C            D            B            B            B
#
#           TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055  \
# ID_ESCOLA
# 11024682             C            C            C            A            A
# 11024828             A            B            C            B            A
# 11024968             B            D            B            B            B
# 11025310             C            D            B            B            D
# 11025352             B            B            B            D            B
# 11025620             B            D            C            B            B
# 11025638             B            B            B            B            A
# 11006773             B            C            B            D            A
# 11006846             B            B            B            B            B
# 11006854             B            C            C            D            B
#
#           TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060  \
# ID_ESCOLA
# 11024682             B            C            A            A            A
# 11024828             B            A            A            A            A
# 11024968             B            C            C            A            A
# 11025310             A            A            A            C            A
# 11025352             B            B            A            A            A
# 11025620             B            C            B            A            A
# 11025638             B            B            A            A            A
# 11006773             D            B            B            A            B
# 11006846             C            B            C            A            B
# 11006854             D            B            C            A            B
#
#           TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065  \
# ID_ESCOLA
# 11024682             A            C            C            D            D
# 11024828             A            C            C            C            C
# 11024968             A            C            C            D            D
# 11025310             A            D            D            D            C
# 11025352             A            D            C            D            C
# 11025620             A            C            C            D            E
# 11025638             B            C            C            D            C
# 11006773             B            D            C            E            C
# 11006846             A            C            C            D            D
# 11006854             A            C            D            D            B
#
#           TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070  \
# ID_ESCOLA
# 11024682             D            A            A            A            A
# 11024828             C            B            B            D            A
# 11024968             C            B            D            C            A
# 11025310             C            A            B            A            A
# 11025352             D            C            A            D            A
# 11025620             E            C            A            A            A
# 11025638             C            B            C            D            D
# 11006773             B            B            B            B            C
# 11006846             D            B            A            C            B
# 11006854             D            B            B            A            A
#
#           TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074 TX_RESP_Q075  \
# ID_ESCOLA
# 11024682             A            A            A            A            A
# 11024828             A            B            C            D            B
# 11024968             B            C            C            C            D
# 11025310             A            B            A            A            A
# 11025352             A            A            B            A            A
# 11025620             B            B            A            A            A
# 11025638             C            D            C            C            C
# 11006773             A            B            C            B            B
# 11006846             A            C            B            B            A
# 11006854             B            A            A            A            A
#
#           TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079 TX_RESP_Q080  \
# ID_ESCOLA
# 11024682             A            B            A            A            A
# 11024828             D            B            B            A            A
# 11024968             A            A            A            A            A
# 11025310             A            A            A            A            A
# 11025352             A            A            A            A            A
# 11025620             A            B            A            A            A
# 11025638             C            A            A            A            A
# 11006773             D            B            A            A            A
# 11006846             C            B            A            A            A
# 11006854             B            B            A            A            A
#
#           TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084 TX_RESP_Q085  \
# ID_ESCOLA
# 11024682             A            A            B            B            A
# 11024828             A            A            A            B            A
# 11024968             A            A            A            B            A
# 11025310             A            B            A            B            A
# 11025352             A            B            A            B            A
# 11025620             A            A            B            B            A
# 11025638             A            A            B            A            A
# 11006773             A            A            B            B            A
# 11006846             A            A            B            B            A
# 11006854             A            A            A            B            A
#
#           TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089 TX_RESP_Q090  \
# ID_ESCOLA
# 11024682             B            A            A            A            B
# 11024828             B            A            A            A            A
# 11024968             B            B            A            B            A
# 11025310             B            A            B            A            B
# 11025352             B            A            A            A            B
# 11025620             B            A            A            A            B
# 11025638             B            A            B            A            A
# 11006773             B            A            A            B            A
# 11006846             B            A            A            A            A
# 11006854             B            A            A            A            B
#
#           TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094 TX_RESP_Q095  \
# ID_ESCOLA
# 11024682             A            B            B            B            B
# 11024828             A            B            B            B            B
# 11024968             A            B            B            B            B
# 11025310             A            B            B            B            B
# 11025352             A            B            B            B            B
# 11025620             A          NaN            B            B            B
# 11025638             A            B            B            B            B
# 11006773             A            B            B            B            B
# 11006846             A            B            B            B            B
# 11006854             A            B            B            A            A
#
#           TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099 TX_RESP_Q100  \
# ID_ESCOLA
# 11024682             B            B            A            B            B
# 11024828             B            B            B            B            B
# 11024968             B            B            B            B            A
# 11025310             B            B            B            B            B
# 11025352             B            B            B            B            B
# 11025620             B            B            B            B            A
# 11025638             B            B            B            B            A
# 11006773             B            B            A            B            A
# 11006846             B            B            B            B            A
# 11006854             B            B            B            B            A
#
#           TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104 TX_RESP_Q105  \
# ID_ESCOLA
# 11024682             A            A            B            A            B
# 11024828             B            B            B            B            B
# 11024968             A            A            A            A            A
# 11025310             A            B            B            A            A
# 11025352             B            B            B            B            B
# 11025620             A            A            A            A            A
# 11025638             A            A            A            A            A
# 11006773             A            A            A            A            A
# 11006846             A            A            A            A            A
# 11006854             A            B            B            A            A
#
#           TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109 TX_RESP_Q110  \
# ID_ESCOLA
# 11024682             B            B            A            C            C
# 11024828             B            A            A            C            C
# 11024968             A            A            A            C            C
# 11025310             B            B            A            B            C
# 11025352             B            B            A            B            C
# 11025620             A            A            A            C            C
# 11025638             A            A            A            A            A
# 11006773             A            A            A            C            C
# 11006846             A            A            A            B            C
# 11006854             B            B            A            B            C
#
#           TX_RESP_Q111
# ID_ESCOLA
# 11024682             C
# 11024828             C
# 11024968             C
# 11025310             C
# 11025352             C
# 11025620             C
# 11025638             A
# 11006773             C
# 11006846             C
# 11006854             C

# %% [markdown]
# Renomeia colunas para identificá-las como pertencentes ao questionário do Diretor.

# %%
df_diretor.columns = ['DIRETOR_' + x for i, x in enumerate(df_diretor.columns, 1)]
df_diretor.head(3)
# Out:
#           DIRETOR_TX_RESP_Q001 DIRETOR_TX_RESP_Q002 DIRETOR_TX_RESP_Q003  \
# ID_ESCOLA
# 11024682                     B                    C                    A
# 11024828                     B                    E                    A
# 11024968                     B                    E                    B
#
#           DIRETOR_TX_RESP_Q004 DIRETOR_TX_RESP_Q005 DIRETOR_TX_RESP_Q006  \
# ID_ESCOLA
# 11024682                     D                    C                    B
# 11024828                     D                    D                    B
# 11024968                     G                    C                    C
#
#           DIRETOR_TX_RESP_Q007 DIRETOR_TX_RESP_Q008 DIRETOR_TX_RESP_Q009  \
# ID_ESCOLA
# 11024682                     B                    C                    E
# 11024828                     D                    C                    F
# 11024968                     B                    C                    C
#
#           DIRETOR_TX_RESP_Q010  ... DIRETOR_TX_RESP_Q102 DIRETOR_TX_RESP_Q103  \
# ID_ESCOLA                       ...
# 11024682                     G  ...                    A                    B
# 11024828                     D  ...                    B                    B
# 11024968                     H  ...                    A                    A
#
#           DIRETOR_TX_RESP_Q104 DIRETOR_TX_RESP_Q105 DIRETOR_TX_RESP_Q106  \
# ID_ESCOLA
# 11024682                     A                    B                    B
# 11024828                     B                    B                    B
# 11024968                     A                    A                    A
#
#           DIRETOR_TX_RESP_Q107 DIRETOR_TX_RESP_Q108 DIRETOR_TX_RESP_Q109  \
# ID_ESCOLA
# 11024682                     B                    A                    C
# 11024828                     A                    A                    C
# 11024968                     A                    A                    C
#
#           DIRETOR_TX_RESP_Q110 DIRETOR_TX_RESP_Q111
# ID_ESCOLA
# 11024682                     C                    C
# 11024828                     C                    C
# 11024968                     C                    C
#
# [3 rows x 111 columns]

# %% [markdown]
# #### Base questionário Professor

# %%
#professor
df_prof = pd.read_csv('gs://bucket-tcc-fia-mba/SAEB/2013/TS_PROFESSOR_2013.csv', sep=',', encoding='utf-8')
print(df_prof.shape)
# Out:
# (237186, 134)

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof.head(10))
# Out:
#    ID_PROVA_BRASIL  ID_UF  ID_MUNICIPIO  ID_ESCOLA  ID_DEPENDENCIA_ADM  \
# 0             2013     11       1100015   11024682                   2
# 1             2013     11       1100015   11025638                   2
# 2             2013     11       1100015   11025620                   2
# 3             2013     11       1100015   11024666                   3
# 4             2013     11       1100015   11025620                   2
# 5             2013     11       1100015   11025638                   2
# 6             2013     11       1100015   11025352                   3
# 7             2013     11       1100015   11024682                   2
# 8             2013     11       1100015   11024828                   3
# 9             2013     11       1100015   11024968                   2
#
#    ID_LOCALIZACAO  ID_TURMA  ID_SERIE  IN_PREENCHIMENTO_QUESTIONARIO  \
# 0               1    369734         5                              1
# 1               1    369768        12                              1
# 2               1    369760         9                              1
# 3               2    369733         9                              1
# 4               1    369760         9                              1
# 5               1    369763         5                              1
# 6               2    369752         9                              1
# 7               1    369735         5                              1
# 8               2    369742         9                              1
# 9               1    369745         5                              1
#
#   TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004 TX_RESP_Q005  \
# 0            A            D            A            D            C
# 1            B            C            B            G            C
# 2            B            B            B            G            B
# 3            B            C            B            G            C
# 4          NaN            D            A            F            C
# 5            B            B            A            D            B
# 6            B            E            B            G            E
# 7            B            D            A            D            E
# 8            A            D            B            D            B
# 9            B            D            A            D            C
#
#   TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010  \
# 0            C            B            C            E            G
# 1            D            B            C            E            H
# 2            B            B            A            A            E
# 3            B            B            C            C            F
# 4            C            B            C            D            F
# 5            C            B            C            E            D
# 6            D            B            C            E            G
# 7            C            B            C            E            G
# 8            B            D            C            C            E
# 9            C            B            A            A            E
#
#   TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015  \
# 0            C            G            G            F            E
# 1            B            I            F            F            D
# 2            C            E            C            C            C
# 3            B          NaN            D            B            D
# 4            C            F            F            E            C
# 5            C            D            C            C            B
# 6            A            I            G            E            G
# 7            C            G            F            F            F
# 8            C            E            F            F            D
# 9            C            E            D            D            C
#
#   TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020  \
# 0            A            B            A            B            C
# 1            A            A            C            A            B
# 2            A            B            A            B            B
# 3            B            C            D            A            A
# 4            A            B            A            A            B
# 5            A            C            A            C            A
# 6            A            C            B            A            B
# 7            A            B            A            B            B
# 8            A            B            A            B            B
# 9            A            B            A            B            D
#
#   TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025  \
# 0            D            C            C            C            A
# 1            A            C            A            D            A
# 2            B            B            A            A            A
# 3            C            A            C            A          NaN
# 4            B            B            B            A            A
# 5            A            A            E            A            B
# 6            D            D            A            D            A
# 7            C            D            A            A            A
# 8            A            A            A            B            A
# 9            A            A            A            A            A
#
#   TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030  \
# 0            B            B            C            C            B
# 1            C            C            C            C            C
# 2            B            C            C            B            B
# 3            D            D            D            D            D
# 4            C            B            C            B            C
# 5            A            B            B            B            C
# 6            C            C            C            B            C
# 7            C            C            C            B            B
# 8            C            D            C            A            C
# 9            A            A            C            A            B
#
#   TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035  \
# 0            C            C            B            B            C
# 1            D            D            B            B            B
# 2            C            C            B            B            B
# 3            D            D            B            C            C
# 4            D            D            B            B            B
# 5            D            D            B            C            B
# 6            D            D            B            B            C
# 7            C            D            B            B            C
# 8            D            C            B            B            C
# 9            B            D            B            C            C
#
#   TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040  \
# 0            C            C            B            C            C
# 1            B            C            C            C            C
# 2            B            C            B            C            B
# 3            C            C            B            B            B
# 4            B            C            A            A            B
# 5            B            C            B            B            A
# 6            C            C            C            C            C
# 7            C            C            B            C            C
# 8            C            B            B            C            C
# 9            C            C            C            C            C
#
#   TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045  \
# 0            C            A            A            C            D
# 1            A            A            B            D            D
# 2            B            B            B            C            D
# 3            B            B            B          NaN          NaN
# 4            A            A            A            A            B
# 5            A            A            A            C            C
# 6            B            A            B            C            D
# 7            C            A            A            C            D
# 8            B            A            B            C            C
# 9            B            A            A            C            D
#
#   TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050  \
# 0            C            C            C            D            C
# 1            D            C            D            A            D
# 2            D            D            D            D            D
# 3            A            B            C            A            A
# 4            C            B            C            C            C
# 5            C            C            D            A            A
# 6            C            C            D            D            D
# 7            C            C            C            C            C
# 8            C            D            D            C            C
# 9            C            C            C            B            C
#
#   TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055  \
# 0            D            E            C            E            D
# 1            F            E            B            D            D
# 2            F            E            B            A            E
# 3          NaN            E            A            A            D
# 4            F            E            B            A            B
# 5            C            E            B            E            C
# 6            F            E            C            D            C
# 7            F            E            B            E            D
# 8          NaN            D            C            B            D
# 9            E            D            B            E            D
#
#   TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060  \
# 0            C            B            B            C            C
# 1            D            B            C            D            C
# 2            D            C            C            C            C
# 3            D            D            C            B            C
# 4            D            C            D            D            C
# 5            C            C            B            C            A
# 6            D            D            C            C            B
# 7            D            C            B            C            B
# 8            D            C            D            C            C
# 9            E            E            B            B            B
#
#   TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065  \
# 0            C            C            C            C            B
# 1            D            B            C            B            B
# 2            C            C            C            C            C
# 3            C            C            C            C            C
# 4            C            D            D            B            C
# 5            B            B            C            B            A
# 6            C            C            C            C            D
# 7            C            C            C            B            B
# 8            C            C            C            B            B
# 9            B            C            C            A            A
#
#   TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070  \
# 0            C            C            C            C            B
# 1            D            D            D            D            A
# 2            C            C            C            C            B
# 3            D            D            D            D            A
# 4            D            D            C            D            B
# 5            B            C            B            B            A
# 6            D            D            C            C            A
# 7            D            B            C            B            B
# 8            C            B            C            B            B
# 9            D            B            B            B            B
#
#   TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074 TX_RESP_Q075  \
# 0            A            B            A            A            B
# 1            B            A            A            A            B
# 2            B            B            B            B            B
# 3            B            B            B            A            B
# 4            B            A            B            A            A
# 5            A            B            B            B            B
# 6            B            B            A            A            A
# 7            B            B          NaN            A            A
# 8            B            A            A            B            A
# 9            B            B            B            B            B
#
#   TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079 TX_RESP_Q080  \
# 0            A            A            A            A            A
# 1            B            A            A            A            A
# 2            B            B            B            B          NaN
# 3            A            A            A            A            A
# 4            A            A            A            A            A
# 5            A            A            A            A            A
# 6            A            A            A            A            A
# 7            A            A            A            A            A
# 8            A            A            A            A            A
# 9            A            A            A            B            A
#
#   TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084 TX_RESP_Q085  \
# 0            B            B            B            A            B
# 1            B            B            B            B            B
# 2            B            B            B            B            B
# 3            A            A            B            B            B
# 4            A            B            B            A            B
# 5            A            B            A            A            B
# 6            A            A            A            A            A
# 7            A            B            A            A            B
# 8            A            B            A            A            B
# 9            A            B            A            A            B
#
#   TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089 TX_RESP_Q090  \
# 0            B            B            B            B            B
# 1            B            A            B            B            B
# 2            B            B            B            B            B
# 3            B            B            B            B            B
# 4            B            B            B            B            B
# 5            B            B            B            B            B
# 6            A            A            A            A            A
# 7            B            B            B            B            B
# 8            B            B            B            B            B
# 9            B            B            B            B            B
#
#   TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094 TX_RESP_Q095  \
# 0            B            B            D            D            C
# 1            B            B            D          NaN            D
# 2            B            B          NaN            D            D
# 3            B            B          NaN          NaN            D
# 4            B            B          NaN            D            C
# 5            B            B            D            C            D
# 6            A            A            D            D            D
# 7            B            B            D            D            C
# 8            A            B            D            D            D
# 9            B            B            D            D            D
#
#   TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099 TX_RESP_Q100  \
# 0            B            A            B            E            A
# 1            D            A            A            E            A
# 2            B            B            A            E            A
# 3            C            A            B            E            A
# 4            B            A            A            E            A
# 5            C            B            A            E            A
# 6            C            A            A            E            A
# 7            A            A            A            E            A
# 8            D            A            B            E            A
# 9            A            A            B            A            B
#
#   TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104 TX_RESP_Q105  \
# 0            D            A            B            E            C
# 1            D            A            A            F            A
# 2            D            A            A            F            A
# 3            D            A            A            F            A
# 4            D            A            D            F            B
# 5            D            A            B            F            B
# 6            D            A            F            F            A
# 7            D            A            A            B            C
# 8            C            A            E            F            A
# 9            A            A            A            F            C
#
#   TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109 TX_RESP_Q110  \
# 0            E            E            F            E            D
# 1            E            F            F            E            C
# 2            D            F            F            E            D
# 3            D            E            E            D            D
# 4            E            F            F            D            B
# 5            E            E            F            D            C
# 6            E            E            E            E            D
# 7            D            E            E            E            C
# 8            D            E            F            D            B
# 9            E            F            F            E            B
#
#   TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114 TX_RESP_Q115  \
# 0            F            F            F            D            D
# 1            F            F            C            D            E
# 2            F            E            E            E            E
# 3            E            E            E            C            D
# 4            A            A            D          NaN          NaN
# 5            F            E            C            E            E
# 6            D            D            D            D            D
# 7            E            F            E            E            E
# 8            E            E            B            C            C
# 9            E            F            F            F            F
#
#   TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119 TX_RESP_Q120  \
# 0            E            E            D            E            D
# 1            F            F            F            F          NaN
# 2            D            E            E            E          NaN
# 3            E            D            B            F          NaN
# 4          NaN          NaN          NaN          NaN            F
# 5            E            E            E            E            E
# 6            E            E            D            E          NaN
# 7            F            E            D            E            E
# 8            E            F            E            D          NaN
# 9            E            E            E            E            D
#
#   TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124 TX_RESP_Q125
# 0            F            F            E            F            D
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4            F            E            D            F            D
# 5            E            E            E            E            D
# 6          NaN          NaN          NaN          NaN          NaN
# 7            E            F            E            A            E
# 8          NaN          NaN          NaN          NaN          NaN
# 9            D            E            E            E            E

# %% [markdown]
# Mantém apenas professores que lecionam na nona série e que tenham preenchido o questionário.

# %%
df_prof = df_prof[(df_prof.IN_PREENCHIMENTO_QUESTIONARIO==1) & (df_prof.ID_SERIE==9)]
df_prof.drop(columns=['ID_UF', 'ID_MUNICIPIO', 'ID_DEPENDENCIA_ADM', 'ID_LOCALIZACAO', 'ID_TURMA', 'ID_SERIE', 'IN_PREENCHIMENTO_QUESTIONARIO', 'ID_PROVA_BRASIL'], inplace=True)
print(df_prof.shape)

#filtrar qm tem IN_PREENCHIMENTO_QUESTIONARIO = 1 e ID_SERIE = 9
# Out:
# (121310, 126)

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof.head(10))
# Out:
#     ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 2    11025620            B            B            B            G
# 3    11024666            B            C            B            G
# 4    11025620          NaN            D            A            F
# 6    11025352            B            E            B            G
# 8    11024828            A            D            B            D
# 10   11024828            B            D            B            F
# 11   11024682            B            A            B            G
# 12   11025638            B            C            B            G
# 14   11025638            A            C            B            F
# 16   11025310            B            C            B            G
#
#    TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  \
# 2             B            B            B            A            A
# 3             C            B            B            C            C
# 4             C            C            B            C            D
# 6             E            D            B            C            E
# 8             B            B            D            C            C
# 10            C            B            D            C            E
# 11            B            B            D            A            A
# 12            C            C            B            C            E
# 14            C            C            B            A            A
# 16            B            B            B            C            C
#
#    TX_RESP_Q010 TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014  \
# 2             E            C            E            C            C
# 3             F            B          NaN            D            B
# 4             F            C            F            F            E
# 6             G            A            I            G            E
# 8             E            C            E            F            F
# 10            B            C            D            E            D
# 11            F            C            F            A            A
# 12            E            C            E            D            D
# 14            G            C            G            F            F
# 16            C            C            D            C            A
#
#    TX_RESP_Q015 TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019  \
# 2             C            A            B            A            B
# 3             D            B            C            D            A
# 4             C            A            B            A            A
# 6             G            A            C            B            A
# 8             D            A            B            A            B
# 10            D            A            C            A            C
# 11            A            A            B            A            B
# 12            D            A            B            A            B
# 14            E            A            A            A            B
# 16            B            C            C            B            B
#
#    TX_RESP_Q020 TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024  \
# 2             B            B            B            A            A
# 3             A            C            A            C            A
# 4             B            B            B            B            A
# 6             B            D            D            A            D
# 8             B            A            A            A            B
# 10            B            B            B            B            B
# 11            B            D            D            D            D
# 12            B            A            D            C            A
# 14            C            C            C            A            A
# 16            C            E            E            E            E
#
#    TX_RESP_Q025 TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029  \
# 2             A            B            C            C            B
# 3           NaN            D            D            D            D
# 4             A            C            B            C            B
# 6             A            C            C            C            B
# 8             A            C            D            C            A
# 10            B            C            D            C            B
# 11            A            C            B            B            B
# 12            A            B            B            A            A
# 14            A            C            B            B            B
# 16            B            A            A            A            A
#
#    TX_RESP_Q030 TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034  \
# 2             B            C            C            B            B
# 3             D            D            D            B            C
# 4             C            D            D            B            B
# 6             C            D            D            B            B
# 8             C            D            C            B            B
# 10            A            B            D            B            B
# 11            A            B            D            B            B
# 12            B            D            D            B            C
# 14            C            C            D            B            B
# 16            A            C            D            B            C
#
#    TX_RESP_Q035 TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039  \
# 2             B            B            C            B            C
# 3             C            C            C            B            B
# 4             B            B            C            A            A
# 6             C            C            C            C            C
# 8             C            C            B            B            C
# 10            B            B            B            B            B
# 11            C            C            C            B            B
# 12            C            B            B            B            C
# 14            B            B            B            B            B
# 16            B            B            C            B            C
#
#    TX_RESP_Q040 TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044  \
# 2             B            B            B            B            C
# 3             B            B            B            B          NaN
# 4             B            A            A            A            A
# 6             C            B            A            B            C
# 8             C            B            A            B            C
# 10            C            A            A            A            C
# 11            C            B            A            A            C
# 12            B            C            B            A            C
# 14            C            B            A            A            C
# 16            B            C            A            B            D
#
#    TX_RESP_Q045 TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049  \
# 2             D            D            D            D            D
# 3           NaN            A            B            C            A
# 4             B            C            B            C            C
# 6             D            C            C            D            D
# 8             C            C            D            D            C
# 10            C            C            B            D            D
# 11            C            C            C            D            B
# 12            D            C            C            D            B
# 14            C            C            B            C            C
# 16            D            A            C            C            A
#
#    TX_RESP_Q050 TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054  \
# 2             D            F            E            B            A
# 3             A          NaN            E            A            A
# 4             C            F            E            B            A
# 6             D            F            E            C            D
# 8             C          NaN            D            C            B
# 10            D            C            C            B            A
# 11            C            F            E            A            C
# 12            B            F            E            B            E
# 14            B            F            E            B            C
# 16            A            F            E            B            C
#
#    TX_RESP_Q055 TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059  \
# 2             E            D            C            C            C
# 3             D            D            D            C            B
# 4             B            D            C            D            D
# 6             C            D            D            C            C
# 8             D            D            C            D            C
# 10            A            C            B            B            B
# 11            C            C            C            C            C
# 12            D            D            D            C            C
# 14            B            C            B            B          NaN
# 16            C            C            C            C            C
#
#    TX_RESP_Q060 TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064  \
# 2             C            C            C            C            C
# 3             C            C            C            C            C
# 4             C            C            D            D            B
# 6             B            C            C            C            C
# 8             C            C            C            C            B
# 10            B            C            C            C            A
# 11            D            D            D            C            C
# 12            B            C            D            D            B
# 14            D            D            D            D            B
# 16            C            C            C            C            C
#
#    TX_RESP_Q065 TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069  \
# 2             C            C            C            C            C
# 3             C            D            D            D            D
# 4             C            D            D            C            D
# 6             D            D            D            C            C
# 8             B            C            B            C            B
# 10            B            D            B            C            C
# 11            C            D            C            D            B
# 12            C            D            D            C            C
# 14            B            D            D            D            D
# 16            C            C            C            C            C
#
#    TX_RESP_Q070 TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074  \
# 2             B            B            B            B            B
# 3             A            B            B            B            A
# 4             B            B            A            B            A
# 6             A            B            B            A            A
# 8             B            B            A            A            B
# 10            A            B            B            A            A
# 11            A            B            A            B            A
# 12            B            B            A            B            A
# 14            B            B            A            B            B
# 16            B            B            B            B            B
#
#    TX_RESP_Q075 TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079  \
# 2             B            B            B            B            B
# 3             B            A            A            A            A
# 4             A            A            A            A            A
# 6             A            A            A            A            A
# 8             A            A            A            A            A
# 10            A            A            A            A            A
# 11            A            A            A            A            A
# 12            A            A            A            A            A
# 14            A            B            B            A            A
# 16            B            A            A            A            A
#
#    TX_RESP_Q080 TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084  \
# 2           NaN            B            B            B            B
# 3             A            A            A            B            B
# 4             A            A            B            B            A
# 6             A            A            A            A            A
# 8             A            A            B            A            A
# 10            A            A            B            B          NaN
# 11            A            A            A            B            A
# 12            A            A            A            B            A
# 14            A            B            B            A            A
# 16            A            A            B            B            A
#
#    TX_RESP_Q085 TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089  \
# 2             B            B            B            B            B
# 3             B            B            B            B            B
# 4             B            B            B            B            B
# 6             A            A            A            A            A
# 8             B            B            B            B            B
# 10            B            B            B            B            B
# 11            B            B            B            B            B
# 12            B            B            B            B            B
# 14            B            B            B            B            B
# 16            B            B            B            B            B
#
#    TX_RESP_Q090 TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094  \
# 2             B            B            B          NaN            D
# 3             B            B            B          NaN          NaN
# 4             B            B            B          NaN            D
# 6             A            A            A            D            D
# 8             B            A            B            D            D
# 10            B            B            B            D            D
# 11            B            B            B          NaN            D
# 12            B            B            B          NaN            D
# 14            B            B            B          NaN            B
# 16            B            B            B            D            D
#
#    TX_RESP_Q095 TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099  \
# 2             D            B            B            A            E
# 3             D            C            A            B            E
# 4             C            B            A            A            E
# 6             D            C            A            A            E
# 8             D            D            A            B            E
# 10            D            B            A            A            E
# 11            D            D            B            A            E
# 12            D            C            A            A            E
# 14            B            A            A            A            E
# 16            D            D            A            C            E
#
#    TX_RESP_Q100 TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104  \
# 2             A            D            A            A            F
# 3             A            D            A            A            F
# 4             A            D            A            D            F
# 6             A            D            A            F            F
# 8             A            C            A            E            F
# 10            A            D            A            E            E
# 11            A            C            A            B            E
# 12            A            D            A            A            F
# 14            A            D            A            A            F
# 16            A            D            A            A            D
#
#    TX_RESP_Q105 TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109  \
# 2             A            D            F            F            E
# 3             A            D            E            E            D
# 4             B            E            F            F            D
# 6             A            E            E            E            E
# 8             A            D            E            F            D
# 10            B            D            E            F            F
# 11            C            D            E            E            E
# 12            A            E            B            B            E
# 14            B            E            F            F            E
# 16            A            E            E            E            E
#
#    TX_RESP_Q110 TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114  \
# 2             D            F            E            E            E
# 3             D            E            E            E            C
# 4             B            A            A            D          NaN
# 6             D            D            D            D            D
# 8             B            E            E            B            C
# 10            D            F            F            F            F
# 11            E            F            E            E            D
# 12            C            A            F            F            D
# 14            D            F            E            F          NaN
# 16            B            E            E            E            E
#
#    TX_RESP_Q115 TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119  \
# 2             E            D            E            E            E
# 3             D            E            D            B            F
# 4           NaN          NaN          NaN          NaN          NaN
# 6             D            E            E            D            E
# 8             C            E            F            E            D
# 10            F            F            F            F            F
# 11            E            E            E            D            F
# 12            D            E            D            C            C
# 14          NaN          NaN          NaN          NaN          NaN
# 16            E            E            E            E            E
#
#    TX_RESP_Q120 TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124  \
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4             F            F            E            D            F
# 6           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 14            F            F            F            D            F
# 16          NaN          NaN          NaN          NaN          NaN
#
#    TX_RESP_Q125
# 2           NaN
# 3           NaN
# 4             D
# 6           NaN
# 8           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 14            D
# 16          NaN

# %% [markdown]
# Como o objetivo é avaliar a aprendizagem das matérias de lingua portuguesa e matemática, selecionarei apenas os questionários respondidos pelos professores dessas máterias.

# %%
df_prof.groupby('TX_RESP_Q105')['TX_RESP_Q105'].count()
# Out:
# TX_RESP_Q105
# A    54039
# B    54642
# C     7303
# Name: TX_RESP_Q105, dtype: int64

# %% [markdown]
# A = Língua Portuguesa
#
# B = Matemática
#
# C = Mais de uma disciplina.

# %% [markdown]
# Separa base de questionários respondidos por professores de lingua portuguesa.

# %%
df_prof_lp = df_prof[(df_prof.TX_RESP_Q105=='A')]
display(df_prof_lp.shape)
display(df_prof_lp.head())
# Out:
# (54039, 126)
#     ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 2    11025620            B            B            B            G
# 3    11024666            B            C            B            G
# 6    11025352            B            E            B            G
# 8    11024828            A            D            B            D
# 12   11025638            B            C            B            G
#
#    TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  ...  \
# 2             B            B            B            A            A  ...
# 3             C            B            B            C            C  ...
# 6             E            D            B            C            E  ...
# 8             B            B            D            C            C  ...
# 12            C            C            B            C            E  ...
#
#    TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119 TX_RESP_Q120  \
# 2             D            E            E            E          NaN
# 3             E            D            B            F          NaN
# 6             E            E            D            E          NaN
# 8             E            F            E            D          NaN
# 12            E            D            C            C          NaN
#
#    TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124 TX_RESP_Q125
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 126 columns]

# %% [markdown]
# Separa base de questionários respondidos por professores de matemática.

# %%
df_prof_mt = df_prof[(df_prof.TX_RESP_Q105=='B')]
display(df_prof_mt.shape)
display(df_prof_mt.head())
# Out:
# (54642, 126)
#     ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 4    11025620          NaN            D            A            F
# 10   11024828            B            D            B            F
# 14   11025638            A            C            B            F
# 17   11025310            A            D            B            F
# 18   11024968            B            C            A            F
#
#    TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  ...  \
# 4             C            C            B            C            D  ...
# 10            C            B            D            C            E  ...
# 14            C            C            B            A            A  ...
# 17            B            B            D            C            D  ...
# 18            C            C            C            A            A  ...
#
#    TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119 TX_RESP_Q120  \
# 4           NaN          NaN          NaN          NaN            F
# 10            F            F            F            F          NaN
# 14          NaN          NaN          NaN          NaN            F
# 17          NaN          NaN          NaN          NaN            E
# 18            A            A            A          NaN            E
#
#    TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124 TX_RESP_Q125
# 4             F            E            D            F            D
# 10          NaN          NaN          NaN          NaN          NaN
# 14            F            F            D            F            D
# 17            E            E            D            E            D
# 18            E            E            D            E            D
#
# [5 rows x 126 columns]

# %% [markdown]
# Existe mais de um professor da mesma matéria por escola, para manter o indice por escola vou selecionar aquele que preencheu mais itens do questionário e descartar as demais informações.

# %% [markdown]
# Lingua Portuguesa

# %%
df_prof_lp['qtd_preenchido'] = df_prof_lp.apply(lambda x: x.isnull().sum(), axis = 1 )
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof_lp.head(10))
# Out:
#     ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 2    11025620            B            B            B            G
# 3    11024666            B            C            B            G
# 6    11025352            B            E            B            G
# 8    11024828            A            D            B            D
# 12   11025638            B            C            B            G
# 16   11025310            B            C            B            G
# 19   11024682            B            C            A            G
# 28   11025352            B            C            B            G
# 40   11006889            B            C            A            G
# 44   11048620            B            C            B            G
#
#    TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  \
# 2             B            B            B            A            A
# 3             C            B            B            C            C
# 6             E            D            B            C            E
# 8             B            B            D            C            C
# 12            C            C            B            C            E
# 16            B            B            B            C            C
# 19            C            C            B            A            A
# 28            C            B            B            C            C
# 40            C            C            C            C            E
# 44            B            B            B            A            A
#
#    TX_RESP_Q010 TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014  \
# 2             E            C            E            C            C
# 3             F            B          NaN            D            B
# 6             G            A            I            G            E
# 8             E            C            E            F            F
# 12            E            C            E            D            D
# 16            C            C            D            C            A
# 19            F            C            F            C            A
# 28            C            C            C            B            B
# 40            G            A            H            F            E
# 44            H            A            H            C            B
#
#    TX_RESP_Q015 TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019  \
# 2             C            A            B            A            B
# 3             D            B            C            D            A
# 6             G            A            C            B            A
# 8             D            A            B            A            B
# 12            D            A            B            A            B
# 16            B            C            C            B            B
# 19            C            A            B            A            B
# 28            B            C            C            B            B
# 40            B            A            B            B            A
# 44            B            A            B            A            B
#
#    TX_RESP_Q020 TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024  \
# 2             B            B            B            A            A
# 3             A            C            A            C            A
# 6             B            D            D            A            D
# 8             B            A            A            A            B
# 12            B            A            D            C            A
# 16            C            E            E            E            E
# 19            C            C            C            A            A
# 28            B            E            E            E            E
# 40            B            C            D            A            A
# 44            C            D            D            A            A
#
#    TX_RESP_Q025 TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029  \
# 2             A            B            C            C            B
# 3           NaN            D            D            D            D
# 6             A            C            C            C            B
# 8             A            C            D            C            A
# 12            A            B            B            A            A
# 16            B            A            A            A            A
# 19            A            C            C            C            B
# 28            B            C            A            A            A
# 40            A            C            C            C            B
# 44            A            C            C            C            C
#
#    TX_RESP_Q030 TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034  \
# 2             B            C            C            B            B
# 3             D            D            D            B            C
# 6             C            D            D            B            B
# 8             C            D            C            B            B
# 12            B            D            D            B            C
# 16            A            C            D            B            C
# 19            C            C            B            B            B
# 28            A            C            D            B            B
# 40            C            C            C            B            B
# 44            C            C            D            B            B
#
#    TX_RESP_Q035 TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039  \
# 2             B            B            C            B            C
# 3             C            C            C            B            B
# 6             C            C            C            C            C
# 8             C            C            B            B            C
# 12            C            B            B            B            C
# 16            B            B            C            B            C
# 19            C            C            C            C            B
# 28            B            B            C            C            C
# 40            C            C            B            B            C
# 44            C            C            B            C            C
#
#    TX_RESP_Q040 TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044  \
# 2             B            B            B            B            C
# 3             B            B            B            B          NaN
# 6             C            B            A            B            C
# 8             C            B            A            B            C
# 12            B            C            B            A            C
# 16            B            C            A            B            D
# 19            C            B            A            A            D
# 28            B            C            A            B            D
# 40            C            B            A            A            C
# 44            C            C            C            A            C
#
#    TX_RESP_Q045 TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049  \
# 2             D            D            D            D            D
# 3           NaN            A            B            C            A
# 6             D            C            C            D            D
# 8             C            C            D            D            C
# 12            D            C            C            D            B
# 16            D            A            C            C            A
# 19            D            D            C            D            C
# 28            D            A            C            C            A
# 40            D            C            C            C            C
# 44            D            D            D            D            A
#
#    TX_RESP_Q050 TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054  \
# 2             D            F            E            B            A
# 3             A          NaN            E            A            A
# 6             D            F            E            C            D
# 8             C          NaN            D            C            B
# 12            B            F            E            B            E
# 16            A            F            E            B            C
# 19            D            F            E            B            B
# 28            A            F            E            B            D
# 40            C            H            D            B            D
# 44            D            H            E            B            E
#
#    TX_RESP_Q055 TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059  \
# 2             E            D            C            C            C
# 3             D            D            D            C            B
# 6             C            D            D            C            C
# 8             D            D            C            D            C
# 12            D            D            D            C            C
# 16            C            C            C            C            C
# 19            D            D            D            D            D
# 28            C            C            C            C            C
# 40            C            C            C            C            D
# 44            D            D            C            D            D
#
#    TX_RESP_Q060 TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064  \
# 2             C            C            C            C            C
# 3             C            C            C            C            C
# 6             B            C            C            C            C
# 8             C            C            C            C            B
# 12            B            C            D            D            B
# 16            C            C            C            C            C
# 19            D            D            D            D            D
# 28            C            C            C            C            C
# 40            C            C            D            D            C
# 44            C            D            D            D            D
#
#    TX_RESP_Q065 TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069  \
# 2             C            C            C            C            C
# 3             C            D            D            D            D
# 6             D            D            D            C            C
# 8             B            C            B            C            B
# 12            C            D            D            C            C
# 16            C            C            C            C            C
# 19            D            D            D            D            B
# 28            C            C            C            C            D
# 40            C            C            C            C            C
# 44            D            D            D            C            B
#
#    TX_RESP_Q070 TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074  \
# 2             B            B            B            B            B
# 3             A            B            B            B            A
# 6             A            B            B            A            A
# 8             B            B            A            A            B
# 12            B            B            A            B            A
# 16            B            B            B            B            B
# 19            B            B            B            B            B
# 28            B            B            B            B            B
# 40            A            B            B            B            B
# 44            A            B            B            B            B
#
#    TX_RESP_Q075 TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079  \
# 2             B            B            B            B            B
# 3             B            A            A            A            A
# 6             A            A            A            A            A
# 8             A            A            A            A            A
# 12            A            A            A            A            A
# 16            B            A            A            A            A
# 19            B            A            A            A            A
# 28            B            A            A            A            A
# 40            B            B            B            A            B
# 44            B            A            A            A            A
#
#    TX_RESP_Q080 TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084  \
# 2           NaN            B            B            B            B
# 3             A            A            A            B            B
# 6             A            A            A            A            A
# 8             A            A            B            A            A
# 12            A            A            A            B            A
# 16            A            A            B            B            A
# 19            A            A            B            B            A
# 28            A            A            A            B            A
# 40            A            B            B            B            A
# 44            A            A            A            A            A
#
#    TX_RESP_Q085 TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089  \
# 2             B            B            B            B            B
# 3             B            B            B            B            B
# 6             A            A            A            A            A
# 8             B            B            B            B            B
# 12            B            B            B            B            B
# 16            B            B            B            B            B
# 19            B          NaN            B            B            B
# 28            B            B            B            B            B
# 40            B            B            B            B            B
# 44            B            B            A            B            B
#
#    TX_RESP_Q090 TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094  \
# 2             B            B            B          NaN            D
# 3             B            B            B          NaN          NaN
# 6             A            A            A            D            D
# 8             B            A            B            D            D
# 12            B            B            B          NaN            D
# 16            B            B            B            D            D
# 19            B            B            B          NaN            D
# 28            B            B            B            D            D
# 40            B            B            B          NaN            D
# 44            B            B            B          NaN            D
#
#    TX_RESP_Q095 TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099  \
# 2             D            B            B            A            E
# 3             D            C            A            B            E
# 6             D            C            A            A            E
# 8             D            D            A            B            E
# 12            D            C            A            A            E
# 16            D            D            A            C            E
# 19            C            C            A            A            E
# 28            D            C            B            C            E
# 40            D            C            A            A            E
# 44            D            D            A            B            E
#
#    TX_RESP_Q100 TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104  \
# 2             A            D            A            A            F
# 3             A            D            A            A            F
# 6             A            D            A            F            F
# 8             A            C            A            E            F
# 12            A            D            A            A            F
# 16            A            D            A            A            D
# 19            A            C            A            A            F
# 28            A            D            A            A            E
# 40            A            D            A            C            E
# 44            A            C            A            B            F
#
#    TX_RESP_Q105 TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109  \
# 2             A            D            F            F            E
# 3             A            D            E            E            D
# 6             A            E            E            E            E
# 8             A            D            E            F            D
# 12            A            E            B            B            E
# 16            A            E            E            E            E
# 19            A            E            F            F            E
# 28            A            E            E            E            E
# 40            A            E            A            A            E
# 44            A            E            E            E            D
#
#    TX_RESP_Q110 TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114  \
# 2             D            F            E            E            E
# 3             D            E            E            E            C
# 6             D            D            D            D            D
# 8             B            E            E            B            C
# 12            C            A            F            F            D
# 16            B            E            E            E            E
# 19            D            F            F            F            D
# 28            D            E            E            E            E
# 40            C            F            F            F            D
# 44            D            F            F            F            E
#
#    TX_RESP_Q115 TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119  \
# 2             E            D            E            E            E
# 3             D            E            D            B            F
# 6             D            E            E            D            E
# 8             C            E            F            E            D
# 12            D            E            D            C            C
# 16            E            E            E            E            E
# 19            C            E            E            D            E
# 28            E            E            E            E            E
# 40            D            E            E            C            E
# 44            E            D            E            E            F
#
#    TX_RESP_Q120 TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124  \
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 19            F          NaN          NaN          NaN          NaN
# 28          NaN          NaN          NaN          NaN          NaN
# 40          NaN          NaN          NaN          NaN          NaN
# 44          NaN          NaN          NaN          NaN          NaN
#
#    TX_RESP_Q125  qtd_preenchido
# 2           NaN               8
# 3           NaN              13
# 6           NaN               6
# 8           NaN               7
# 12          NaN               7
# 16          NaN               6
# 19          NaN               7
# 28          NaN               6
# 40          NaN               7
# 44          NaN               7

# %%
df_prof_lp.sort_values(by=['ID_ESCOLA', 'qtd_preenchido'], ascending=[True,True], inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof_lp.head(20))
# Out:
#       ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 1296   11000260            B            C            B            G
# 1298   11000260            B            E            B            G
# 859    11000260            B            E            B            G
# 860    11000260            B            E            B            G
# 1286   11000317            B            D            A            G
# 1035   11000368            A            B            B            G
# 1278   11000368            B            D            A            G
# 847    11000384            B            D            A            G
# 1246   11000384            B            D            A            G
# 1014   11000457            B            C            A            G
# 1261   11000457            B            C            A            G
# 877    11000597            B            F            B            G
# 1311   11000678            B            D            A            G
# 1293   11000678            B            D            C            G
# 1310   11000708            B            D            B            B
# 1150   11000848            B            D            B            H
# 1112   11000856            B            E            B            G
# 1104   11000856            B            C            A            G
# 1299   11000856            A            E            C            B
# 1119   11000856            B            F            C            B
#
#      TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  \
# 1296            C            C            B            C            C
# 1298            C            C            B            C            E
# 859             C            C            B            C            E
# 860             C            C            B            C            E
# 1286            B            B            B            C            E
# 1035            B            C            C            C            E
# 1278            C            C            C            C            E
# 847             C            B            B            C            C
# 1246            E            B            B            C            E
# 1014            C            C            B            C            E
# 1261            C            C            B            C            E
# 877             C            C            B            C            E
# 1311            C            C            B            C            E
# 1293            D            C            B            A            A
# 1310            E            D            B            C            C
# 1150            C            C            B            C            C
# 1112            C            C            C            C            E
# 1104            C            C            B            C            C
# 1299            A            B            B            A            A
# 1119            C            B            B            B            A
#
#      TX_RESP_Q010 TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014  \
# 1296            G            A            H            E            C
# 1298            H            C            I            G            G
# 859             H            C            I            G            G
# 860             H            C            I            G            G
# 1286            G            C            G            E            A
# 1035            G            A            H            E            D
# 1278            G            C            G            G            D
# 847             E            C            E            D            A
# 1246            F            A            I            G            F
# 1014            F            A            I            F            F
# 1261            G            A            I            F            F
# 877             H            C            H            G            G
# 1311            G            C            G            F            F
# 1293            G            C          NaN            G            E
# 1310            H          NaN            H            G            E
# 1150            G            B            H            F            F
# 1112            H            C            H            G            G
# 1104            G            C            G            F            D
# 1299            E            C            F            F            F
# 1119            E            C            E            F            F
#
#      TX_RESP_Q015 TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019  \
# 1296            D            A            B            B            A
# 1298            C            A            C            B            A
# 859             C            A            C            B            A
# 860             C            A            C            B            A
# 1286            E            A            B            A            B
# 1035            C            A            C            B            A
# 1278            C            A            C            A            C
# 847             D            A            B            A            B
# 1246            G            A            B            A            A
# 1014            B            A            B            B            A
# 1261            B            A            B            B            A
# 877             A            A            B            A            B
# 1311            F            A            B            A            B
# 1293            C            A            D            B            B
# 1310            E            A            B            A            B
# 1150            D            A            B            A            B
# 1112            F            A            B            A            B
# 1104            D            A            A            A            A
# 1299            F            A            B            A            B
# 1119            F            A            B            A            B
#
#      TX_RESP_Q020 TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024  \
# 1296            B            B            A            A            A
# 1298            B            B            B            A            A
# 859             B            B            B            A            A
# 860             B            B            B            A            A
# 1286            C            D            D            E            A
# 1035            B            A            D            E            A
# 1278            C            A            A            A            A
# 847             C            A            D            D            D
# 1246            C            B            B            B            A
# 1014            C            E            B            A            C
# 1261            B            D            D            A            A
# 877             C            A            A            B            B
# 1311            B            D            C            A            A
# 1293            B            A            A            A            A
# 1310            C            A            A            A            A
# 1150            B            D            D            D            A
# 1112            B            B            B            C            C
# 1104            B            D            D            A            A
# 1299            C            A            A            A            A
# 1119            B            C            A            A            A
#
#      TX_RESP_Q025 TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029  \
# 1296            B            A            C            D            C
# 1298            A            B            B            B            B
# 859             A            B            B            B            B
# 860             A            B            B            B            B
# 1286            B            D            D            C            C
# 1035            A            C            D            D            B
# 1278            A            C            C            C            C
# 847             A            A            A            A            A
# 1246            A            A            A            A            A
# 1014            A            B            B            B            B
# 1261            A            C            C            C            C
# 877             A            C            C            C            B
# 1311            A            C            B            B            B
# 1293            A            C            C            C            C
# 1310          NaN            C            C            C            A
# 1150            B            B            B            C            C
# 1112            A            D            C            C            B
# 1104            A            C            C            C            D
# 1299            A            B            C            B            C
# 1119            A            C            D            C            D
#
#      TX_RESP_Q030 TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034  \
# 1296            D            D            D            B            C
# 1298            B            C            C            B            B
# 859             B            C            C            B            B
# 860             B            C            C            B            B
# 1286            C            C            D            B            C
# 1035            C            B            D            B            B
# 1278            C            C            C            B            B
# 847             A            D            D            B            C
# 1246            A            C            D            B            B
# 1014            C            C            D            B            C
# 1261            C            D            D            B            B
# 877             C            D            D            B            C
# 1311            C            C            D            A            A
# 1293            C            B            D            B            C
# 1310            C            C            A          NaN            B
# 1150            C            C            D            B            C
# 1112            C            B            D            B            C
# 1104            C            D            D            B            B
# 1299            B            C            B            B            A
# 1119            C            C            D            B            B
#
#      TX_RESP_Q035 TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039  \
# 1296            C            C            B            C            C
# 1298            C            C            C            C            C
# 859             C            C            C            C            C
# 860             C            C            C            C            C
# 1286            C            C            B            C            B
# 1035            C            C            C            C            B
# 1278            C            C            B            C            C
# 847             C            C            C            C            C
# 1246            C            B            B            C            C
# 1014            B            B            B            B            B
# 1261            C            C            B            B            B
# 877             C            C            B            C            C
# 1311            A            A            A            C            B
# 1293            B            C            C            B            C
# 1310            B            B            B            B            B
# 1150            B            B            B            B            C
# 1112            B            C            B            B            B
# 1104            C            C            C            B            C
# 1299            A            C            C            C            C
# 1119            C            C            C            C            C
#
#      TX_RESP_Q040 TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044  \
# 1296            C            A            C            C            B
# 1298            B            C            B            C            C
# 859             B            C            B            C            C
# 860             B            C            B            C            C
# 1286            C            B            A            A            C
# 1035            C            A            B            B            C
# 1278            C            B            A            A            C
# 847             B            B            A            A            A
# 1246            B            A            A            A            C
# 1014            C            B            A            A            C
# 1261            C            B            A            A            C
# 877             B            B            B            B            D
# 1311            B            B            B            A            C
# 1293            C            C            B            A            C
# 1310            A            B            B            B            C
# 1150            B            C            C            B            D
# 1112            B            A            B            A            C
# 1104            C            A            B            B            C
# 1299            C            C            C            C            D
# 1119            C            C            B            C            D
#
#      TX_RESP_Q045 TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049  \
# 1296            D            C            B            D            C
# 1298            D            C            D            C            C
# 859             D            C            D            C            C
# 860             D            C            D            C            C
# 1286            C            C            C            D            C
# 1035            A            D            D            D            C
# 1278            B            B            B            C            C
# 847             D            B            B            D            B
# 1246            C            C            C            D            B
# 1014            C            D            C            D            B
# 1261            D            C            C            D            C
# 877             D            B            D            D            C
# 1311            D            C            B            D            B
# 1293            C            D            C            D            C
# 1310            C            C            C            C            C
# 1150            D            D            D            D            D
# 1112            C            C            C            C            C
# 1104            D            C            C            D            B
# 1299            D            D            D            D            D
# 1119            C            C            D            D            D
#
#      TX_RESP_Q050 TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054  \
# 1296            D            A            D            B            E
# 1298            C            E            E            B            C
# 859             C            E            E            B            C
# 860             C            E            E            B            C
# 1286            C            F            E            B            B
# 1035            C            F            E            B            E
# 1278            C            F            E            B            D
# 847             B            C            D            B            C
# 1246            C            C            D            B            C
# 1014            C            F            D            C            D
# 1261            C            F            E            C            D
# 877             C            H            D            B            D
# 1311            B            F            D            B            C
# 1293            C            H            E            C            C
# 1310            C            H            B            B            B
# 1150            C            F            C            B            C
# 1112            C            H            C            B            D
# 1104            B            A            B            B            C
# 1299            D            H            C            C            B
# 1119            D            H            C            B            A
#
#      TX_RESP_Q055 TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059  \
# 1296            A            C            C            D            D
# 1298            C            C            C            B            C
# 859             C            C            C            B            C
# 860             C            C            C            B            C
# 1286            C            C            C            C            C
# 1035            C            C            C            A            C
# 1278            C            A            C            C            C
# 847             B            D            C            B            D
# 1246            B            C            B            B            C
# 1014            C            D            C            C            C
# 1261            D            D            D            C            C
# 877             C            C            B            B            C
# 1311            C            C            C            C            C
# 1293            C            C            C            C            C
# 1310            B            D            B            B            B
# 1150            C            C            C            D            D
# 1112            C            C            B            C            D
# 1104            A            B            B            B            B
# 1299            B            C            B            C            B
# 1119            B            E            B            D            C
#
#      TX_RESP_Q060 TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064  \
# 1296            A            D            D            D            D
# 1298            C            C            C            C            B
# 859             C            C            C            C            B
# 860             C            C            C            C            B
# 1286            B            C            C            C            C
# 1035            B            B            B            B            B
# 1278            B            D            D            D            C
# 847             D            D            D            D            B
# 1246            C            B            C            D            B
# 1014            B            C            C            C            D
# 1261            B            C            D            D            D
# 877             C            C            C            C            C
# 1311            C            C            B            B            B
# 1293            B            C            B            C            C
# 1310            B            B            B            C            B
# 1150            D            C            C            D            D
# 1112            D            D            D            D            D
# 1104            B            B            D            D            A
# 1299            D            C            C            C            C
# 1119            D            D            D            C            C
#
#      TX_RESP_Q065 TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069  \
# 1296            D            D            D            C            C
# 1298            B            D            D            C            C
# 859             B            D            D            C            C
# 860             B            D            D            C            C
# 1286            C            D            D            D            C
# 1035            B            D            B            D            D
# 1278            D            D            D            D            D
# 847             C            C            C            C            B
# 1246            B            D            D            D            D
# 1014            C            C            D            C            D
# 1261            C            D            D            D            C
# 877             C            C            C            C            B
# 1311            C            C            C            C            C
# 1293            C            C            C            C            C
# 1310            B            C            C            C            C
# 1150            D            D            D            D            C
# 1112            D            D            D            C            B
# 1104            A            C            B            B            A
# 1299            D            C            C            C            C
# 1119            C            C            D            C            D
#
#      TX_RESP_Q070 TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074  \
# 1296            B            B            B            B            A
# 1298            B            B            B            B            B
# 859             B            B            B            B            B
# 860             B            B            B            B            B
# 1286            B            B            B            B            B
# 1035            B            B            B            B            B
# 1278            B            A            B            A            B
# 847             A            B            B            A            A
# 1246            B            B            B            B            B
# 1014            A            B            B            B            B
# 1261            A            B            B            B            B
# 877             B            B            B            B            A
# 1311            B            B            B            B            A
# 1293            B            B            B            B            B
# 1310            B            B            A            B            B
# 1150            A            A            A            A            A
# 1112            A            B            B            B            A
# 1104            A            A            A            B            A
# 1299            A            B            B            B            B
# 1119            B            A          NaN            B            B
#
#      TX_RESP_Q075 TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079  \
# 1296            A            A            A            A            A
# 1298            B            B            B            A            A
# 859             B            B            B            A            A
# 860             B            B            B            A            A
# 1286            B            A            A            A            A
# 1035            A            A            A            A            A
# 1278            B            A            A            A            A
# 847             B            A            A            A            A
# 1246            B          NaN            A            A            A
# 1014            B            A            A            A            A
# 1261            B            A            A            A            A
# 877             A            A            A            A            A
# 1311            B            A            A            A            A
# 1293            A            A            A            A            A
# 1310            B            A            A            A            A
# 1150            A            A            A            A            A
# 1112            B            A            B            A            A
# 1104            A            A            A            A            B
# 1299            B            A            A            A            A
# 1119            B            A            A            A            A
#
#      TX_RESP_Q080 TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084  \
# 1296            A            A            A            A            A
# 1298            A            A            A            A            A
# 859             A            A            A            A            A
# 860             A            A            A            A            A
# 1286            A            A            A            B            B
# 1035            A            A            B            B            A
# 1278            A            B            B            B            B
# 847             A            A            A            A            A
# 1246            A            A            A            A            A
# 1014            A            B            A            A            A
# 1261            A            A            B            A            A
# 877             A            A            B            B            A
# 1311            A            A            B            A            A
# 1293            A            B            A            A            A
# 1310            A            A            A            A            A
# 1150            A            A            A            B            B
# 1112            A            A            A            B            A
# 1104            A            A            A            A            A
# 1299            A            A            B            B            B
# 1119            A            A            B            B            B
#
#      TX_RESP_Q085 TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089  \
# 1296            B            B            B            B            B
# 1298            A            A            A            A            A
# 859             A            A            A            A            A
# 860             A            A            A            A            A
# 1286            B            B            B            B            B
# 1035            B            B            B            B            B
# 1278            B            B            B            B            B
# 847             B            B            B            B            B
# 1246            B            B            B            B            A
# 1014            B            B            B            B            A
# 1261            B            B            B            B            A
# 877             B            B            B            B            B
# 1311            B            B            B            B            B
# 1293            B            A            A            B            B
# 1310            B            B            B            B            B
# 1150            B            B            B            B            B
# 1112            B            B            B            B            B
# 1104            B            B            B            B            B
# 1299            B            B            B            B            B
# 1119            B            B            B            B            B
#
#      TX_RESP_Q090 TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094  \
# 1296            B            B            B          NaN            D
# 1298            A            A            A          NaN            D
# 859             A            A            A          NaN            D
# 860             A            A            A          NaN            D
# 1286            B            B            B          NaN            D
# 1035            B            B            B          NaN            D
# 1278            B            B            B          NaN            D
# 847             A            B            B          NaN            D
# 1246            A            A            B          NaN            D
# 1014            A            A            B          NaN            D
# 1261            B            A            B          NaN            D
# 877             B            B            B          NaN            C
# 1311            B            B            B          NaN            D
# 1293            A            B            B          NaN            D
# 1310            A            B            B          NaN            C
# 1150            B            B            B          NaN            D
# 1112            B            B            B          NaN            C
# 1104            A            A            B          NaN            C
# 1299            B            B            B          NaN            D
# 1119            B            B            B            D            D
#
#      TX_RESP_Q095 TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099  \
# 1296            D            D            B            C            E
# 1298            D            D            A            B            E
# 859             D            D            A            B            E
# 860             D            D            A            B            E
# 1286            D            B            B            A            E
# 1035            D            B            A            B            E
# 1278            D            C            A            A            E
# 847             C            A            B            A            E
# 1246            D            C            A            A            E
# 1014            D            C            A            A            E
# 1261            D            C            A            A            E
# 877             C            B            A            A            B
# 1311            D            B            A            A            E
# 1293            D            C            B            A            D
# 1310            C            A            A            A            E
# 1150            D            D            A            A            E
# 1112            C            B            A            C            E
# 1104            C            A            A            A            E
# 1299            C            B            A            A            E
# 1119            C          NaN            A            A            E
#
#      TX_RESP_Q100 TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104  \
# 1296            A            E            B            B            F
# 1298            A            B            A            B            E
# 859             A            B            A            B            E
# 860             A            B            A            B            E
# 1286            A            D            B            E            C
# 1035            A            D            A            A            F
# 1278            A            E            A            B            F
# 847             A            C            A            A            D
# 1246            A            D            B            D            D
# 1014            A            C            A            A            E
# 1261            A            C            A            B            E
# 877             A            C            A            A            E
# 1311            A            D            A            B            D
# 1293            A            D            A            B            D
# 1310            A            D            A            F            F
# 1150            A            E            A            A            F
# 1112            A            D            A            B            F
# 1104            A            D            A            A            E
# 1299            A            D            A            B            C
# 1119          NaN            A            A            B            B
#
#      TX_RESP_Q105 TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109  \
# 1296            A            E            F            F            C
# 1298            A            D          NaN            E            D
# 859             A            D            D            E            D
# 860             A            D            D            E            D
# 1286            A            C            F            F            E
# 1035            A            D            E            F            E
# 1278            A            D            E            E            D
# 847             A            E            E            F            E
# 1246            A            D            E            E            D
# 1014            A            D            E            E            D
# 1261            A            D            E            E            E
# 877             A            D            E            F            D
# 1311            A            D            F            F            D
# 1293            A            D            E            F            E
# 1310            A            E            F            F            E
# 1150            A            E            F            F            D
# 1112            A            E            E            F            E
# 1104            A            C            D            D            B
# 1299            A            D            D            D            E
# 1119            A            D            F            F            F
#
#      TX_RESP_Q110 TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114  \
# 1296            C            D            E            D            A
# 1298            C            D            E            E            D
# 859             C            D            E            E            D
# 860             C            D            E            E            D
# 1286            D            E            E          NaN            D
# 1035            D            E            E            E            E
# 1278            D            E            E            E            D
# 847             B            E            E            E            E
# 1246            C            F            F            F            D
# 1014            E            E            F            F            E
# 1261            D            E            E            E            D
# 877             C            F            F            F            E
# 1311            A            F            E            A            D
# 1293            D            E            E            D            E
# 1310            E            E            F            E            D
# 1150            D            E            F            F            E
# 1112            D            E            E            E            E
# 1104            B            D            D            D            B
# 1299            F            E            F            F            F
# 1119            C            E            F            F            E
#
#      TX_RESP_Q115 TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119  \
# 1296            A            E            E            A            E
# 1298            D            D            D            D            D
# 859             D            D            D            D            D
# 860             D            D            D            D            D
# 1286            E            E            E            D            E
# 1035            E            E            E            C            E
# 1278            D            E            E            D            E
# 847             E            E            E            A            E
# 1246            D            D            F            D            E
# 1014            E            E            E            D            D
# 1261            E            E            F            E            F
# 877             E            E            E            D            F
# 1311            E            D            B            E            E
# 1293            D            E            D            E            E
# 1310            E            E            E            D            E
# 1150            F            E            F            E            F
# 1112            E            E            E            D            E
# 1104            B            B            B            B            B
# 1299            E            F            F            F            F
# 1119            E            F            F            F            E
#
#      TX_RESP_Q120 TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124  \
# 1296            E          NaN          NaN          NaN          NaN
# 1298            E            E          NaN          NaN          NaN
# 859           NaN          NaN          NaN          NaN          NaN
# 860           NaN          NaN          NaN          NaN          NaN
# 1286            F            F          NaN          NaN          NaN
# 1035          NaN          NaN          NaN          NaN          NaN
# 1278          NaN          NaN          NaN          NaN          NaN
# 847           NaN          NaN          NaN          NaN          NaN
# 1246          NaN          NaN          NaN          NaN          NaN
# 1014          NaN          NaN          NaN          NaN          NaN
# 1261          NaN          NaN          NaN          NaN          NaN
# 877           NaN          NaN          NaN          NaN          NaN
# 1311          NaN          NaN          NaN          NaN          NaN
# 1293          NaN          NaN          NaN          NaN          NaN
# 1310            F            E            E            D          NaN
# 1150          NaN          NaN          NaN          NaN          NaN
# 1112            D            C          NaN          NaN          NaN
# 1104          NaN          NaN          NaN          NaN          NaN
# 1299          NaN          NaN          NaN          NaN          NaN
# 1119          NaN          NaN          NaN          NaN          NaN
#
#      TX_RESP_Q125  qtd_preenchido
# 1296          NaN               6
# 1298          NaN               6
# 859           NaN               7
# 860           NaN               7
# 1286          NaN               6
# 1035          NaN               7
# 1278          NaN               7
# 847           NaN               7
# 1246          NaN               8
# 1014          NaN               7
# 1261          NaN               7
# 877           NaN               7
# 1311          NaN               7
# 1293          NaN               8
# 1310          NaN               6
# 1150          NaN               7
# 1112          NaN               5
# 1104          NaN               7
# 1299          NaN               7
# 1119          NaN               9

# %%
df_prof_lp_final = df_prof_lp.drop_duplicates(subset=['ID_ESCOLA'])
df_prof_lp_final.set_index('ID_ESCOLA', inplace=True)
df_prof_lp_final.drop(columns='qtd_preenchido', inplace=True)
df_prof_lp_final.shape
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# (27207, 125)

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof_lp_final.head(10))
# Out:
#           TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004 TX_RESP_Q005  \
# ID_ESCOLA
# 11000260             B            C            B            G            C
# 11000317             B            D            A            G            B
# 11000368             A            B            B            G            B
# 11000384             B            D            A            G            C
# 11000457             B            C            A            G            C
# 11000597             B            F            B            G            C
# 11000678             B            D            A            G            C
# 11000708             B            D            B            B            E
# 11000848             B            D            B            H            C
# 11000856             B            E            B            G            C
#
#           TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010  \
# ID_ESCOLA
# 11000260             C            B            C            C            G
# 11000317             B            B            C            E            G
# 11000368             C            C            C            E            G
# 11000384             B            B            C            C            E
# 11000457             C            B            C            E            F
# 11000597             C            B            C            E            H
# 11000678             C            B            C            E            G
# 11000708             D            B            C            C            H
# 11000848             C            B            C            C            G
# 11000856             C            C            C            E            H
#
#           TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015  \
# ID_ESCOLA
# 11000260             A            H            E            C            D
# 11000317             C            G            E            A            E
# 11000368             A            H            E            D            C
# 11000384             C            E            D            A            D
# 11000457             A            I            F            F            B
# 11000597             C            H            G            G            A
# 11000678             C            G            F            F            F
# 11000708           NaN            H            G            E            E
# 11000848             B            H            F            F            D
# 11000856             C            H            G            G            F
#
#           TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020  \
# ID_ESCOLA
# 11000260             A            B            B            A            B
# 11000317             A            B            A            B            C
# 11000368             A            C            B            A            B
# 11000384             A            B            A            B            C
# 11000457             A            B            B            A            C
# 11000597             A            B            A            B            C
# 11000678             A            B            A            B            B
# 11000708             A            B            A            B            C
# 11000848             A            B            A            B            B
# 11000856             A            B            A            B            B
#
#           TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025  \
# ID_ESCOLA
# 11000260             B            A            A            A            B
# 11000317             D            D            E            A            B
# 11000368             A            D            E            A            A
# 11000384             A            D            D            D            A
# 11000457             E            B            A            C            A
# 11000597             A            A            B            B            A
# 11000678             D            C            A            A            A
# 11000708             A            A            A            A          NaN
# 11000848             D            D            D            A            B
# 11000856             B            B            C            C            A
#
#           TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030  \
# ID_ESCOLA
# 11000260             A            C            D            C            D
# 11000317             D            D            C            C            C
# 11000368             C            D            D            B            C
# 11000384             A            A            A            A            A
# 11000457             B            B            B            B            C
# 11000597             C            C            C            B            C
# 11000678             C            B            B            B            C
# 11000708             C            C            C            A            C
# 11000848             B            B            C            C            C
# 11000856             D            C            C            B            C
#
#           TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035  \
# ID_ESCOLA
# 11000260             D            D            B            C            C
# 11000317             C            D            B            C            C
# 11000368             B            D            B            B            C
# 11000384             D            D            B            C            C
# 11000457             C            D            B            C            B
# 11000597             D            D            B            C            C
# 11000678             C            D            A            A            A
# 11000708             C            A          NaN            B            B
# 11000848             C            D            B            C            B
# 11000856             B            D            B            C            B
#
#           TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040  \
# ID_ESCOLA
# 11000260             C            B            C            C            C
# 11000317             C            B            C            B            C
# 11000368             C            C            C            B            C
# 11000384             C            C            C            C            B
# 11000457             B            B            B            B            C
# 11000597             C            B            C            C            B
# 11000678             A            A            C            B            B
# 11000708             B            B            B            B            A
# 11000848             B            B            B            C            B
# 11000856             C            B            B            B            B
#
#           TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045  \
# ID_ESCOLA
# 11000260             A            C            C            B            D
# 11000317             B            A            A            C            C
# 11000368             A            B            B            C            A
# 11000384             B            A            A            A            D
# 11000457             B            A            A            C            C
# 11000597             B            B            B            D            D
# 11000678             B            B            A            C            D
# 11000708             B            B            B            C            C
# 11000848             C            C            B            D            D
# 11000856             A            B            A            C            C
#
#           TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050  \
# ID_ESCOLA
# 11000260             C            B            D            C            D
# 11000317             C            C            D            C            C
# 11000368             D            D            D            C            C
# 11000384             B            B            D            B            B
# 11000457             D            C            D            B            C
# 11000597             B            D            D            C            C
# 11000678             C            B            D            B            B
# 11000708             C            C            C            C            C
# 11000848             D            D            D            D            C
# 11000856             C            C            C            C            C
#
#           TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055  \
# ID_ESCOLA
# 11000260             A            D            B            E            A
# 11000317             F            E            B            B            C
# 11000368             F            E            B            E            C
# 11000384             C            D            B            C            B
# 11000457             F            D            C            D            C
# 11000597             H            D            B            D            C
# 11000678             F            D            B            C            C
# 11000708             H            B            B            B            B
# 11000848             F            C            B            C            C
# 11000856             H            C            B            D            C
#
#           TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060  \
# ID_ESCOLA
# 11000260             C            C            D            D            A
# 11000317             C            C            C            C            B
# 11000368             C            C            A            C            B
# 11000384             D            C            B            D            D
# 11000457             D            C            C            C            B
# 11000597             C            B            B            C            C
# 11000678             C            C            C            C            C
# 11000708             D            B            B            B            B
# 11000848             C            C            D            D            D
# 11000856             C            B            C            D            D
#
#           TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065  \
# ID_ESCOLA
# 11000260             D            D            D            D            D
# 11000317             C            C            C            C            C
# 11000368             B            B            B            B            B
# 11000384             D            D            D            B            C
# 11000457             C            C            C            D            C
# 11000597             C            C            C            C            C
# 11000678             C            B            B            B            C
# 11000708             B            B            C            B            B
# 11000848             C            C            D            D            D
# 11000856             D            D            D            D            D
#
#           TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070  \
# ID_ESCOLA
# 11000260             D            D            C            C            B
# 11000317             D            D            D            C            B
# 11000368             D            B            D            D            B
# 11000384             C            C            C            B            A
# 11000457             C            D            C            D            A
# 11000597             C            C            C            B            B
# 11000678             C            C            C            C            B
# 11000708             C            C            C            C            B
# 11000848             D            D            D            C            A
# 11000856             D            D            C            B            A
#
#           TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074 TX_RESP_Q075  \
# ID_ESCOLA
# 11000260             B            B            B            A            A
# 11000317             B            B            B            B            B
# 11000368             B            B            B            B            A
# 11000384             B            B            A            A            B
# 11000457             B            B            B            B            B
# 11000597             B            B            B            A            A
# 11000678             B            B            B            A            B
# 11000708             B            A            B            B            B
# 11000848             A            A            A            A            A
# 11000856             B            B            B            A            B
#
#           TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079 TX_RESP_Q080  \
# ID_ESCOLA
# 11000260             A            A            A            A            A
# 11000317             A            A            A            A            A
# 11000368             A            A            A            A            A
# 11000384             A            A            A            A            A
# 11000457             A            A            A            A            A
# 11000597             A            A            A            A            A
# 11000678             A            A            A            A            A
# 11000708             A            A            A            A            A
# 11000848             A            A            A            A            A
# 11000856             A            B            A            A            A
#
#           TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084 TX_RESP_Q085  \
# ID_ESCOLA
# 11000260             A            A            A            A            B
# 11000317             A            A            B            B            B
# 11000368             A            B            B            A            B
# 11000384             A            A            A            A            B
# 11000457             B            A            A            A            B
# 11000597             A            B            B            A            B
# 11000678             A            B            A            A            B
# 11000708             A            A            A            A            B
# 11000848             A            A            B            B            B
# 11000856             A            A            B            A            B
#
#           TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089 TX_RESP_Q090  \
# ID_ESCOLA
# 11000260             B            B            B            B            B
# 11000317             B            B            B            B            B
# 11000368             B            B            B            B            B
# 11000384             B            B            B            B            A
# 11000457             B            B            B            A            A
# 11000597             B            B            B            B            B
# 11000678             B            B            B            B            B
# 11000708             B            B            B            B            A
# 11000848             B            B            B            B            B
# 11000856             B            B            B            B            B
#
#           TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094 TX_RESP_Q095  \
# ID_ESCOLA
# 11000260             B            B          NaN            D            D
# 11000317             B            B          NaN            D            D
# 11000368             B            B          NaN            D            D
# 11000384             B            B          NaN            D            C
# 11000457             A            B          NaN            D            D
# 11000597             B            B          NaN            C            C
# 11000678             B            B          NaN            D            D
# 11000708             B            B          NaN            C            C
# 11000848             B            B          NaN            D            D
# 11000856             B            B          NaN            C            C
#
#           TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099 TX_RESP_Q100  \
# ID_ESCOLA
# 11000260             D            B            C            E            A
# 11000317             B            B            A            E            A
# 11000368             B            A            B            E            A
# 11000384             A            B            A            E            A
# 11000457             C            A            A            E            A
# 11000597             B            A            A            B            A
# 11000678             B            A            A            E            A
# 11000708             A            A            A            E            A
# 11000848             D            A            A            E            A
# 11000856             B            A            C            E            A
#
#           TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104 TX_RESP_Q105  \
# ID_ESCOLA
# 11000260             E            B            B            F            A
# 11000317             D            B            E            C            A
# 11000368             D            A            A            F            A
# 11000384             C            A            A            D            A
# 11000457             C            A            A            E            A
# 11000597             C            A            A            E            A
# 11000678             D            A            B            D            A
# 11000708             D            A            F            F            A
# 11000848             E            A            A            F            A
# 11000856             D            A            B            F            A
#
#           TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109 TX_RESP_Q110  \
# ID_ESCOLA
# 11000260             E            F            F            C            C
# 11000317             C            F            F            E            D
# 11000368             D            E            F            E            D
# 11000384             E            E            F            E            B
# 11000457             D            E            E            D            E
# 11000597             D            E            F            D            C
# 11000678             D            F            F            D            A
# 11000708             E            F            F            E            E
# 11000848             E            F            F            D            D
# 11000856             E            E            F            E            D
#
#           TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114 TX_RESP_Q115  \
# ID_ESCOLA
# 11000260             D            E            D            A            A
# 11000317             E            E          NaN            D            E
# 11000368             E            E            E            E            E
# 11000384             E            E            E            E            E
# 11000457             E            F            F            E            E
# 11000597             F            F            F            E            E
# 11000678             F            E            A            D            E
# 11000708             E            F            E            D            E
# 11000848             E            F            F            E            F
# 11000856             E            E            E            E            E
#
#           TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119 TX_RESP_Q120  \
# ID_ESCOLA
# 11000260             E            E            A            E            E
# 11000317             E            E            D            E            F
# 11000368             E            E            C            E          NaN
# 11000384             E            E            A            E          NaN
# 11000457             E            E            D            D          NaN
# 11000597             E            E            D            F          NaN
# 11000678             D            B            E            E          NaN
# 11000708             E            E            D            E            F
# 11000848             E            F            E            F          NaN
# 11000856             E            E            D            E            D
#
#           TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124 TX_RESP_Q125
# ID_ESCOLA
# 11000260           NaN          NaN          NaN          NaN          NaN
# 11000317             F          NaN          NaN          NaN          NaN
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000384           NaN          NaN          NaN          NaN          NaN
# 11000457           NaN          NaN          NaN          NaN          NaN
# 11000597           NaN          NaN          NaN          NaN          NaN
# 11000678           NaN          NaN          NaN          NaN          NaN
# 11000708             E            E            D          NaN          NaN
# 11000848           NaN          NaN          NaN          NaN          NaN
# 11000856             C          NaN          NaN          NaN          NaN

# %%
df_prof_lp_final.columns = ['PROF_LP_' + x for i, x in enumerate(df_prof_lp_final.columns, 1)]
df_prof_lp_final.head(3)
# Out:
#           PROF_LP_TX_RESP_Q001 PROF_LP_TX_RESP_Q002 PROF_LP_TX_RESP_Q003  \
# ID_ESCOLA
# 11000260                     B                    C                    B
# 11000317                     B                    D                    A
# 11000368                     A                    B                    B
#
#           PROF_LP_TX_RESP_Q004 PROF_LP_TX_RESP_Q005 PROF_LP_TX_RESP_Q006  \
# ID_ESCOLA
# 11000260                     G                    C                    C
# 11000317                     G                    B                    B
# 11000368                     G                    B                    C
#
#           PROF_LP_TX_RESP_Q007 PROF_LP_TX_RESP_Q008 PROF_LP_TX_RESP_Q009  \
# ID_ESCOLA
# 11000260                     B                    C                    C
# 11000317                     B                    C                    E
# 11000368                     C                    C                    E
#
#           PROF_LP_TX_RESP_Q010  ... PROF_LP_TX_RESP_Q116 PROF_LP_TX_RESP_Q117  \
# ID_ESCOLA                       ...
# 11000260                     G  ...                    E                    E
# 11000317                     G  ...                    E                    E
# 11000368                     G  ...                    E                    E
#
#           PROF_LP_TX_RESP_Q118 PROF_LP_TX_RESP_Q119 PROF_LP_TX_RESP_Q120  \
# ID_ESCOLA
# 11000260                     A                    E                    E
# 11000317                     D                    E                    F
# 11000368                     C                    E                  NaN
#
#           PROF_LP_TX_RESP_Q121 PROF_LP_TX_RESP_Q122 PROF_LP_TX_RESP_Q123  \
# ID_ESCOLA
# 11000260                   NaN                  NaN                  NaN
# 11000317                     F                  NaN                  NaN
# 11000368                   NaN                  NaN                  NaN
#
#           PROF_LP_TX_RESP_Q124 PROF_LP_TX_RESP_Q125
# ID_ESCOLA
# 11000260                   NaN                  NaN
# 11000317                   NaN                  NaN
# 11000368                   NaN                  NaN
#
# [3 rows x 125 columns]

# %% [markdown]
# Matemática

# %%
df_prof_mt['qtd_preenchido'] = df_prof_mt.apply(lambda x: x.isnull().sum(), axis = 1 )
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof_mt.head(10))
# Out:
#     ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 4    11025620          NaN            D            A            F
# 10   11024828            B            D            B            F
# 14   11025638            A            C            B            F
# 17   11025310            A            D            B            F
# 18   11024968            B            C            A            F
# 21   11025638            A            E            B            H
# 24   11024666            B            C            C            F
# 25   11024682            B            D            B            F
# 29   11025352            B            D            A            F
# 39   11006889            B            B            F            F
#
#    TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  \
# 4             C            C            B            C            D
# 10            C            B            D            C            E
# 14            C            C            B            A            A
# 17            B            B            D            C            D
# 18            C            C            C            A            A
# 21            E            B            B            C            E
# 24            B            B            D            C            E
# 25            B            B            B            C            E
# 29            C            C            B            C            D
# 39            B            B            B            C            D
#
#    TX_RESP_Q010 TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014  \
# 4             F            C            F            F            E
# 10            B            C            D            E            D
# 14            G            C            G            F            F
# 17            E            C            E            E            D
# 18            G            B            H            F            D
# 21            H            B            J            G            G
# 24            D            A            F            D            A
# 25            G            B            H            C            C
# 29            I            A            I            G            B
# 39            E            C            E            D            C
#
#    TX_RESP_Q015 TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019  \
# 4             C            A            B            A            A
# 10            D            A            C            A            C
# 14            E            A            A            A            B
# 17            D            A            B            A            B
# 18            D            A            B            A            B
# 21            C            A            D            B            B
# 24            A            A            C            B            B
# 25            C            A            B            A            B
# 29            D            A            D            B            A
# 39            C            A            B            A            B
#
#    TX_RESP_Q020 TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024  \
# 4             B            B            B            B            A
# 10            B            B            B            B            B
# 14            C            C            C            A            A
# 17            B            D            D            D            D
# 18            C            A            A            A            A
# 21            B            A            C            C            C
# 24            B            C            C            D            B
# 25            C            A            C            A            C
# 29            B            A            C            A            A
# 39            C            B            A            D            C
#
#    TX_RESP_Q025 TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029  \
# 4             A            C            B            C            B
# 10            B            C            D            C            B
# 14            A            C            B            B            B
# 17            B            A            A            A            A
# 18            A            C            B            B            A
# 21            A            D            C            B            B
# 24            B            B            C            C            B
# 25            A            C            D            D            D
# 29            A            C            C            B            B
# 39            A            B            B            A            A
#
#    TX_RESP_Q030 TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034  \
# 4             C            D            D            B            B
# 10            A            B            D            B            B
# 14            C            C            D            B            B
# 17            A            B            B            B            C
# 18            B            D            D            B            B
# 21            C            D            D            B            C
# 24            C            A            D            B            C
# 25            D            C            D            B            B
# 29            A            B            D            A            B
# 39            B            B            D            B            A
#
#    TX_RESP_Q035 TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039  \
# 4             B            B            C            A            A
# 10            B            B            B            B            B
# 14            B            B            B            B            B
# 17            B            B            C            B            B
# 18            B            B            C            B            B
# 21            C            C            B            B            A
# 24            B            B            B            B            B
# 25            B            B            C            C            C
# 29            B            B            C            B            A
# 39            C            B            A            B            C
#
#    TX_RESP_Q040 TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044  \
# 4             B            A            A            A            A
# 10            C            A            A            A            C
# 14            C            B            A            A            C
# 17            C            B            A            B            C
# 18            B            A            A            A            C
# 21            C            B            A            A            C
# 24            C            B            A            B            C
# 25            C            A            A            A            C
# 29            B            A            A            A            A
# 39            C            B            B            B            C
#
#    TX_RESP_Q045 TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049  \
# 4             B            C            B            C            C
# 10            C            C            B            D            D
# 14            C            C            B            C            C
# 17            C            C            D            C            C
# 18            B            B            B            D            B
# 21            B            C            B            D            B
# 24            B            C            C            D            C
# 25            B            C            C            D            C
# 29            C            C            C            C            A
# 39            B            C            C            D            D
#
#    TX_RESP_Q050 TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054  \
# 4             C            F            E            B            A
# 10            D            C            C            B            A
# 14            B            F            E            B            C
# 17            C            F            E            B            C
# 18            C            F            D            A            B
# 21            D            F            E            B            E
# 24            D            F            E            B            C
# 25            C            F            E            B            D
# 29            A            D            E            A            A
# 39            D            F            D            B            E
#
#    TX_RESP_Q055 TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059  \
# 4             B            D            C            D            D
# 10            A            C            B            B            B
# 14            B            C            B            B          NaN
# 17            C            C            C            C            C
# 18            A            B            A            B            B
# 21            D            C            B            C            C
# 24            B            C            C            B            B
# 25            D            E            C            C            D
# 29            A            C            B            B            B
# 39            C            E            B            C            C
#
#    TX_RESP_Q060 TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064  \
# 4             C            C            D            D            B
# 10            B            C            C            C            A
# 14            D            D            D            D            B
# 17            C            C            C            C            C
# 18            B            B            B            B            A
# 21            C            C            C            D            D
# 24            B            C            C            C            C
# 25            C            D            D            D            C
# 29            B            B            C            C            B
# 39            B            C            D            D            B
#
#    TX_RESP_Q065 TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069  \
# 4             C            D            D            C            D
# 10            B            D            B            C            C
# 14            B            D            D            D            D
# 17            C            C            C            C            C
# 18            A            D            B            B            B
# 21            D            D            D            C            D
# 24            C            D            D            C            B
# 25            C            C            C            C            C
# 29            A            D            C            B            B
# 39            C            D            D            D            C
#
#    TX_RESP_Q070 TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074  \
# 4             B            B            A            B            A
# 10            A            B            B            A            A
# 14            B            B            A            B            B
# 17            B            B            B            B            B
# 18            B            B            B            B            A
# 21            B            B            B            A            A
# 24            A            B            B            B            A
# 25            B            B            B            B            A
# 29            A            B            A            B            A
# 39            A            B            B            A            B
#
#    TX_RESP_Q075 TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079  \
# 4             A            A            A            A            A
# 10            A            A            A            A            A
# 14            A            B            B            A            A
# 17            B            A            A            A            A
# 18            A            A            A            A            A
# 21            A            B            B            A            B
# 24            A            B            A            A            B
# 25            A            A            A            A            A
# 29            B            A            B            A            A
# 39            B            A            A            A            A
#
#    TX_RESP_Q080 TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084  \
# 4             A            A            B            B            A
# 10            A            A            B            B          NaN
# 14            A            B            B            A            A
# 17            A            A            B            B            A
# 18            A            A            B            A            A
# 21            A            A            A            B            B
# 24            A            A            B            A            A
# 25            A            A            B            A            A
# 29            A            A            B            B            A
# 39            A            A            A            B            A
#
#    TX_RESP_Q085 TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089  \
# 4             B            B            B            B            B
# 10            B            B            B            B            B
# 14            B            B            B            B            B
# 17            B            B            B            B            B
# 18            B            B            A            A            A
# 21            B            B            B            B            B
# 24            B            B            B            B            B
# 25            B            B            B            B            B
# 29            B            B            B            B            B
# 39            B            B            B            B            B
#
#    TX_RESP_Q090 TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094  \
# 4             B            B            B          NaN            D
# 10            B            B            B            D            D
# 14            B            B            B          NaN            B
# 17            B            B            B            D            D
# 18            A            A            A          NaN            D
# 21            B            B            B          NaN            D
# 24            B            B            B          NaN            D
# 25            B            B            B          NaN            D
# 29            B            B            B          NaN            D
# 39            A            B            B          NaN            C
#
#    TX_RESP_Q095 TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099  \
# 4             C            B            A            A            E
# 10            D            B            A            A            E
# 14            B            A            A            A            E
# 17            D            D            A            A            E
# 18            C            C            A            A            E
# 21            D            C            A            A            E
# 24            D            C            B            C            E
# 25            D            C            B            C            E
# 29            C            B            A            C            E
# 39            C            B            A            A            E
#
#    TX_RESP_Q100 TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104  \
# 4             A            D            A            D            F
# 10            A            D            A            E            E
# 14            A            D            A            A            F
# 17            A            E            A            A            D
# 18            A            C            A            C            D
# 21            A            D            A            A            F
# 24            A            C            A            A            F
# 25            A            D            A            C            E
# 29            A            D            A            A            F
# 39            A            D            A            C            E
#
#    TX_RESP_Q105 TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109  \
# 4             B            E            F            F            D
# 10            B            D            E            F            F
# 14            B            E            F            F            E
# 17            B            E            E            E            E
# 18            B            E            D            B            D
# 21            B            D            E            E            E
# 24            B            E            E            F            E
# 25            B            E            E            E            D
# 29            B            D            E            E            D
# 39            B            E            F            F            D
#
#    TX_RESP_Q110 TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114  \
# 4             B            A            A            D          NaN
# 10            D            F            F            F            F
# 14            D            F            E            F          NaN
# 17            B            E            E            E          NaN
# 18            C            D            E            E            A
# 21            D            E            E            E          NaN
# 24            C            F            F            F            D
# 25            C            E            D            D          NaN
# 29            C            F            D            C          NaN
# 39            C            F            F            F          NaN
#
#    TX_RESP_Q115 TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119  \
# 4           NaN          NaN          NaN          NaN          NaN
# 10            F            F            F            F            F
# 14          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18            A            A            A            A          NaN
# 21          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25          NaN          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN          NaN
# 39          NaN          NaN          NaN          NaN          NaN
#
#    TX_RESP_Q120 TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124  \
# 4             F            F            E            D            F
# 10          NaN          NaN          NaN          NaN          NaN
# 14            F            F            F            D            F
# 17            E            E            E            D            E
# 18            E            E            E            D            E
# 21            E            E            E            D            E
# 24            F            F            F            D            F
# 25            F            F            E            D            E
# 29            F            F            F            C            E
# 39            F            F            F            E            F
#
#    TX_RESP_Q125  qtd_preenchido
# 4             D               8
# 10          NaN               7
# 14            D               8
# 17            D               6
# 18            D               2
# 21            E               7
# 24            F               6
# 25            D               7
# 29            C               7
# 39            D               7

# %%
df_prof_mt.sort_values(by=['ID_ESCOLA', 'qtd_preenchido'], ascending=[True,True], inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof_mt.head(20))
# Out:
#       ID_ESCOLA TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004  \
# 854    11000260            A            B            B            F
# 870    11000317            B            D            A            F
# 1288   11000317            B            D            A            I
# 851    11000368          NaN          NaN          NaN          NaN
# 850    11000376            B            D            A            H
# 1265   11000376            B            D            A            H
# 1253   11000384            A            F            B            I
# 846    11000457            A            F            A            H
# 1255   11000457            A            F            A            H
# 1320   11000554            A            D            B            F
# 872    11000597            B            D            B            F
# 874    11000678            B            C            B            H
# 1262   11000678            B            D            A            F
# 1203   11000708            A            B            C            F
# 1036   11000708            B            D            B            F
# 1306   11000848            A            D            A            F
# 1135   11000856            A            E            B            F
# 885    11000856            A            D            A            F
# 922    11000856            A            D            A            F
# 1198   11000856            A            D            A            F
#
#      TX_RESP_Q005 TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009  \
# 854             E            C            B            A            A
# 870             C            C            B            C            D
# 1288            E            B            B            C            E
# 851           NaN          NaN          NaN          NaN          NaN
# 850             D            B            B            A          NaN
# 1265            D            B            B            A            A
# 1253            E            C            B            D            F
# 846             B            B            B            C            A
# 1255            C            B            B            C            A
# 1320            B            C            B          NaN          NaN
# 872             C            C            B            A            A
# 874             C            C            B            C            D
# 1262            E            C            B            C            D
# 1203            B            C            B            A            A
# 1036            D            C            B            C            D
# 1306            C            C            B            A            A
# 1135            D            C            B            A            A
# 885             B            C            B            C            D
# 922             B            C            B            C            D
# 1198            B            C            B            C            D
#
#      TX_RESP_Q010 TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014  \
# 854             B            B            C            C            B
# 870             H            C            F            G            A
# 1288            H            B            K            G            A
# 851           NaN          NaN          NaN          NaN          NaN
# 850             F            C            H            G            D
# 1265            I            C            I            G            D
# 1253            E            C            E            F            D
# 846             E            B            I            G            G
# 1255            E            B            I            G            E
# 1320            I            A            I            D            D
# 872             F            C            F            G            F
# 874             H            C            H            E            E
# 1262            H            B          NaN            G            F
# 1203            H            C            H            C            C
# 1036            G            C            G            G            E
# 1306            F            A            G            D            C
# 1135            G            C            G            G            A
# 885             G            C            H            F            F
# 922             G            C            H            F            F
# 1198            G            C            H            F            F
#
#      TX_RESP_Q015 TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019  \
# 854             A            D            C            A            C
# 870             E            A            B            A            B
# 1288            G            A            B            A            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             F            A            B            A            B
# 1265            D            A            B            A            B
# 1253            C            B            B            A            B
# 846             D            B            B            A            B
# 1255            F            B            A            A            A
# 1320            B            A            B            B            A
# 872             D            A            B            A            B
# 874             A            A            B            A            B
# 1262            E            A            B            A            B
# 1203            C            B            B            B            A
# 1036            E            A            B            A            B
# 1306            B            B            D            C            A
# 1135            A            A            B            B            C
# 885             F            A            B            A            B
# 922             F            A            B            A            B
# 1198            F            A            B            A            B
#
#      TX_RESP_Q020 TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024  \
# 854             B            A            A            A            A
# 870             B            B            B            A            A
# 1288            A            D            A            C            D
# 851           NaN          NaN          NaN          NaN          NaN
# 850             B            B            A            A            A
# 1265            B            B            A            A            A
# 1253            C            C            C            A            A
# 846             C            E            E            E            E
# 1255            C            E            E            E            E
# 1320            C            D            A            D            A
# 872             B            D            D            D            D
# 874             C            C            D            A            A
# 1262            B            C            A            A            A
# 1203            C            D            C            A            A
# 1036            C            B            B            A            A
# 1306            B            C            C            A            A
# 1135            C            E            E            A            A
# 885             C            C            C            D            C
# 922             C            C            C            D            C
# 1198            C            C            C            D            C
#
#      TX_RESP_Q025 TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029  \
# 854             A            B            A            A            B
# 870             A            C            A            C            A
# 1288            A            B            D            D            D
# 851           NaN          NaN          NaN          NaN          NaN
# 850           NaN          NaN            D            D            D
# 1265          NaN            B            B            B            B
# 1253            A            C            A            B            B
# 846             A            A            C            C            C
# 1255            A            D            D            D            D
# 1320            A            C            A            B            B
# 872             B            C            D            D            D
# 874             A            C            C            D            C
# 1262            A            B            A            B            B
# 1203            A            D            D            D            D
# 1036            A            A            A            A            A
# 1306            A            C            C            C            C
# 1135            C            C            C            D            D
# 885             B            A            A            A            A
# 922             B            A            A            A            A
# 1198            B            A            A            A            A
#
#      TX_RESP_Q030 TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034  \
# 854             B            B            D            B            C
# 870             A            D            C            B            B
# 1288            B            D            C            B            A
# 851           NaN          NaN          NaN          NaN          NaN
# 850             D            D            D            B            C
# 1265            B            B            B            B            C
# 1253            B            B            D            B            C
# 846             C            C            A            B            C
# 1255            D            D            D            B            C
# 1320            C            B            C            A            A
# 872             D            D            D            B            B
# 874             D            C            D            B            C
# 1262            B            C            B            B            B
# 1203            D            D            D            B            C
# 1036            C            D            D            B            A
# 1306            C            D            D            B            C
# 1135            C            D            D            B            C
# 885             A            A            A            A            B
# 922             A            A            A            A            B
# 1198            A            A            A            A            B
#
#      TX_RESP_Q035 TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039  \
# 854             C            C            B            B            B
# 870             C            C            C            B            A
# 1288            C            C            C            C            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             C            C            C            B            B
# 1265            C            C            C            B            B
# 1253            C            C            C            C            C
# 846             C            C            C            C            C
# 1255            B            B            C            C            C
# 1320            C            C            C            C            B
# 872             C            C            B            C            B
# 874             C            C            B            B            B
# 1262            B            B            C            B            B
# 1203            C            B            B            B            C
# 1036            C            C            C            C          NaN
# 1306            C            B            C            B            B
# 1135            B            B            B            C            C
# 885             B            B            B            C            C
# 922             B            B            B            C            C
# 1198            B            B            B            C            C
#
#      TX_RESP_Q040 TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044  \
# 854             C            B            B            A            C
# 870             B            A            B            A            C
# 1288            C            A            B            A            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             B            B            B            A            C
# 1265            B            B            B            B            C
# 1253            C            C            B            B            C
# 846             C            C            B            B            C
# 1255            C            C            B            C            C
# 1320            C            A            A            A            C
# 872             C            A            C            C            D
# 874             B            A            A            A            C
# 1262            C            A            B            B            C
# 1203            C            B            B            B            C
# 1036          NaN            A            A            B            C
# 1306            A            B            B            A            C
# 1135            C            B            C            C            D
# 885             C            C            C            C            C
# 922             C            C            C            C            C
# 1198            C            C            C            C            C
#
#      TX_RESP_Q045 TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049  \
# 854             C            C            C            D            C
# 870             B            B            B            C            B
# 1288            D            C            A            D            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             C            C            C            C            C
# 1265            C            C            C            C            C
# 1253            C            C            C            D            C
# 846             D            C            C            C            C
# 1255            C            C            C            D            C
# 1320            C            C            C            D            D
# 872             D            C            C            D            D
# 874             A            B            B            D            B
# 1262            B            C            B            C            A
# 1203            C            D            D            D            D
# 1036            C            B            C            D            B
# 1306            C            C            C            D            C
# 1135            C            B            C            D            B
# 885             C            A            A            A            C
# 922             C            A            A            A            C
# 1198            C            A            A            A            C
#
#      TX_RESP_Q050 TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054  \
# 854             C            D            E            B            B
# 870             C            A            E            A            A
# 1288            C            F            E            B            B
# 851           NaN          NaN          NaN          NaN          NaN
# 850           NaN            F            D            B            B
# 1265            C            D            E            B            D
# 1253            D            F            E            B            B
# 846             C            F            D            B            E
# 1255            D            F            D            C            D
# 1320            C            F            C            B            E
# 872             D            H            E            B            D
# 874             B            H            E          NaN            C
# 1262            C          NaN            E            C            C
# 1203            D            E            B            B            E
# 1036            B            F            B            C            D
# 1306            C            F            D            B            C
# 1135            B            H            D            B            D
# 885             C            F            D            C            A
# 922             C            F            D            C            A
# 1198            C            F            D            C            A
#
#      TX_RESP_Q055 TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059  \
# 854             B            B            B            C            C
# 870             C            E            C            B            D
# 1288            C            C            C            C            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             A            C            B            C            C
# 1265            A            C            A            B            B
# 1253            B            C            B            B            B
# 846             E            E            E            C            C
# 1255            B            E            D            C            C
# 1320            C            E            C            C            C
# 872             C            E            D            C            D
# 874             C            C            C            D            D
# 1262            C            C            C            C            D
# 1203            D            E            D            C            C
# 1036            C            D            C            B            D
# 1306            C            C            C            C            C
# 1135            C            D            C            D            D
# 885             C            C            C            D            D
# 922             C            C            C            D            D
# 1198            C            C            C            D            D
#
#      TX_RESP_Q060 TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064  \
# 854             C            C            C            C            C
# 870             B            D            C            C            D
# 1288            B            C            C            C            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             C            C            C            C            C
# 1265            B            B            B            B            B
# 1253            B            C            B            C            B
# 846             B            C            C            C            C
# 1255            A            B            C            C            A
# 1320            C            D            D            D            B
# 872             C            C            C            C            B
# 874             B            C            D            D            C
# 1262            C            C            C            D            D
# 1203            D            D            C            C            B
# 1036            C            B            D            D            B
# 1306            C            C            D            D            C
# 1135            D            D            D            D            D
# 885             D            D            D            D            D
# 922             D            D            D            D            D
# 1198            D            D            D            D            D
#
#      TX_RESP_Q065 TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069  \
# 854             C            C            C            C            C
# 870             D            D            D            D            B
# 1288            C            D            D            D            C
# 851           NaN          NaN          NaN          NaN          NaN
# 850             C            B            C            B            B
# 1265            B            B            B            B            B
# 1253            B            C            D            C            B
# 846             C            C            C            C            C
# 1255            A            B            A            C            C
# 1320            D            D            D            C            B
# 872             C            C            C            C            C
# 874             D            D            D            D            C
# 1262            D            D            D            D            D
# 1203            B            D            D            D            D
# 1036            A            D            D            C            C
# 1306            D            D            D            D            C
# 1135            D            D            D            D            D
# 885             D            D            D            D            D
# 922             D            D            D            D            D
# 1198            D            D            D            D            D
#
#      TX_RESP_Q070 TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074  \
# 854             B            B            B            A            A
# 870             B            B            B            B            B
# 1288            B            B            B            B            B
# 851             B            B            B            B            B
# 850             B            B            B            A            A
# 1265            B            B            B            A            A
# 1253            A            B            B            A            A
# 846             B            B            B            B            A
# 1255            A            A            A            A            A
# 1320            B            B            B            B            A
# 872             A            B            B            A            B
# 874             A            B            B            A            B
# 1262            B            B            B            B            A
# 1203            A            B            B            B            A
# 1036            B            B            A            A            A
# 1306            B            B            B            B            B
# 1135            A            B            B            B            B
# 885             A            B            B            B            B
# 922             B            A            B            B            B
# 1198            A            B            B            B            B
#
#      TX_RESP_Q075 TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079  \
# 854             A            B            A            A            A
# 870             B            B            B            A            A
# 1288            B            A            A            A            A
# 851             A            A            A            A            A
# 850             A            A            A            A            A
# 1265            A            A            A            A            A
# 1253            B            A            A            A            A
# 846             B            A            A            A            B
# 1255            A            A            A            A            A
# 1320            B            B            A            A            B
# 872             A            A            A            A            A
# 874             B            A            A            A            A
# 1262            B            A            B            A            A
# 1203            B            A            A            A            B
# 1036            A            A            A            A            A
# 1306            B            B            B            A            A
# 1135            B            B            A            A            B
# 885             B            B            A            A            B
# 922             B            B            B            A            B
# 1198            B            B            A            A            B
#
#      TX_RESP_Q080 TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084  \
# 854             A            A            B            B            B
# 870             A            A            A            A            A
# 1288            A            A            A            B            B
# 851             A            A            A            B            B
# 850             A            A            A            A            A
# 1265            A            A            A            B            B
# 1253            A            A            B            B            B
# 846             A            A            A            A            A
# 1255            A            A            A            A            A
# 1320            A            A            A            A            A
# 872             A            A            A            A            A
# 874             A            A            A            B            A
# 1262            A            A            A            A            A
# 1203            A            A            A            B            B
# 1036            A            A            A            A            A
# 1306            A            A            B            B            A
# 1135            B            B            B            A            A
# 885             B            B            B            A            A
# 922             B            B            B            A            A
# 1198            B            B            B            A            A
#
#      TX_RESP_Q085 TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089  \
# 854             B            B            B            B            B
# 870             B            B            B            B            B
# 1288            B            B            B            B            B
# 851             B            B            B            B            B
# 850             B            B            B            B            B
# 1265            B            B            B            B            B
# 1253            B            B            B            B            B
# 846             A            A            B            B            B
# 1255            B            A            B            B            B
# 1320            B            B            B            B            B
# 872             B            B            B            B            B
# 874             B            B            A            B            B
# 1262            B            A            B            B            B
# 1203            B            B            B            B            B
# 1036            B            B            B            B            A
# 1306            B            B            B            B            B
# 1135            B            A            A            B            B
# 885             B            B            B            B            B
# 922             B            B            B            B            B
# 1198            B            B            B            B            B
#
#      TX_RESP_Q090 TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094  \
# 854             B            B            B          NaN            D
# 870             B            B            B          NaN            D
# 1288            B            B            B          NaN            D
# 851             B            B            B          NaN            D
# 850             A            B            B          NaN            D
# 1265            B            B            B          NaN            D
# 1253            B            B            B            D            D
# 846             B            B            B          NaN            B
# 1255            B            B            B          NaN            D
# 1320            B            B            B          NaN            D
# 872             B            B            B          NaN            D
# 874             B            B            B          NaN            C
# 1262            A            B            B          NaN            C
# 1203            A            B            B          NaN            D
# 1036            A            B            B            D            C
# 1306            B            B            B          NaN            D
# 1135            B            B            B          NaN            D
# 885             B            B            B          NaN          NaN
# 922             B            B            B          NaN          NaN
# 1198            B            B            B          NaN          NaN
#
#      TX_RESP_Q095 TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099  \
# 854             D            D            B            A            E
# 870             D            C            B            C            E
# 1288            D            B            A            A            E
# 851             D            B            A            A            D
# 850             D            C            A            A            D
# 1265            D            D            A            A            D
# 1253            D            C            A            A            D
# 846             A            A            A            A            E
# 1255            D            B            A            A            E
# 1320            D            C            A            A            E
# 872             D            B            A            A            E
# 874             C            C            A            A            E
# 1262            D            B            A            B            E
# 1203            D            C            A            A            E
# 1036            A            A            A            A            D
# 1306            D            C            A            A            E
# 1135            D            A          NaN            A            E
# 885           NaN          NaN            A            C            E
# 922           NaN          NaN            A            C            E
# 1198          NaN          NaN            A            C            E
#
#      TX_RESP_Q100 TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104  \
# 854             A            D            B            A            D
# 870             C            D            A            A            F
# 1288            A            D            A            E            C
# 851             A            D            C            A            E
# 850             A            B            A            E            F
# 1265            A            D            A            E            E
# 1253            A            C            B            B            E
# 846             A            C            A            B            D
# 1255            A            C            A            B            D
# 1320            A            D            A            A            F
# 872             A            D            A            B            D
# 874             A            E            B            B            E
# 1262            A            D            A            B            F
# 1203            A            D            B            B            D
# 1036            A            D            A            B            F
# 1306            A            E            A            B            F
# 1135            A            E            A            C            D
# 885             A            C            A            A            E
# 922             A            C            A            A            E
# 1198            A            C            A            A            E
#
#      TX_RESP_Q105 TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109  \
# 854             B            D            F            F            E
# 870             B            D            F            F            E
# 1288            B            D          NaN            F            F
# 851             B            E            E            F            D
# 850             B          NaN            C            F            F
# 1265            B            E            F            F            F
# 1253            B            E            D            D            E
# 846             B            C            C            C            E
# 1255            B            C            E            E            E
# 1320            B            D            E            E            E
# 872             B            D            E            F            D
# 874             B            D            F            F            D
# 1262            B            E          NaN            F            D
# 1203            B            C            E            E            E
# 1036            B            C            F            F            D
# 1306            B            E            F            E            D
# 1135            B            D            E            E            F
# 885             B            D            E            E            D
# 922             B            D            E            E            D
# 1198            B            D            E            E            D
#
#      TX_RESP_Q110 TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114  \
# 854             D            D            F            F            C
# 870             C            F            F            E          NaN
# 1288            C            F            F            B          NaN
# 851             B            E            D            E          NaN
# 850             D            F            F            F            E
# 1265            F            F            F            F          NaN
# 1253            E            D            D            E          NaN
# 846             C            D            F            F            D
# 1255            D            E            E            E            C
# 1320            C            E            E            E          NaN
# 872             D            F            F            F          NaN
# 874             C            E            F            F          NaN
# 1262            C            F            F            F          NaN
# 1203            E            E            F            F            D
# 1036            D            F            D            F          NaN
# 1306            D            E            C            C          NaN
# 1135            C            F            F            F          NaN
# 885             D            D            F            F          NaN
# 922             D            D            F            F          NaN
# 1198            D            D            F            F          NaN
#
#      TX_RESP_Q115 TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119  \
# 854           NaN          NaN          NaN          NaN          NaN
# 870           NaN          NaN          NaN          NaN          NaN
# 1288          NaN          NaN          NaN          NaN          NaN
# 851           NaN          NaN          NaN          NaN          NaN
# 850             E            E            E            E            E
# 1265          NaN          NaN          NaN          NaN          NaN
# 1253          NaN          NaN          NaN          NaN          NaN
# 846             E            E            D            E            E
# 1255            D            C            C            C            C
# 1320          NaN          NaN          NaN          NaN          NaN
# 872           NaN          NaN          NaN          NaN          NaN
# 874           NaN          NaN          NaN          NaN          NaN
# 1262          NaN          NaN          NaN          NaN          NaN
# 1203            A          NaN          NaN          NaN          NaN
# 1036          NaN          NaN          NaN          NaN          NaN
# 1306          NaN          NaN          NaN          NaN          NaN
# 1135          NaN          NaN          NaN          NaN          NaN
# 885           NaN          NaN          NaN          NaN          NaN
# 922           NaN          NaN          NaN          NaN          NaN
# 1198          NaN          NaN          NaN          NaN          NaN
#
#      TX_RESP_Q120 TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124  \
# 854             F            F            F            E            F
# 870             F            F            F            E            F
# 1288            F            F            F            D            D
# 851             F            F            F            B            E
# 850             F            F            F            E            F
# 1265            F            F            F            F            F
# 1253            E            E            E            C            E
# 846             F            F            E            E            E
# 1255            E            F            F            F            F
# 1320            E            E            E            E            E
# 872             F            F            F            D            F
# 874             F            F            F            D            F
# 1262            F            F            F            E            F
# 1203            E            E            F            F            E
# 1036            F            F            F            E            F
# 1306            F            F            E            C            E
# 1135            F            F            F            E            F
# 885             F            F            F            E            F
# 922             F            F            F            E            F
# 1198            F            F            F            E            F
#
#      TX_RESP_Q125  qtd_preenchido
# 854             D               6
# 870             D               7
# 1288            C               8
# 851             C              76
# 850             F               6
# 1265            F               8
# 1253            D               6
# 846             E               1
# 1255            F               1
# 1320            E               9
# 872             D               7
# 874             D               8
# 1262            D              10
# 1203            E               5
# 1036            D               8
# 1306            C               7
# 1135            D               8
# 885             F              10
# 922             F              10
# 1198            F              10

# %%
df_prof_mt_final = df_prof_mt.drop_duplicates(subset=['ID_ESCOLA'])
df_prof_mt_final.set_index('ID_ESCOLA', inplace=True)
df_prof_mt_final.drop(columns='qtd_preenchido', inplace=True)
df_prof_mt_final.shape
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# (27690, 125)

# %%
with pd.option_context("display.max_rows", 165, "display.max_columns", 165):
    display(df_prof_mt_final.head(10))
# Out:
#           TX_RESP_Q001 TX_RESP_Q002 TX_RESP_Q003 TX_RESP_Q004 TX_RESP_Q005  \
# ID_ESCOLA
# 11000260             A            B            B            F            E
# 11000317             B            D            A            F            C
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             B            D            A            H            D
# 11000384             A            F            B            I            E
# 11000457             A            F            A            H            B
# 11000554             A            D            B            F            B
# 11000597             B            D            B            F            C
# 11000678             B            C            B            H            C
# 11000708             A            B            C            F            B
#
#           TX_RESP_Q006 TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010  \
# ID_ESCOLA
# 11000260             C            B            A            A            B
# 11000317             C            B            C            D            H
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             B            B            A          NaN            F
# 11000384             C            B            D            F            E
# 11000457             B            B            C            A            E
# 11000554             C            B          NaN          NaN            I
# 11000597             C            B            A            A            F
# 11000678             C            B            C            D            H
# 11000708             C            B            A            A            H
#
#           TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015  \
# ID_ESCOLA
# 11000260             B            C            C            B            A
# 11000317             C            F            G            A            E
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             C            H            G            D            F
# 11000384             C            E            F            D            C
# 11000457             B            I            G            G            D
# 11000554             A            I            D            D            B
# 11000597             C            F            G            F            D
# 11000678             C            H            E            E            A
# 11000708             C            H            C            C            C
#
#           TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020  \
# ID_ESCOLA
# 11000260             D            C            A            C            B
# 11000317             A            B            A            B            B
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             A            B            A            B            B
# 11000384             B            B            A            B            C
# 11000457             B            B            A            B            C
# 11000554             A            B            B            A            C
# 11000597             A            B            A            B            B
# 11000678             A            B            A            B            C
# 11000708             B            B            B            A            C
#
#           TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025  \
# ID_ESCOLA
# 11000260             A            A            A            A            A
# 11000317             B            B            A            A            A
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             B            A            A            A          NaN
# 11000384             C            C            A            A            A
# 11000457             E            E            E            E            A
# 11000554             D            A            D            A            A
# 11000597             D            D            D            D            B
# 11000678             C            D            A            A            A
# 11000708             D            C            A            A            A
#
#           TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030  \
# ID_ESCOLA
# 11000260             B            A            A            B            B
# 11000317             C            A            C            A            A
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376           NaN            D            D            D            D
# 11000384             C            A            B            B            B
# 11000457             A            C            C            C            C
# 11000554             C            A            B            B            C
# 11000597             C            D            D            D            D
# 11000678             C            C            D            C            D
# 11000708             D            D            D            D            D
#
#           TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035  \
# ID_ESCOLA
# 11000260             B            D            B            C            C
# 11000317             D            C            B            B            C
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             D            D            B            C            C
# 11000384             B            D            B            C            C
# 11000457             C            A            B            C            C
# 11000554             B            C            A            A            C
# 11000597             D            D            B            B            C
# 11000678             C            D            B            C            C
# 11000708             D            D            B            C            C
#
#           TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040  \
# ID_ESCOLA
# 11000260             C            B            B            B            C
# 11000317             C            C            B            A            B
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             C            C            B            B            B
# 11000384             C            C            C            C            C
# 11000457             C            C            C            C            C
# 11000554             C            C            C            B            C
# 11000597             C            B            C            B            C
# 11000678             C            B            B            B            B
# 11000708             B            B            B            C            C
#
#           TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045  \
# ID_ESCOLA
# 11000260             B            B            A            C            C
# 11000317             A            B            A            C            B
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             B            B            A            C            C
# 11000384             C            B            B            C            C
# 11000457             C            B            B            C            D
# 11000554             A            A            A            C            C
# 11000597             A            C            C            D            D
# 11000678             A            A            A            C            A
# 11000708             B            B            B            C            C
#
#           TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050  \
# ID_ESCOLA
# 11000260             C            C            D            C            C
# 11000317             B            B            C            B            C
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             C            C            C            C          NaN
# 11000384             C            C            D            C            D
# 11000457             C            C            C            C            C
# 11000554             C            C            D            D            C
# 11000597             C            C            D            D            D
# 11000678             B            B            D            B            B
# 11000708             D            D            D            D            D
#
#           TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055  \
# ID_ESCOLA
# 11000260             D            E            B            B            B
# 11000317             A            E            A            A            C
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             F            D            B            B            A
# 11000384             F            E            B            B            B
# 11000457             F            D            B            E            E
# 11000554             F            C            B            E            C
# 11000597             H            E            B            D            C
# 11000678             H            E          NaN            C            C
# 11000708             E            B            B            E            D
#
#           TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060  \
# ID_ESCOLA
# 11000260             B            B            C            C            C
# 11000317             E            C            B            D            B
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             C            B            C            C            C
# 11000384             C            B            B            B            B
# 11000457             E            E            C            C            B
# 11000554             E            C            C            C            C
# 11000597             E            D            C            D            C
# 11000678             C            C            D            D            B
# 11000708             E            D            C            C            D
#
#           TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065  \
# ID_ESCOLA
# 11000260             C            C            C            C            C
# 11000317             D            C            C            D            D
# 11000368           NaN          NaN          NaN          NaN          NaN
# 11000376             C            C            C            C            C
# 11000384             C            B            C            B            B
# 11000457             C            C            C            C            C
# 11000554             D            D            D            B            D
# 11000597             C            C            C            B            C
# 11000678             C            D            D            C            D
# 11000708             D            C            C            B            B
#
#           TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070  \
# ID_ESCOLA
# 11000260             C            C            C            C            B
# 11000317             D            D            D            B            B
# 11000368           NaN          NaN          NaN          NaN            B
# 11000376             B            C            B            B            B
# 11000384             C            D            C            B            A
# 11000457             C            C            C            C            B
# 11000554             D            D            C            B            B
# 11000597             C            C            C            C            A
# 11000678             D            D            D            C            A
# 11000708             D            D            D            D            A
#
#           TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074 TX_RESP_Q075  \
# ID_ESCOLA
# 11000260             B            B            A            A            A
# 11000317             B            B            B            B            B
# 11000368             B            B            B            B            A
# 11000376             B            B            A            A            A
# 11000384             B            B            A            A            B
# 11000457             B            B            B            A            B
# 11000554             B            B            B            A            B
# 11000597             B            B            A            B            A
# 11000678             B            B            A            B            B
# 11000708             B            B            B            A            B
#
#           TX_RESP_Q076 TX_RESP_Q077 TX_RESP_Q078 TX_RESP_Q079 TX_RESP_Q080  \
# ID_ESCOLA
# 11000260             B            A            A            A            A
# 11000317             B            B            A            A            A
# 11000368             A            A            A            A            A
# 11000376             A            A            A            A            A
# 11000384             A            A            A            A            A
# 11000457             A            A            A            B            A
# 11000554             B            A            A            B            A
# 11000597             A            A            A            A            A
# 11000678             A            A            A            A            A
# 11000708             A            A            A            B            A
#
#           TX_RESP_Q081 TX_RESP_Q082 TX_RESP_Q083 TX_RESP_Q084 TX_RESP_Q085  \
# ID_ESCOLA
# 11000260             A            B            B            B            B
# 11000317             A            A            A            A            B
# 11000368             A            A            B            B            B
# 11000376             A            A            A            A            B
# 11000384             A            B            B            B            B
# 11000457             A            A            A            A            A
# 11000554             A            A            A            A            B
# 11000597             A            A            A            A            B
# 11000678             A            A            B            A            B
# 11000708             A            A            B            B            B
#
#           TX_RESP_Q086 TX_RESP_Q087 TX_RESP_Q088 TX_RESP_Q089 TX_RESP_Q090  \
# ID_ESCOLA
# 11000260             B            B            B            B            B
# 11000317             B            B            B            B            B
# 11000368             B            B            B            B            B
# 11000376             B            B            B            B            A
# 11000384             B            B            B            B            B
# 11000457             A            B            B            B            B
# 11000554             B            B            B            B            B
# 11000597             B            B            B            B            B
# 11000678             B            A            B            B            B
# 11000708             B            B            B            B            A
#
#           TX_RESP_Q091 TX_RESP_Q092 TX_RESP_Q093 TX_RESP_Q094 TX_RESP_Q095  \
# ID_ESCOLA
# 11000260             B            B          NaN            D            D
# 11000317             B            B          NaN            D            D
# 11000368             B            B          NaN            D            D
# 11000376             B            B          NaN            D            D
# 11000384             B            B            D            D            D
# 11000457             B            B          NaN            B            A
# 11000554             B            B          NaN            D            D
# 11000597             B            B          NaN            D            D
# 11000678             B            B          NaN            C            C
# 11000708             B            B          NaN            D            D
#
#           TX_RESP_Q096 TX_RESP_Q097 TX_RESP_Q098 TX_RESP_Q099 TX_RESP_Q100  \
# ID_ESCOLA
# 11000260             D            B            A            E            A
# 11000317             C            B            C            E            C
# 11000368             B            A            A            D            A
# 11000376             C            A            A            D            A
# 11000384             C            A            A            D            A
# 11000457             A            A            A            E            A
# 11000554             C            A            A            E            A
# 11000597             B            A            A            E            A
# 11000678             C            A            A            E            A
# 11000708             C            A            A            E            A
#
#           TX_RESP_Q101 TX_RESP_Q102 TX_RESP_Q103 TX_RESP_Q104 TX_RESP_Q105  \
# ID_ESCOLA
# 11000260             D            B            A            D            B
# 11000317             D            A            A            F            B
# 11000368             D            C            A            E            B
# 11000376             B            A            E            F            B
# 11000384             C            B            B            E            B
# 11000457             C            A            B            D            B
# 11000554             D            A            A            F            B
# 11000597             D            A            B            D            B
# 11000678             E            B            B            E            B
# 11000708             D            B            B            D            B
#
#           TX_RESP_Q106 TX_RESP_Q107 TX_RESP_Q108 TX_RESP_Q109 TX_RESP_Q110  \
# ID_ESCOLA
# 11000260             D            F            F            E            D
# 11000317             D            F            F            E            C
# 11000368             E            E            F            D            B
# 11000376           NaN            C            F            F            D
# 11000384             E            D            D            E            E
# 11000457             C            C            C            E            C
# 11000554             D            E            E            E            C
# 11000597             D            E            F            D            D
# 11000678             D            F            F            D            C
# 11000708             C            E            E            E            E
#
#           TX_RESP_Q111 TX_RESP_Q112 TX_RESP_Q113 TX_RESP_Q114 TX_RESP_Q115  \
# ID_ESCOLA
# 11000260             D            F            F            C          NaN
# 11000317             F            F            E          NaN          NaN
# 11000368             E            D            E          NaN          NaN
# 11000376             F            F            F            E            E
# 11000384             D            D            E          NaN          NaN
# 11000457             D            F            F            D            E
# 11000554             E            E            E          NaN          NaN
# 11000597             F            F            F          NaN          NaN
# 11000678             E            F            F          NaN          NaN
# 11000708             E            F            F            D            A
#
#           TX_RESP_Q116 TX_RESP_Q117 TX_RESP_Q118 TX_RESP_Q119 TX_RESP_Q120  \
# ID_ESCOLA
# 11000260           NaN          NaN          NaN          NaN            F
# 11000317           NaN          NaN          NaN          NaN            F
# 11000368           NaN          NaN          NaN          NaN            F
# 11000376             E            E            E            E            F
# 11000384           NaN          NaN          NaN          NaN            E
# 11000457             E            D            E            E            F
# 11000554           NaN          NaN          NaN          NaN            E
# 11000597           NaN          NaN          NaN          NaN            F
# 11000678           NaN          NaN          NaN          NaN            F
# 11000708           NaN          NaN          NaN          NaN            E
#
#           TX_RESP_Q121 TX_RESP_Q122 TX_RESP_Q123 TX_RESP_Q124 TX_RESP_Q125
# ID_ESCOLA
# 11000260             F            F            E            F            D
# 11000317             F            F            E            F            D
# 11000368             F            F            B            E            C
# 11000376             F            F            E            F            F
# 11000384             E            E            C            E            D
# 11000457             F            E            E            E            E
# 11000554             E            E            E            E            E
# 11000597             F            F            D            F            D
# 11000678             F            F            D            F            D
# 11000708             E            F            F            E            E

# %%
df_prof_mt_final.columns = ['PROF_MT_' + x for i, x in enumerate(df_prof_mt_final.columns, 1)]
df_prof_mt_final.head(3)
# Out:
#           PROF_MT_TX_RESP_Q001 PROF_MT_TX_RESP_Q002 PROF_MT_TX_RESP_Q003  \
# ID_ESCOLA
# 11000260                     A                    B                    B
# 11000317                     B                    D                    A
# 11000368                   NaN                  NaN                  NaN
#
#           PROF_MT_TX_RESP_Q004 PROF_MT_TX_RESP_Q005 PROF_MT_TX_RESP_Q006  \
# ID_ESCOLA
# 11000260                     F                    E                    C
# 11000317                     F                    C                    C
# 11000368                   NaN                  NaN                  NaN
#
#           PROF_MT_TX_RESP_Q007 PROF_MT_TX_RESP_Q008 PROF_MT_TX_RESP_Q009  \
# ID_ESCOLA
# 11000260                     B                    A                    A
# 11000317                     B                    C                    D
# 11000368                   NaN                  NaN                  NaN
#
#           PROF_MT_TX_RESP_Q010  ... PROF_MT_TX_RESP_Q116 PROF_MT_TX_RESP_Q117  \
# ID_ESCOLA                       ...
# 11000260                     B  ...                  NaN                  NaN
# 11000317                     H  ...                  NaN                  NaN
# 11000368                   NaN  ...                  NaN                  NaN
#
#           PROF_MT_TX_RESP_Q118 PROF_MT_TX_RESP_Q119 PROF_MT_TX_RESP_Q120  \
# ID_ESCOLA
# 11000260                   NaN                  NaN                    F
# 11000317                   NaN                  NaN                    F
# 11000368                   NaN                  NaN                    F
#
#           PROF_MT_TX_RESP_Q121 PROF_MT_TX_RESP_Q122 PROF_MT_TX_RESP_Q123  \
# ID_ESCOLA
# 11000260                     F                    F                    E
# 11000317                     F                    F                    E
# 11000368                     F                    F                    B
#
#           PROF_MT_TX_RESP_Q124 PROF_MT_TX_RESP_Q125
# ID_ESCOLA
# 11000260                     F                    D
# 11000317                     F                    D
# 11000368                     E                    C
#
# [3 rows x 125 columns]

# %% [markdown]
# Agora vou juntar todas as bases num único dataframe que será minha ABT de 2017.

# %%
df_saeb9_dir = df_saeb9.join(df_diretor)

# %%
df_saeb9_dir.shape
# Out:
# (31776, 210)

# %%
df_saeb9_dir_lp = df_saeb9_dir.join(df_prof_lp_final)

# %%
df_saeb9_dir_lp.shape
# Out:
# (31776, 335)

# %%
df_saeb9_dir_lp_mt = df_saeb9_dir_lp.join(df_prof_mt_final)

# %%
df_saeb9_dir_lp_mt.shape
# Out:
# (31776, 460)

# %%
with pd.option_context("display.max_rows", 50, "display.max_columns", 500):
    display(df_saeb9_dir_lp_mt.head(10))
# Out:
#            ID_PROVA_BRASIL  ID_UF  ID_MUNICIPIO  ID_DEPENDENCIA_ADM  \
# ID_ESCOLA
# 11025638              2013     11       1100015                   2
# 11025352              2013     11       1100015                   3
# 11024828              2013     11       1100015                   3
# 11025310              2013     11       1100015                   3
# 11024968              2013     11       1100015                   2
# 11025620              2013     11       1100015                   2
# 11024666              2013     11       1100015                   3
# 11024682              2013     11       1100015                   2
# 11007885              2013     11       1100023                   2
# 11007281              2013     11       1100023                   2
#
#            ID_LOCALIZACAO  PC_FORMACAO_DOCENTE_FINAL NIVEL_SOCIO_ECONOMICO  \
# ID_ESCOLA
# 11025638                1                       54.1               Grupo 3
# 11025352                2                       34.5               Grupo 3
# 11024828                2                       19.7               Grupo 3
# 11025310                2                       39.7               Grupo 3
# 11024968                1                       38.9               Grupo 4
# 11025620                1                       44.4               Grupo 2
# 11024666                2                       42.2               Grupo 3
# 11024682                1                       72.7               Grupo 4
# 11007885                1                       70.0               Grupo 4
# 11007281                1                       60.6               Grupo 5
#
#            NU_MATRICULADOS_CENSO_9EF  NU_PRESENTES_9EF  TAXA_PARTICIPACAO_9EF  \
# ID_ESCOLA
# 11025638                       113.0              97.0               0.858407
# 11025352                        31.0              25.0               0.806452
# 11024828                        23.0              20.0               0.869565
# 11025310                        34.0              27.0               0.794118
# 11024968                        92.0              66.0               0.717391
# 11025620                        21.0              17.0               0.809524
# 11024666                        26.0              22.0               0.846154
# 11024682                        42.0              39.0               0.928571
# 11007885                        84.0              82.0               0.976190
# 11007281                        34.0              27.0               0.794118
#
#            NIVEL_0_LP9  NIVEL_1_LP9  NIVEL_2_LP9  NIVEL_3_LP9  NIVEL_4_LP9  \
# ID_ESCOLA
# 11025638         33.24        12.14        15.36        16.78        13.16
# 11025352         31.83        20.00        23.66        16.34         4.52
# 11024828         30.00        25.00         5.00        30.00         5.00
# 11025310         34.61        21.37        28.92        10.69         0.00
# 11024968         19.64        15.19        18.36        19.99        17.91
# 11025620          0.00         5.88        17.65        52.94        17.65
# 11024666         27.27        22.73        31.82         9.09         4.55
# 11024682         10.33        17.97        20.46        20.46        25.62
# 11007885         17.19        15.92        17.08        25.38        19.45
# 11007281         22.21        18.53        14.80        22.21        14.80
#
#            NIVEL_5_LP9  NIVEL_6_LP9  NIVEL_7_LP9  NIVEL_8_LP9  NIVEL_0_MT9  \
# ID_ESCOLA
# 11025638          7.22         2.09         0.00          0.0        18.78
# 11025352          3.66         0.00         0.00          0.0        17.20
# 11024828          5.00         0.00         0.00          0.0        35.00
# 11025310          4.41         0.00         0.00          0.0        44.71
# 11024968          4.44         3.05         1.42          0.0        10.96
# 11025620          5.88         0.00         0.00          0.0        11.76
# 11024666          4.55         0.00         0.00          0.0        13.64
# 11024682          5.16         0.00         0.00          0.0         5.16
# 11007885          2.33         1.32         1.32          0.0        10.91
# 11007281          7.45         0.00         0.00          0.0        22.30
#
#            NIVEL_1_MT9  NIVEL_2_MT9  NIVEL_3_MT9  NIVEL_4_MT9  NIVEL_5_MT9  \
# ID_ESCOLA
# 11025638         17.45        17.58        24.62        16.49         1.98
# 11025352          8.17        27.31        35.48         8.17         3.66
# 11024828         15.00         5.00        25.00        20.00         0.00
# 11025310         10.69        12.55        16.96        10.69         0.00
# 11024968         13.23        27.15        21.62        21.36         2.84
# 11025620          5.88        23.53        29.41        17.65        11.76
# 11024666         13.64        40.91        18.18         9.09         4.55
# 11024682         10.33        18.17        30.78        22.55         7.84
# 11007885          6.08        21.83        27.72        22.29         8.67
# 11007281         18.48        22.11        22.25        14.85         0.00
#
#            NIVEL_6_MT9  NIVEL_7_MT9  NIVEL_8_MT9  NIVEL_9_MT9  MEDIA_9EF_LP  \
# ID_ESCOLA
# 11025638          2.03         1.07          0.0          0.0        233.25
# 11025352          0.00         0.00          0.0          0.0        223.29
# 11024828          0.00         0.00          0.0          0.0        228.97
# 11025310          0.00         4.41          0.0          0.0        219.39
# 11024968          0.00         2.84          0.0          0.0        242.93
# 11025620          0.00         0.00          0.0          0.0        261.64
# 11024666          0.00         0.00          0.0          0.0        222.50
# 11024682          5.16         0.00          0.0          0.0        247.24
# 11007885          2.51         0.00          0.0          0.0        242.80
# 11007281          0.00         0.00          0.0          0.0        240.31
#
#            MEDIA_9EF_MT TX_RESP_Q007 TX_RESP_Q008 TX_RESP_Q009 TX_RESP_Q010  \
# ID_ESCOLA
# 11025638         242.78            A            A            C            B
# 11025352         239.49            B            C            C            C
# 11024828         226.35            C            C            B            B
# 11025310         222.39            B            B            B          NaN
# 11024968         250.56            B            A            A            A
# 11025620         255.07            A            A            A            A
# 11024666         238.92          NaN          NaN          NaN          NaN
# 11024682         261.89            A            B            A            A
# 11007885         256.32            A            A            A            A
# 11007281         231.46            A            A            A            A
#
#           TX_RESP_Q011 TX_RESP_Q012 TX_RESP_Q013 TX_RESP_Q014 TX_RESP_Q015  \
# ID_ESCOLA
# 11025638             A            B            C            B            B
# 11025352             C            C            C            C            C
# 11024828             B            C            C            C            C
# 11025310             C            B            B            C            C
# 11024968             A            A            B            B            B
# 11025620             A            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            A            A            B            A
# 11007885             A            A            A            A            A
# 11007281             A            B            B            A            A
#
#           TX_RESP_Q016 TX_RESP_Q017 TX_RESP_Q018 TX_RESP_Q019 TX_RESP_Q020  \
# ID_ESCOLA
# 11025638             B            A            A            C            A
# 11025352             B            B            C            C            B
# 11024828             B            C            B            C            A
# 11025310             B            A            A            B            D
# 11024968             B            B            A            B            B
# 11025620             A            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            B            A            A            B
# 11007885             A            A            A            A            B
# 11007281             B            B            B            A            A
#
#           TX_RESP_Q021 TX_RESP_Q022 TX_RESP_Q023 TX_RESP_Q024 TX_RESP_Q025  \
# ID_ESCOLA
# 11025638             A            A            A            D            D
# 11025352             B            A            A            C            A
# 11024828             A            C            C            D            C
# 11025310             D            A            A            A            D
# 11024968             B            B            B            C            C
# 11025620             A            A            A            A            B
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            A            A            A            D
# 11007885           NaN            A            A            B            B
# 11007281             C            A            A            D            D
#
#           TX_RESP_Q026 TX_RESP_Q027 TX_RESP_Q028 TX_RESP_Q029 TX_RESP_Q030  \
# ID_ESCOLA
# 11025638             D            D            D            D            D
# 11025352             A            C            C            C            C
# 11024828             B            D            D            D            D
# 11025310             A            D            D            D            B
# 11024968             C            C            C            C            B
# 11025620             A            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             D            D            D            B            A
# 11007885           NaN            C            C            C            A
# 11007281             D            B            B            B            B
#
#           TX_RESP_Q031 TX_RESP_Q032 TX_RESP_Q033 TX_RESP_Q034 TX_RESP_Q035  \
# ID_ESCOLA
# 11025638             B            A            A            A            B
# 11025352             C            A            B            A            A
# 11024828             A            B            A            B            B
# 11025310             A            B            A            A            A
# 11024968             B            A            A            B            B
# 11025620             A            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             B            A            A            A            A
# 11007885             A            A            A            A            A
# 11007281             B            A            A            A            A
#
#           TX_RESP_Q036 TX_RESP_Q037 TX_RESP_Q038 TX_RESP_Q039 TX_RESP_Q040  \
# ID_ESCOLA
# 11025638             C            A            B            B            A
# 11025352             B            B            D            B            D
# 11024828             A            B            D            A            A
# 11025310             A            A            D            A            D
# 11024968             B            B            B            B            B
# 11025620             C            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             C            A            A            A            A
# 11007885             B            A            B            A            A
# 11007281             B            B            A            A            B
#
#           TX_RESP_Q041 TX_RESP_Q042 TX_RESP_Q043 TX_RESP_Q044 TX_RESP_Q045  \
# ID_ESCOLA
# 11025638             A            A            D            A            A
# 11025352             A            A            A            A            A
# 11024828             A            A            B            A            A
# 11025310             A            A            A            A            B
# 11024968             A            A            C            B            A
# 11025620             A            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            A            A            D            A
# 11007885             A            A            A            A            A
# 11007281             A            A            A            B            B
#
#           TX_RESP_Q046 TX_RESP_Q047 TX_RESP_Q048 TX_RESP_Q049 TX_RESP_Q050  \
# ID_ESCOLA
# 11025638             A            A            B            A            D
# 11025352             A            A            A            A            C
# 11024828             A            A            A            A            C
# 11025310             A            A            A            A            D
# 11024968             A            A            A            A            D
# 11025620             A            A            A            C            C
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            A            A            A            A
# 11007885             A            A            A            A            A
# 11007281             A            A            A            A            B
#
#           TX_RESP_Q051 TX_RESP_Q052 TX_RESP_Q053 TX_RESP_Q054 TX_RESP_Q055  \
# ID_ESCOLA
# 11025638             A            B            A            A            A
# 11025352             A            C            D            A            D
# 11024828             A            A            D            D            D
# 11025310             A            A            D            A            D
# 11024968             A            B          NaN            A            A
# 11025620             A            A            A            A            D
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            A            A            A            A
# 11007885             A            A            A            A            A
# 11007281             A            A            B            A            A
#
#           TX_RESP_Q056 TX_RESP_Q057 TX_RESP_Q058 TX_RESP_Q059 TX_RESP_Q060  \
# ID_ESCOLA
# 11025638             A            C            A            B            C
# 11025352             D            B            D            A            D
# 11024828             B            B            D            B            D
# 11025310             B            B            D            A            D
# 11024968             A            B            C            A            A
# 11025620             A            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             A            A            D            A            A
# 11007885             A            A            A            A            A
# 11007281             A            A            A            A            A
#
#           TX_RESP_Q061 TX_RESP_Q062 TX_RESP_Q063 TX_RESP_Q064 TX_RESP_Q065  \
# ID_ESCOLA
# 11025638             C            C            D            B            A
# 11025352             D            D            D            D            A
# 11024828             D            D            D            D            B
# 11025310             D            D            D            D            A
# 11024968             A            D            D            D            A
# 11025620             D            D            D            D            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             D            D            D            D            A
# 11007885             A            A            A            A            A
# 11007281             D            A            D            D            A
#
#           TX_RESP_Q066 TX_RESP_Q067 TX_RESP_Q068 TX_RESP_Q069 TX_RESP_Q070  \
# ID_ESCOLA
# 11025638             B            B            A            A            B
# 11025352             B            A            A            A            A
# 11024828             C            C            A            A            B
# 11025310             B            A            A            A            B
# 11024968             B            B            A            A            A
# 11025620             B            A            A            A            A
# 11024666           NaN          NaN          NaN          NaN          NaN
# 11024682             B            B            A            A            A
# 11007885             A            A            A            A            A
# 11007281             A            A            A            A            A
#
#           TX_RESP_Q071 TX_RESP_Q072 TX_RESP_Q073 TX_RESP_Q074  \
# ID_ESCOLA
# 11025638             A            A            A            B
# 11025352             A            A            A            A
# 11024828             B            A            B            B
# 11025310             A            A            A            A
# 11024968             A            A            A            A
# 11025620             A            A            A            C
# 11024666           NaN          NaN          NaN          NaN
# 11024682             A            A            A            C
# 11007885             A            A            A            A
# 11007281             A            A            A            B
#
#           DIRETOR_TX_RESP_Q001 DIRETOR_TX_RESP_Q002 DIRETOR_TX_RESP_Q003  \
# ID_ESCOLA
# 11025638                     B                    D                    A
# 11025352                     B                    C                    A
# 11024828                     B                    E                    A
# 11025310                     B                    C                    B
# 11024968                     B                    E                    B
# 11025620                     B                    D                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     B                    C                    A
# 11007885                     A                    E                    A
# 11007281                     A                    C                    C
#
#           DIRETOR_TX_RESP_Q004 DIRETOR_TX_RESP_Q005 DIRETOR_TX_RESP_Q006  \
# ID_ESCOLA
# 11025638                     G                    C                    C
# 11025352                     F                    C                    C
# 11024828                     D                    D                    B
# 11025310                     D                    B                    B
# 11024968                     G                    C                    C
# 11025620                     G                    C                    C
# 11024666                   NaN                  NaN                  NaN
# 11024682                     D                    C                    B
# 11007885                     D                    D                    C
# 11007281                     D                    C                    C
#
#           DIRETOR_TX_RESP_Q007 DIRETOR_TX_RESP_Q008 DIRETOR_TX_RESP_Q009  \
# ID_ESCOLA
# 11025638                     B                    A                    A
# 11025352                     B                    C                    D
# 11024828                     D                    C                    F
# 11025310                     D                    C                    E
# 11024968                     B                    C                    C
# 11025620                     B                    A                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     B                    C                    E
# 11007885                     C                    C                    E
# 11007281                     B                    C                    E
#
#           DIRETOR_TX_RESP_Q010 DIRETOR_TX_RESP_Q011 DIRETOR_TX_RESP_Q012  \
# ID_ESCOLA
# 11025638                     I                    C                    I
# 11025352                     F                    C                  NaN
# 11024828                     D                    C                    D
# 11025310                     G                    C                    G
# 11024968                     H                    C                    I
# 11025620                     G                    C                    G
# 11024666                   NaN                  NaN                  NaN
# 11024682                     G                    C                  NaN
# 11007885                     J                    A                    K
# 11007281                     I                    C                    I
#
#           DIRETOR_TX_RESP_Q013 DIRETOR_TX_RESP_Q014 DIRETOR_TX_RESP_Q015  \
# ID_ESCOLA
# 11025638                     B                    B                    H
# 11025352                     B                    C                    F
# 11024828                     B                    C                    H
# 11025310                     B                    C                    F
# 11024968                     B                    B                    H
# 11025620                     B                    B                    F
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    B                    D
# 11007885                     A                    B                    F
# 11007281                     B                    C                    F
#
#           DIRETOR_TX_RESP_Q016 DIRETOR_TX_RESP_Q017 DIRETOR_TX_RESP_Q018  \
# ID_ESCOLA
# 11025638                     C                    B                    G
# 11025352                     A                    A                    E
# 11024828                     A                    A                    G
# 11025310                     A                    A                    E
# 11024968                     B                    B                    G
# 11025620                     C                    C                    F
# 11024666                   NaN                  NaN                  NaN
# 11024682                     C                    C                    D
# 11007885                     F                    F                    G
# 11007281                     B                    B                    E
#
#           DIRETOR_TX_RESP_Q019 DIRETOR_TX_RESP_Q020 DIRETOR_TX_RESP_Q021  \
# ID_ESCOLA
# 11025638                     B                    A                    B
# 11025352                     B                    D                    B
# 11024828                     B                    E                    B
# 11025310                     B                    D                    A
# 11024968                     A                    A                    B
# 11025620                     B                    E                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     B                    E                    A
# 11007885                     B                    D                    B
# 11007281                     B                    C                    B
#
#           DIRETOR_TX_RESP_Q022 DIRETOR_TX_RESP_Q023 DIRETOR_TX_RESP_Q024  \
# ID_ESCOLA
# 11025638                     B                    B                    B
# 11025352                     B                    B                    B
# 11024828                     B                    B                    B
# 11025310                     B                    B                    B
# 11024968                     B                    C                    C
# 11025620                     C                    B                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     C                    C                    C
# 11007885                     B                    C                    C
# 11007281                     B                    C                    C
#
#           DIRETOR_TX_RESP_Q025 DIRETOR_TX_RESP_Q026 DIRETOR_TX_RESP_Q027  \
# ID_ESCOLA
# 11025638                     C                    A                  NaN
# 11025352                     C                    A                    A
# 11024828                     B                    A                    E
# 11025310                     C                    A                    A
# 11024968                     B                    A                    A
# 11025620                     B                    B                    E
# 11024666                   NaN                  NaN                  NaN
# 11024682                     B                    B                    E
# 11007885                     C                    B                    D
# 11007281                     B                    B                    E
#
#           DIRETOR_TX_RESP_Q028 DIRETOR_TX_RESP_Q029 DIRETOR_TX_RESP_Q030  \
# ID_ESCOLA
# 11025638                     D                    E                    B
# 11025352                     C                    A                    A
# 11024828                     B                    A                    A
# 11025310                     D                    D                    B
# 11024968                     A                    E                    B
# 11025620                     E                    E                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     D                    E                    C
# 11007885                     D                    E                    B
# 11007281                     D                    C                    E
#
#           DIRETOR_TX_RESP_Q031 DIRETOR_TX_RESP_Q032 DIRETOR_TX_RESP_Q033  \
# ID_ESCOLA
# 11025638                     E                    F                    A
# 11025352                     E                    D                    C
# 11024828                     D                    C                    A
# 11025310                     E                    F                    A
# 11024968                     E                    F                    A
# 11025620                     E                    H                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     D                    H                    A
# 11007885                     E                    H                    A
# 11007281                     E                    F                    A
#
#           DIRETOR_TX_RESP_Q034 DIRETOR_TX_RESP_Q035 DIRETOR_TX_RESP_Q036  \
# ID_ESCOLA
# 11025638                     A                    A                    A
# 11025352                     B                    B                    B
# 11024828                     A                    A                    A
# 11025310                     A                    A                    B
# 11024968                     A                    A                    A
# 11025620                     A                    B                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    A
# 11007885                     A                    A                    A
# 11007281                     A                    A                    A
#
#           DIRETOR_TX_RESP_Q037 DIRETOR_TX_RESP_Q038 DIRETOR_TX_RESP_Q039  \
# ID_ESCOLA
# 11025638                     D                    A                    E
# 11025352                     C                    A                    E
# 11024828                     E                    A                    E
# 11025310                     C                    A                    F
# 11024968                     D                    C                    E
# 11025620                     D                    A                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     D                    A                    C
# 11007885                     D                    A                    D
# 11007281                     D                    A                    E
#
#           DIRETOR_TX_RESP_Q040 DIRETOR_TX_RESP_Q041 DIRETOR_TX_RESP_Q042  \
# ID_ESCOLA
# 11025638                     B                    C                    C
# 11025352                     I                    C                    E
# 11024828                     I                    B                    D
# 11025310                     J                    C                    C
# 11024968                     I                    C                    C
# 11025620                     H                    D                    D
# 11024666                   NaN                  NaN                  NaN
# 11024682                     E                    E                    D
# 11007885                     H                    E                    E
# 11007281                     E                    C                    C
#
#           DIRETOR_TX_RESP_Q043 DIRETOR_TX_RESP_Q044 DIRETOR_TX_RESP_Q045  \
# ID_ESCOLA
# 11025638                     B                    C                    C
# 11025352                     B                    C                    C
# 11024828                     B                    C                    C
# 11025310                     B                    C                    C
# 11024968                     B                    C                    B
# 11025620                     B                    D                    D
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    C                    C
# 11007885                     B                    C                    C
# 11007281                     B                    C                    B
#
#           DIRETOR_TX_RESP_Q046 DIRETOR_TX_RESP_Q047 DIRETOR_TX_RESP_Q048  \
# ID_ESCOLA
# 11025638                     D                    C                    C
# 11025352                     D                    D                    D
# 11024828                     D                    D                    D
# 11025310                     D                    D                    D
# 11024968                     C                    A                    C
# 11025620                     D                    C                    D
# 11024666                   NaN                  NaN                  NaN
# 11024682                     C                    C                    C
# 11007885                     C                    C                    D
# 11007281                     C                    C                    C
#
#           DIRETOR_TX_RESP_Q049 DIRETOR_TX_RESP_Q050 DIRETOR_TX_RESP_Q051  \
# ID_ESCOLA
# 11025638                     B                    B                    B
# 11025352                     B                    B                    B
# 11024828                     A                    B                    A
# 11025310                     B                    B                    C
# 11024968                     A                    B                    B
# 11025620                     B                    B                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     B                    C                    C
# 11007885                     B                    B                    B
# 11007281                     A                    C                    D
#
#           DIRETOR_TX_RESP_Q052 DIRETOR_TX_RESP_Q053 DIRETOR_TX_RESP_Q054  \
# ID_ESCOLA
# 11025638                     B                    B                    B
# 11025352                     B                    B                    D
# 11024828                     B                    C                    B
# 11025310                     D                    B                    B
# 11024968                     D                    B                    B
# 11025620                     D                    C                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     C                    C                    A
# 11007885                     C                    B                    C
# 11007281                     C                    B                    B
#
#           DIRETOR_TX_RESP_Q055 DIRETOR_TX_RESP_Q056 DIRETOR_TX_RESP_Q057  \
# ID_ESCOLA
# 11025638                     A                    B                    B
# 11025352                     B                    B                    B
# 11024828                     A                    B                    A
# 11025310                     D                    A                    A
# 11024968                     B                    B                    C
# 11025620                     B                    B                    C
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    B                    C
# 11007885                     B                    E                    B
# 11007281                     A                    D                    B
#
#           DIRETOR_TX_RESP_Q058 DIRETOR_TX_RESP_Q059 DIRETOR_TX_RESP_Q060  \
# ID_ESCOLA
# 11025638                     A                    A                    A
# 11025352                     A                    A                    A
# 11024828                     A                    A                    A
# 11025310                     A                    C                    A
# 11024968                     C                    A                    A
# 11025620                     B                    A                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    A
# 11007885                     C                    A                    B
# 11007281                     B                    A                    B
#
#           DIRETOR_TX_RESP_Q061 DIRETOR_TX_RESP_Q062 DIRETOR_TX_RESP_Q063  \
# ID_ESCOLA
# 11025638                     B                    C                    C
# 11025352                     A                    D                    C
# 11024828                     A                    C                    C
# 11025310                     A                    D                    D
# 11024968                     A                    C                    C
# 11025620                     A                    C                    C
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    C                    C
# 11007885                     A                    D                    D
# 11007281                     A                    D                    D
#
#           DIRETOR_TX_RESP_Q064 DIRETOR_TX_RESP_Q065 DIRETOR_TX_RESP_Q066  \
# ID_ESCOLA
# 11025638                     D                    C                    C
# 11025352                     D                    C                    D
# 11024828                     C                    C                    C
# 11025310                     D                    C                    C
# 11024968                     D                    D                    C
# 11025620                     D                    E                    E
# 11024666                   NaN                  NaN                  NaN
# 11024682                     D                    D                    D
# 11007885                     D                    C                    C
# 11007281                     D                    B                    B
#
#           DIRETOR_TX_RESP_Q067 DIRETOR_TX_RESP_Q068 DIRETOR_TX_RESP_Q069  \
# ID_ESCOLA
# 11025638                     B                    C                    D
# 11025352                     C                    A                    D
# 11024828                     B                    B                    D
# 11025310                     A                    B                    A
# 11024968                     B                    D                    C
# 11025620                     C                    A                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    A
# 11007885                     A                    B                    C
# 11007281                     B                    B                    B
#
#           DIRETOR_TX_RESP_Q070 DIRETOR_TX_RESP_Q071 DIRETOR_TX_RESP_Q072  \
# ID_ESCOLA
# 11025638                     D                    C                    D
# 11025352                     A                    A                    A
# 11024828                     A                    A                    B
# 11025310                     A                    A                    B
# 11024968                     A                    B                    C
# 11025620                     A                    B                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    A
# 11007885                     C                    B                    B
# 11007281                     B                    A                    D
#
#           DIRETOR_TX_RESP_Q073 DIRETOR_TX_RESP_Q074 DIRETOR_TX_RESP_Q075  \
# ID_ESCOLA
# 11025638                     C                    C                    C
# 11025352                     B                    A                    A
# 11024828                     C                    D                    B
# 11025310                     A                    A                    A
# 11024968                     C                    C                    D
# 11025620                     A                    A                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    A
# 11007885                     B                    B                    B
# 11007281                     B                    B                    C
#
#           DIRETOR_TX_RESP_Q076 DIRETOR_TX_RESP_Q077 DIRETOR_TX_RESP_Q078  \
# ID_ESCOLA
# 11025638                     C                    A                    A
# 11025352                     A                    A                    A
# 11024828                     D                    B                    B
# 11025310                     A                    A                    A
# 11024968                     A                    A                    A
# 11025620                     A                    B                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    B                    A
# 11007885                     B                    B                    A
# 11007281                     B                    A                    A
#
#           DIRETOR_TX_RESP_Q079 DIRETOR_TX_RESP_Q080 DIRETOR_TX_RESP_Q081  \
# ID_ESCOLA
# 11025638                     A                    A                    A
# 11025352                     A                    A                    A
# 11024828                     A                    A                    A
# 11025310                     A                    A                    A
# 11024968                     A                    A                    A
# 11025620                     A                    A                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    A
# 11007885                     A                    A                    A
# 11007281                     A                    A                    A
#
#           DIRETOR_TX_RESP_Q082 DIRETOR_TX_RESP_Q083 DIRETOR_TX_RESP_Q084  \
# ID_ESCOLA
# 11025638                     A                    B                    A
# 11025352                     B                    A                    B
# 11024828                     A                    A                    B
# 11025310                     B                    A                    B
# 11024968                     A                    A                    B
# 11025620                     A                    B                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    B                    B
# 11007885                     A                    B                    B
# 11007281                     A                    B                    B
#
#           DIRETOR_TX_RESP_Q085 DIRETOR_TX_RESP_Q086 DIRETOR_TX_RESP_Q087  \
# ID_ESCOLA
# 11025638                     A                    B                    A
# 11025352                     A                    B                    A
# 11024828                     A                    B                    A
# 11025310                     A                    B                    A
# 11024968                     A                    B                    B
# 11025620                     A                    B                    A
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    B                    A
# 11007885                     A                    B                    A
# 11007281                     A                    B                    A
#
#           DIRETOR_TX_RESP_Q088 DIRETOR_TX_RESP_Q089 DIRETOR_TX_RESP_Q090  \
# ID_ESCOLA
# 11025638                     B                    A                    A
# 11025352                     A                    A                    B
# 11024828                     A                    A                    A
# 11025310                     B                    A                    B
# 11024968                     A                    B                    A
# 11025620                     A                    A                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    A                    B
# 11007885                     B                    A                    A
# 11007281                     A                    A                    A
#
#           DIRETOR_TX_RESP_Q091 DIRETOR_TX_RESP_Q092 DIRETOR_TX_RESP_Q093  \
# ID_ESCOLA
# 11025638                     A                    B                    B
# 11025352                     A                    B                    B
# 11024828                     A                    B                    B
# 11025310                     A                    B                    B
# 11024968                     A                    B                    B
# 11025620                     A                  NaN                    B
# 11024666                   NaN                  NaN                  NaN
# 11024682                     A                    B                    B
# 11007885                     A                    B                    B
# 11007281                     A                    B                    B
#
#           DIRETOR_TX_RESP_Q094 DIRETOR_TX_RESP_Q095 DIRETOR_TX_RESP_Q096  \
# ID_ESCOLA
# ...
# 11007281                     A                    A                    A
#
#           PROF_MT_TX_RESP_Q074 PROF_MT_TX_RESP_Q075 PROF_MT_TX_RESP_Q076  \
# ID_ESCOLA
# 11025638                     A                    A                    B
# 11025352                     A                    B                    A
# 11024828                     A                    A                    A
# 11025310                     B                    B                    A
# 11024968                     A                    A                    A
# 11025620                     A                    A                    A
# 11024666                     A                    A                    B
# 11024682                     A                    A                    A
# 11007885                     B                    B                    A
# 11007281                     A                    A                    A
#
#           PROF_MT_TX_RESP_Q077 PROF_MT_TX_RESP_Q078 PROF_MT_TX_RESP_Q079  \
# ID_ESCOLA
# 11025638                     B                    A                    B
# 11025352                     B                    A                    A
# 11024828                     A                    A                    A
# 11025310                     A                    A                    A
# 11024968                     A                    A                    A
# 11025620                     A                    A                    A
# 11024666                     A                    A                    B
# 11024682                     A                    A                    A
# 11007885                     A                    A                    A
# 11007281                     A                    A                    A
#
#           PROF_MT_TX_RESP_Q080 PROF_MT_TX_RESP_Q081 PROF_MT_TX_RESP_Q082  \
# ID_ESCOLA
# 11025638                     A                    A                    A
# 11025352                     A                    A                    B
# 11024828                     A                    A                    B
# 11025310                     A                    A                    B
# 11024968                     A                    A                    B
# 11025620                     A                    A                    B
# 11024666                     A                    A                    B
# 11024682                     A                    A                    B
# 11007885                     A                    A                    B
# 11007281                     A                    A                    A
#
#           PROF_MT_TX_RESP_Q083 PROF_MT_TX_RESP_Q084 PROF_MT_TX_RESP_Q085  \
# ID_ESCOLA
# 11025638                     B                    B                    B
# 11025352                     B                    A                    B
# 11024828                     B                  NaN                    B
# 11025310                     B                    A                    B
# 11024968                     A                    A                    B
# 11025620                     B                    A                    B
# 11024666                     A                    A                    B
# 11024682                     A                    A                    B
# 11007885                     A                    A                    B
# 11007281                     A                    A                    B
#
#           PROF_MT_TX_RESP_Q086 PROF_MT_TX_RESP_Q087 PROF_MT_TX_RESP_Q088  \
# ID_ESCOLA
# 11025638                     B                    B                    B
# 11025352                     B                    B                    B
# 11024828                     B                    B                    B
# 11025310                     B                    B                    B
# 11024968                     B                    A                    A
# 11025620                     B                    B                    B
# 11024666                     B                    B                    B
# 11024682                     B                    B                    B
# 11007885                     B                    B                    B
# 11007281                     B                    B                    B
#
#           PROF_MT_TX_RESP_Q089 PROF_MT_TX_RESP_Q090 PROF_MT_TX_RESP_Q091  \
# ID_ESCOLA
# 11025638                     B                    B                    B
# 11025352                     B                    B                    B
# 11024828                     B                    B                    B
# 11025310                     B                    B                    B
# 11024968                     A                    A                    A
# 11025620                     B                    B                    B
# 11024666                     B                    B                    B
# 11024682                     B                    B                    B
# 11007885                     B                    B                    B
# 11007281                     B                    B                    B
#
#           PROF_MT_TX_RESP_Q092 PROF_MT_TX_RESP_Q093 PROF_MT_TX_RESP_Q094  \
# ID_ESCOLA
# 11025638                     B                  NaN                    D
# 11025352                     B                  NaN                    D
# 11024828                     B                    D                    D
# 11025310                     B                    D                    D
# 11024968                     A                  NaN                    D
# 11025620                     B                  NaN                    D
# 11024666                     B                  NaN                    D
# 11024682                     B                  NaN                    D
# 11007885                     B                  NaN                    D
# 11007281                     B                  NaN                  NaN
#
#           PROF_MT_TX_RESP_Q095 PROF_MT_TX_RESP_Q096 PROF_MT_TX_RESP_Q097  \
# ID_ESCOLA
# 11025638                     D                    C                    A
# 11025352                     C                    B                    A
# 11024828                     D                    B                    A
# 11025310                     D                    D                    A
# 11024968                     C                    C                    A
# 11025620                     C                    B                    A
# 11024666                     D                    C                    B
# 11024682                     D                    C                    B
# 11007885                     D                    C                    A
# 11007281                   NaN                  NaN                    B
#
#           PROF_MT_TX_RESP_Q098 PROF_MT_TX_RESP_Q099 PROF_MT_TX_RESP_Q100  \
# ID_ESCOLA
# 11025638                     A                    E                    A
# 11025352                     C                    E                    A
# 11024828                     A                    E                    A
# 11025310                     A                    E                    A
# 11024968                     A                    E                    A
# 11025620                     A                    E                    A
# 11024666                     C                    E                    A
# 11024682                     C                    E                    A
# 11007885                     A                    E                    A
# 11007281                     C                    E                    A
#
#           PROF_MT_TX_RESP_Q101 PROF_MT_TX_RESP_Q102 PROF_MT_TX_RESP_Q103  \
# ID_ESCOLA
# 11025638                     D                    A                    A
# 11025352                     D                    A                    A
# 11024828                     D                    A                    E
# 11025310                     E                    A                    A
# 11024968                     C                    A                    C
# 11025620                     D                    A                    D
# 11024666                     C                    A                    A
# 11024682                     D                    A                    C
# 11007885                     E                    A                    B
# 11007281                     D                    B                    B
#
#           PROF_MT_TX_RESP_Q104 PROF_MT_TX_RESP_Q105 PROF_MT_TX_RESP_Q106  \
# ID_ESCOLA
# 11025638                     F                    B                    D
# 11025352                     F                    B                    D
# 11024828                     E                    B                    D
# 11025310                     D                    B                    E
# 11024968                     D                    B                    E
# 11025620                     F                    B                    E
# 11024666                     F                    B                    E
# 11024682                     E                    B                    E
# 11007885                     F                    B                    E
# 11007281                     D                    B                    D
#
#           PROF_MT_TX_RESP_Q107 PROF_MT_TX_RESP_Q108 PROF_MT_TX_RESP_Q109  \
# ID_ESCOLA
# 11025638                     E                    E                    E
# 11025352                     E                    E                    D
# 11024828                     E                    F                    F
# 11025310                     E                    E                    E
# 11024968                     D                    B                    D
# 11025620                     F                    F                    D
# 11024666                     E                    F                    E
# 11024682                     E                    E                    D
# 11007885                     F                    F                    E
# 11007281                     F                    F                    D
#
#           PROF_MT_TX_RESP_Q110 PROF_MT_TX_RESP_Q111 PROF_MT_TX_RESP_Q112  \
# ID_ESCOLA
# 11025638                     D                    E                    E
# 11025352                     C                    F                    D
# 11024828                     D                    F                    F
# 11025310                     B                    E                    E
# 11024968                     C                    D                    E
# 11025620                     B                    A                    A
# 11024666                     C                    F                    F
# 11024682                     C                    E                    D
# 11007885                     D                    F                    F
# 11007281                     C                    F                    F
#
#           PROF_MT_TX_RESP_Q113 PROF_MT_TX_RESP_Q114 PROF_MT_TX_RESP_Q115  \
# ID_ESCOLA
# 11025638                     E                  NaN                  NaN
# 11025352                     C                  NaN                  NaN
# 11024828                     F                    F                    F
# 11025310                     E                  NaN                  NaN
# 11024968                     E                    A                    A
# 11025620                     D                  NaN                  NaN
# 11024666                     F                    D                  NaN
# 11024682                     D                  NaN                  NaN
# 11007885                     F                  NaN                  NaN
# 11007281                     E                    D                  NaN
#
#           PROF_MT_TX_RESP_Q116 PROF_MT_TX_RESP_Q117 PROF_MT_TX_RESP_Q118  \
# ID_ESCOLA
# 11025638                   NaN                  NaN                  NaN
# 11025352                   NaN                  NaN                  NaN
# 11024828                     F                    F                    F
# 11025310                   NaN                  NaN                  NaN
# 11024968                     A                    A                    A
# 11025620                   NaN                  NaN                  NaN
# 11024666                   NaN                  NaN                  NaN
# 11024682                   NaN                  NaN                  NaN
# 11007885                   NaN                  NaN                  NaN
# 11007281                   NaN                  NaN                  NaN
#
#           PROF_MT_TX_RESP_Q119 PROF_MT_TX_RESP_Q120 PROF_MT_TX_RESP_Q121  \
# ID_ESCOLA
# 11025638                   NaN                    E                    E
# 11025352                   NaN                    F                    F
# 11024828                     F                  NaN                  NaN
# 11025310                   NaN                    E                    E
# 11024968                   NaN                    E                    E
# 11025620                   NaN                    F                    F
# 11024666                   NaN                    F                    F
# 11024682                   NaN                    F                    F
# 11007885                   NaN                    F                    F
# 11007281                   NaN                    F                    E
#
#           PROF_MT_TX_RESP_Q122 PROF_MT_TX_RESP_Q123 PROF_MT_TX_RESP_Q124  \
# ID_ESCOLA
# 11025638                     E                    D                    E
# 11025352                     F                    C                    E
# 11024828                   NaN                  NaN                  NaN
# 11025310                     E                    D                    E
# 11024968                     E                    D                    E
# 11025620                     E                    D                    F
# 11024666                     F                    D                    F
# 11024682                     E                    D                    E
# 11007885                     F                    E                    F
# 11007281                     F                    D                    F
#
#           PROF_MT_TX_RESP_Q125
# ID_ESCOLA
# 11025638                     E
# 11025352                     C
# 11024828                   NaN
# 11025310                     D
# 11024968                     D
# 11025620                     D
# 11024666                     F
# 11024682                     D
# 11007885                     F
# 11007281                     E

# %%
with pd.option_context("display.max_rows", 500, "display.max_columns", 500):
    display(df_saeb9_dir_lp_mt.isnull().sum())
# Out:
# ID_PROVA_BRASIL                  0
# ID_UF                            0
# ID_MUNICIPIO                     0
# ID_DEPENDENCIA_ADM               0
# ID_LOCALIZACAO                   0
# PC_FORMACAO_DOCENTE_FINAL        0
# NIVEL_SOCIO_ECONOMICO           87
# NU_MATRICULADOS_CENSO_9EF        0
# NU_PRESENTES_9EF                 0
# TAXA_PARTICIPACAO_9EF            0
# NIVEL_0_LP9                      0
# NIVEL_1_LP9                      0
# NIVEL_2_LP9                      0
# NIVEL_3_LP9                      0
# NIVEL_4_LP9                      0
# NIVEL_5_LP9                      0
# NIVEL_6_LP9                      0
# NIVEL_7_LP9                      0
# NIVEL_8_LP9                      0
# NIVEL_0_MT9                      0
# NIVEL_1_MT9                      0
# NIVEL_2_MT9                      0
# NIVEL_3_MT9                      0
# NIVEL_4_MT9                      0
# NIVEL_5_MT9                      0
# NIVEL_6_MT9                      0
# NIVEL_7_MT9                      0
# NIVEL_8_MT9                      0
# NIVEL_9_MT9                      0
# MEDIA_9EF_LP                     0
# MEDIA_9EF_MT                     0
# TX_RESP_Q007                  1194
# TX_RESP_Q008                  1149
# TX_RESP_Q009                  1297
# TX_RESP_Q010                  1341
# TX_RESP_Q011                  1332
# TX_RESP_Q012                  1264
# TX_RESP_Q013                  1197
# TX_RESP_Q014                  1599
# TX_RESP_Q015                  1853
# TX_RESP_Q016                  2105
# TX_RESP_Q017                  2212
# TX_RESP_Q018                  2054
# TX_RESP_Q019                  1993
# TX_RESP_Q020                  1312
# TX_RESP_Q021                  1377
# TX_RESP_Q022                   782
# TX_RESP_Q023                   807
# TX_RESP_Q024                   941
# TX_RESP_Q025                   992
# TX_RESP_Q026                  1177
# TX_RESP_Q027                   906
# TX_RESP_Q028                   922
# TX_RESP_Q029                   975
# TX_RESP_Q030                  1797
# TX_RESP_Q031                   940
# TX_RESP_Q032                  1331
# TX_RESP_Q033                  1475
# TX_RESP_Q034                  1426
# TX_RESP_Q035                  1904
# TX_RESP_Q036                  1927
# TX_RESP_Q037                  1858
# TX_RESP_Q038                  2007
# TX_RESP_Q039                  1999
# TX_RESP_Q040                  1993
# TX_RESP_Q041                  1916
# TX_RESP_Q042                  2092
# TX_RESP_Q043                  2072
# TX_RESP_Q044                  2066
# TX_RESP_Q045                  1873
# TX_RESP_Q046                  1932
# TX_RESP_Q047                  2342
# TX_RESP_Q048                  2455
# TX_RESP_Q049                  2400
# TX_RESP_Q050                  2611
# TX_RESP_Q051                  2504
# TX_RESP_Q052                  2708
# TX_RESP_Q053                  2662
# TX_RESP_Q054                  2482
# TX_RESP_Q055                  2529
# TX_RESP_Q056                  2411
# TX_RESP_Q057                  1509
# TX_RESP_Q058                  1582
# TX_RESP_Q059                  1557
# TX_RESP_Q060                  1564
# TX_RESP_Q061                  1495
# TX_RESP_Q062                  1419
# TX_RESP_Q063                  1292
# TX_RESP_Q064                  1280
# TX_RESP_Q065                  1672
# TX_RESP_Q066                  1806
# TX_RESP_Q067                  1690
# TX_RESP_Q068                  1522
# TX_RESP_Q069                  1630
# TX_RESP_Q070                  1471
# TX_RESP_Q071                  1474
# TX_RESP_Q072                  1898
# TX_RESP_Q073                  1915
# TX_RESP_Q074                  1941
# DIRETOR_TX_RESP_Q001          1522
# DIRETOR_TX_RESP_Q002          1776
# DIRETOR_TX_RESP_Q003          1996
# DIRETOR_TX_RESP_Q004          2726
# DIRETOR_TX_RESP_Q005          1934
# DIRETOR_TX_RESP_Q006          2010
# DIRETOR_TX_RESP_Q007          1979
# DIRETOR_TX_RESP_Q008          1987
# DIRETOR_TX_RESP_Q009          2049
# DIRETOR_TX_RESP_Q010          1871
# DIRETOR_TX_RESP_Q011          1645
# DIRETOR_TX_RESP_Q012          2448
# DIRETOR_TX_RESP_Q013          1358
# DIRETOR_TX_RESP_Q014          1422
# DIRETOR_TX_RESP_Q015          1403
# DIRETOR_TX_RESP_Q016          1410
# DIRETOR_TX_RESP_Q017          1340
# DIRETOR_TX_RESP_Q018          1475
# DIRETOR_TX_RESP_Q019          1332
# DIRETOR_TX_RESP_Q020          1396
# DIRETOR_TX_RESP_Q021          1404
# DIRETOR_TX_RESP_Q022          2747
# DIRETOR_TX_RESP_Q023          2579
# DIRETOR_TX_RESP_Q024          2633
# DIRETOR_TX_RESP_Q025          2771
# DIRETOR_TX_RESP_Q026          2094
# DIRETOR_TX_RESP_Q027          2172
# DIRETOR_TX_RESP_Q028          1940
# DIRETOR_TX_RESP_Q029          2029
# DIRETOR_TX_RESP_Q030          1877
# DIRETOR_TX_RESP_Q031          1823
# DIRETOR_TX_RESP_Q032          1882
# DIRETOR_TX_RESP_Q033          1668
# DIRETOR_TX_RESP_Q034          1679
# DIRETOR_TX_RESP_Q035          1626
# DIRETOR_TX_RESP_Q036          1340
# DIRETOR_TX_RESP_Q037          1427
# DIRETOR_TX_RESP_Q038          1307
# DIRETOR_TX_RESP_Q039          1368
# DIRETOR_TX_RESP_Q040          1345
# DIRETOR_TX_RESP_Q041          1284
# DIRETOR_TX_RESP_Q042          1339
# DIRETOR_TX_RESP_Q043          1366
# DIRETOR_TX_RESP_Q044          1649
# DIRETOR_TX_RESP_Q045          1854
# DIRETOR_TX_RESP_Q046          1909
# DIRETOR_TX_RESP_Q047          1945
# DIRETOR_TX_RESP_Q048          1960
# DIRETOR_TX_RESP_Q049          1930
# DIRETOR_TX_RESP_Q050          1920
# DIRETOR_TX_RESP_Q051          1876
# DIRETOR_TX_RESP_Q052          1911
# DIRETOR_TX_RESP_Q053          1834
# DIRETOR_TX_RESP_Q054          1770
# DIRETOR_TX_RESP_Q055          1671
# DIRETOR_TX_RESP_Q056          1721
# DIRETOR_TX_RESP_Q057          1406
# DIRETOR_TX_RESP_Q058          1330
# DIRETOR_TX_RESP_Q059          1253
# DIRETOR_TX_RESP_Q060          1270
# DIRETOR_TX_RESP_Q061          1245
# DIRETOR_TX_RESP_Q062          1684
# DIRETOR_TX_RESP_Q063          1432
# DIRETOR_TX_RESP_Q064          1412
# DIRETOR_TX_RESP_Q065          1357
# DIRETOR_TX_RESP_Q066          1318
# DIRETOR_TX_RESP_Q067          1708
# DIRETOR_TX_RESP_Q068          1789
# DIRETOR_TX_RESP_Q069          1981
# DIRETOR_TX_RESP_Q070          1923
# DIRETOR_TX_RESP_Q071          1995
# DIRETOR_TX_RESP_Q072          1934
# DIRETOR_TX_RESP_Q073          1892
# DIRETOR_TX_RESP_Q074          1859
# DIRETOR_TX_RESP_Q075          1913
# DIRETOR_TX_RESP_Q076          1852
# DIRETOR_TX_RESP_Q077          1996
# DIRETOR_TX_RESP_Q078          1759
# DIRETOR_TX_RESP_Q079          1782
# DIRETOR_TX_RESP_Q080          1554
# DIRETOR_TX_RESP_Q081          1454
# DIRETOR_TX_RESP_Q082          1529
# DIRETOR_TX_RESP_Q083          1468
# DIRETOR_TX_RESP_Q084          1427
# DIRETOR_TX_RESP_Q085          1359
# DIRETOR_TX_RESP_Q086          1398
# DIRETOR_TX_RESP_Q087          1478
# DIRETOR_TX_RESP_Q088          1457
# DIRETOR_TX_RESP_Q089          1495
# DIRETOR_TX_RESP_Q090          1891
# DIRETOR_TX_RESP_Q091          1880
# DIRETOR_TX_RESP_Q092          2197
# DIRETOR_TX_RESP_Q093          2067
# DIRETOR_TX_RESP_Q094          2166
# DIRETOR_TX_RESP_Q095          1998
# DIRETOR_TX_RESP_Q096          2088
# DIRETOR_TX_RESP_Q097          2010
# DIRETOR_TX_RESP_Q098          1983
# DIRETOR_TX_RESP_Q099          1991
# DIRETOR_TX_RESP_Q100          1882
# DIRETOR_TX_RESP_Q101          1738
# DIRETOR_TX_RESP_Q102          1741
# DIRETOR_TX_RESP_Q103          1592
# DIRETOR_TX_RESP_Q104          1378
# DIRETOR_TX_RESP_Q105          1366
# DIRETOR_TX_RESP_Q106          1378
# DIRETOR_TX_RESP_Q107          1411
# DIRETOR_TX_RESP_Q108          1346
# DIRETOR_TX_RESP_Q109          1740
# DIRETOR_TX_RESP_Q110          1544
# DIRETOR_TX_RESP_Q111          1476
# PROF_LP_TX_RESP_Q001          6160
# PROF_LP_TX_RESP_Q002          6251
# PROF_LP_TX_RESP_Q003          6246
# PROF_LP_TX_RESP_Q004          6559
# PROF_LP_TX_RESP_Q005          6192
# PROF_LP_TX_RESP_Q006          6084
# PROF_LP_TX_RESP_Q007          6017
# PROF_LP_TX_RESP_Q008          6000
# PROF_LP_TX_RESP_Q009          5989
# PROF_LP_TX_RESP_Q010          5922
# PROF_LP_TX_RESP_Q011          5836
# PROF_LP_TX_RESP_Q012          6174
# PROF_LP_TX_RESP_Q013          5646
# PROF_LP_TX_RESP_Q014          5660
# PROF_LP_TX_RESP_Q015          5649
# PROF_LP_TX_RESP_Q016          5826
# PROF_LP_TX_RESP_Q017          5663
# PROF_LP_TX_RESP_Q018          5623
# PROF_LP_TX_RESP_Q019          5849
# PROF_LP_TX_RESP_Q020          5918
# PROF_LP_TX_RESP_Q021          5623
# PROF_LP_TX_RESP_Q022          6306
# PROF_LP_TX_RESP_Q023          6303
# PROF_LP_TX_RESP_Q024          6274
# PROF_LP_TX_RESP_Q025          6321
# PROF_LP_TX_RESP_Q026          6318
# PROF_LP_TX_RESP_Q027          6147
# PROF_LP_TX_RESP_Q028          6101
# PROF_LP_TX_RESP_Q029          6044
# PROF_LP_TX_RESP_Q030          6021
# PROF_LP_TX_RESP_Q031          5956
# PROF_LP_TX_RESP_Q032          5918
# PROF_LP_TX_RESP_Q033          5885
# PROF_LP_TX_RESP_Q034          6045
# PROF_LP_TX_RESP_Q035          5907
# PROF_LP_TX_RESP_Q036          5842
# PROF_LP_TX_RESP_Q037          5831
# PROF_LP_TX_RESP_Q038          5719
# PROF_LP_TX_RESP_Q039          5670
# PROF_LP_TX_RESP_Q040          5673
# PROF_LP_TX_RESP_Q041          5720
# PROF_LP_TX_RESP_Q042          5626
# PROF_LP_TX_RESP_Q043          5628
# PROF_LP_TX_RESP_Q044          5711
# PROF_LP_TX_RESP_Q045          6347
# PROF_LP_TX_RESP_Q046          6369
# PROF_LP_TX_RESP_Q047          6341
# PROF_LP_TX_RESP_Q048          6340
# PROF_LP_TX_RESP_Q049          6268
# PROF_LP_TX_RESP_Q050          6123
# PROF_LP_TX_RESP_Q051          6236
# PROF_LP_TX_RESP_Q052          6126
# PROF_LP_TX_RESP_Q053          6203
# PROF_LP_TX_RESP_Q054          5947
# PROF_LP_TX_RESP_Q055          5896
# PROF_LP_TX_RESP_Q056          5790
# PROF_LP_TX_RESP_Q057          5778
# PROF_LP_TX_RESP_Q058          5693
# PROF_LP_TX_RESP_Q059          5639
# PROF_LP_TX_RESP_Q060          5650
# PROF_LP_TX_RESP_Q061          5644
# PROF_LP_TX_RESP_Q062          5649
# PROF_LP_TX_RESP_Q063          5630
# PROF_LP_TX_RESP_Q064          5634
# PROF_LP_TX_RESP_Q065          5634
# PROF_LP_TX_RESP_Q066          5635
# PROF_LP_TX_RESP_Q067          5611
# PROF_LP_TX_RESP_Q068          5935
# PROF_LP_TX_RESP_Q069          5957
# PROF_LP_TX_RESP_Q070          5991
# PROF_LP_TX_RESP_Q071          5974
# PROF_LP_TX_RESP_Q072          5929
# PROF_LP_TX_RESP_Q073          5891
# PROF_LP_TX_RESP_Q074          5895
# PROF_LP_TX_RESP_Q075          5930
# PROF_LP_TX_RESP_Q076          5843
# PROF_LP_TX_RESP_Q077          5793
# PROF_LP_TX_RESP_Q078          5717
# PROF_LP_TX_RESP_Q079          5688
# PROF_LP_TX_RESP_Q080          5652
# PROF_LP_TX_RESP_Q081          5653
# PROF_LP_TX_RESP_Q082          5659
# PROF_LP_TX_RESP_Q083          5684
# PROF_LP_TX_RESP_Q084          5668
# PROF_LP_TX_RESP_Q085          5653
# PROF_LP_TX_RESP_Q086          5632
# PROF_LP_TX_RESP_Q087          5604
# PROF_LP_TX_RESP_Q088          5595
# PROF_LP_TX_RESP_Q089          5611
# PROF_LP_TX_RESP_Q090          5626
# PROF_LP_TX_RESP_Q091          5629
# PROF_LP_TX_RESP_Q092          5655
# PROF_LP_TX_RESP_Q093         26933
# PROF_LP_TX_RESP_Q094          8902
# PROF_LP_TX_RESP_Q095          6457
# PROF_LP_TX_RESP_Q096          6334
# PROF_LP_TX_RESP_Q097          5861
# PROF_LP_TX_RESP_Q098          5865
# PROF_LP_TX_RESP_Q099          5784
# PROF_LP_TX_RESP_Q100          5796
# PROF_LP_TX_RESP_Q101          5830
# PROF_LP_TX_RESP_Q102          5824
# PROF_LP_TX_RESP_Q103          5858
# PROF_LP_TX_RESP_Q104          5798
# PROF_LP_TX_RESP_Q105          5536
# PROF_LP_TX_RESP_Q106          5666
# PROF_LP_TX_RESP_Q107          5737
# PROF_LP_TX_RESP_Q108          5739
# PROF_LP_TX_RESP_Q109          5730
# PROF_LP_TX_RESP_Q110          5778
# PROF_LP_TX_RESP_Q111          5770
# PROF_LP_TX_RESP_Q112          5711
# PROF_LP_TX_RESP_Q113          5700
# PROF_LP_TX_RESP_Q114          5649
# PROF_LP_TX_RESP_Q115          5656
# PROF_LP_TX_RESP_Q116          5658
# PROF_LP_TX_RESP_Q117          5678
# PROF_LP_TX_RESP_Q118          5678
# PROF_LP_TX_RESP_Q119          5731
# PROF_LP_TX_RESP_Q120         25310
# PROF_LP_TX_RESP_Q121         26676
# PROF_LP_TX_RESP_Q122         27706
# PROF_LP_TX_RESP_Q123         28101
# PROF_LP_TX_RESP_Q124         28208
# PROF_LP_TX_RESP_Q125         28266
# PROF_MT_TX_RESP_Q001          5686
# PROF_MT_TX_RESP_Q002          5750
# PROF_MT_TX_RESP_Q003          5761
# PROF_MT_TX_RESP_Q004          6078
# PROF_MT_TX_RESP_Q005          5731
# PROF_MT_TX_RESP_Q006          5645
# PROF_MT_TX_RESP_Q007          5548
# PROF_MT_TX_RESP_Q008          5515
# PROF_MT_TX_RESP_Q009          5552
# PROF_MT_TX_RESP_Q010          5457
# PROF_MT_TX_RESP_Q011          5324
# PROF_MT_TX_RESP_Q012          5616
# PROF_MT_TX_RESP_Q013          5151
# PROF_MT_TX_RESP_Q014          5170
# PROF_MT_TX_RESP_Q015          5162
# PROF_MT_TX_RESP_Q016          5356
# PROF_MT_TX_RESP_Q017          5174
# PROF_MT_TX_RESP_Q018          5128
# PROF_MT_TX_RESP_Q019          5270
# PROF_MT_TX_RESP_Q020          5298
# PROF_MT_TX_RESP_Q021          5153
# PROF_MT_TX_RESP_Q022          5844
# PROF_MT_TX_RESP_Q023          5856
# PROF_MT_TX_RESP_Q024          5821
# PROF_MT_TX_RESP_Q025          5829
# PROF_MT_TX_RESP_Q026          5846
# PROF_MT_TX_RESP_Q027          5663
# PROF_MT_TX_RESP_Q028          5654
# PROF_MT_TX_RESP_Q029          5571
# PROF_MT_TX_RESP_Q030          5508
# PROF_MT_TX_RESP_Q031          5487
# PROF_MT_TX_RESP_Q032          5445
# PROF_MT_TX_RESP_Q033          5383
# PROF_MT_TX_RESP_Q034          5588
# PROF_MT_TX_RESP_Q035          5459
# PROF_MT_TX_RESP_Q036          5372
# PROF_MT_TX_RESP_Q037          5343
# PROF_MT_TX_RESP_Q038          5130
# PROF_MT_TX_RESP_Q039          5130
# PROF_MT_TX_RESP_Q040          5139
# PROF_MT_TX_RESP_Q041          5134
# PROF_MT_TX_RESP_Q042          5127
# PROF_MT_TX_RESP_Q043          5127
# PROF_MT_TX_RESP_Q044          5220
# PROF_MT_TX_RESP_Q045          5944
# PROF_MT_TX_RESP_Q046          5926
# PROF_MT_TX_RESP_Q047          5887
# PROF_MT_TX_RESP_Q048          5876
# PROF_MT_TX_RESP_Q049          5800
# PROF_MT_TX_RESP_Q050          5655
# PROF_MT_TX_RESP_Q051          5734
# PROF_MT_TX_RESP_Q052          5619
# PROF_MT_TX_RESP_Q053          5678
# PROF_MT_TX_RESP_Q054          5507
# PROF_MT_TX_RESP_Q055          5410
# PROF_MT_TX_RESP_Q056          5308
# PROF_MT_TX_RESP_Q057          5277
# PROF_MT_TX_RESP_Q058          5206
# PROF_MT_TX_RESP_Q059          5158
# PROF_MT_TX_RESP_Q060          5143
# PROF_MT_TX_RESP_Q061          5143
# PROF_MT_TX_RESP_Q062          5145
# PROF_MT_TX_RESP_Q063          5145
# PROF_MT_TX_RESP_Q064          5122
# PROF_MT_TX_RESP_Q065          5139
# PROF_MT_TX_RESP_Q066          5139
# PROF_MT_TX_RESP_Q067          5132
# PROF_MT_TX_RESP_Q068          5435
# PROF_MT_TX_RESP_Q069          5467
# PROF_MT_TX_RESP_Q070          5509
# PROF_MT_TX_RESP_Q071          5501
# PROF_MT_TX_RESP_Q072          5459
# PROF_MT_TX_RESP_Q073          5413
# PROF_MT_TX_RESP_Q074          5396
# PROF_MT_TX_RESP_Q075          5425
# PROF_MT_TX_RESP_Q076          5372
# PROF_MT_TX_RESP_Q077          5289
# PROF_MT_TX_RESP_Q078          5242
# PROF_MT_TX_RESP_Q079          5226
# PROF_MT_TX_RESP_Q080          5190
# PROF_MT_TX_RESP_Q081          5185
# PROF_MT_TX_RESP_Q082          5171
# PROF_MT_TX_RESP_Q083          5194
# PROF_MT_TX_RESP_Q084          5186
# PROF_MT_TX_RESP_Q085          5181
# PROF_MT_TX_RESP_Q086          5168
# PROF_MT_TX_RESP_Q087          5135
# PROF_MT_TX_RESP_Q088          5130
# PROF_MT_TX_RESP_Q089          5156
# PROF_MT_TX_RESP_Q090          5156
# PROF_MT_TX_RESP_Q091          5158
# PROF_MT_TX_RESP_Q092          5178
# PROF_MT_TX_RESP_Q093         27470
# PROF_MT_TX_RESP_Q094          8800
# PROF_MT_TX_RESP_Q095          5840
# PROF_MT_TX_RESP_Q096          5761
# PROF_MT_TX_RESP_Q097          5383
# PROF_MT_TX_RESP_Q098          5378
# PROF_MT_TX_RESP_Q099          5324
# PROF_MT_TX_RESP_Q100          5328
# PROF_MT_TX_RESP_Q101          5367
# PROF_MT_TX_RESP_Q102          5342
# PROF_MT_TX_RESP_Q103          5339
# PROF_MT_TX_RESP_Q104          5275
# PROF_MT_TX_RESP_Q105          5065
# PROF_MT_TX_RESP_Q106          5185
# PROF_MT_TX_RESP_Q107          5270
# PROF_MT_TX_RESP_Q108          5235
# PROF_MT_TX_RESP_Q109          5247
# PROF_MT_TX_RESP_Q110          5270
# PROF_MT_TX_RESP_Q111          5310
# PROF_MT_TX_RESP_Q112          5213
# PROF_MT_TX_RESP_Q113          5256
# PROF_MT_TX_RESP_Q114         24196
# PROF_MT_TX_RESP_Q115         25385
# PROF_MT_TX_RESP_Q116         26286
# PROF_MT_TX_RESP_Q117         26936
# PROF_MT_TX_RESP_Q118         27064
# PROF_MT_TX_RESP_Q119         27121
# PROF_MT_TX_RESP_Q120          5401
# PROF_MT_TX_RESP_Q121          5312
# PROF_MT_TX_RESP_Q122          5300
# PROF_MT_TX_RESP_Q123          5323
# PROF_MT_TX_RESP_Q124          5332
# PROF_MT_TX_RESP_Q125          5372
# dtype: int64

# %% [markdown]
# Grava base de 2013 no Storage.

# %%
df_saeb9_dir_lp_mt.to_csv('gs://bucket-tcc-fia-mba/ABT/ABT_2013.csv')
